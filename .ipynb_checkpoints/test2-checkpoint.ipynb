# %%
from MaterialPlanning import MaterialPlanning
import requests
import json
from os.path import isfile
from loguru import logger
import numpy as np

# %%
URL_ITEM = "https://penguin-stats.io/PenguinStats/api/v2/items" # item_id, item_name
URL_STAGE = "https://penguin-stats.io/PenguinStats/api/v2/stages" # stage_id, stage_name
URL_MATRIX = "https://penguin-stats.io/PenguinStats/api/v2/result/matrix?show_closed_zone=true"
URL_MATRIX_PRIVATE = "https://penguin-stats.io/PenguinStats/api/v2/_private/result/matrix/CN/global"
URL_FORMULA = "https://penguin-stats.io/PenguinStats/api/v2/formula" 
URL_EVENT = "https://penguin-stats.io/PenguinStats/api/v2/period"

URL_OPERATOR = "https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/locales/cn/character.json" # operator_name, operator_id
# URL_OPERATORORDER = "https://prts.wiki/w/%E6%A8%A1%E5%9D%97:GetCharCnOnlineTime"
# = "https://prts.wiki/w/%E5%B9%B2%E5%91%98%E4%B8%8A%E7%BA%BF%E6%97%B6%E9%97%B4%E4%B8%80%E8%A7%88"
URL_CULTIVATE = "https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/data/cultivate.json" # costs of elite, skill, module
URL_SKILL = "https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/locales/cn/skill.json"
URL_UNIEQUIP = "https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/locales/cn/uniequip.json"
URL_ZONE = "https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/locales/cn/zone.json"
URL_PRICE = "https://raw.githubusercontent.com/penguin-statistics/ArkPlanner/master/price.txt"




URL_SPREADSHEET = "https://docs.google.com/spreadsheets/d/1W6yO5FAmRP_-83MO0JDtc3m1MKzFdjjyiWPmt5SRFjY/gviz/tq?tqx=out:csv&sheet=planner"

# %%
def update_item_map() -> dict[str, str]:
    try:
        with requests.get(URL_ITEM) as response:
            txt = json.loads(response.text)

        item_map = dict() # item_id2item_name | item_name2item_id
        for item in txt:
            item_id = ite["itemId"].strip()
            item_name = item["name"].strip()
            
            item_map[item_id] = item_name
            item_map[item_name] = item_id

        # raw data        
        with open("./data/raw/item.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"Download item.json successfully from {URL_ITEM}.")

        # item_map
        with open("./data/item_map.json", 'w', encoding="utf-8") as fw:
            json.dump(item_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"item.json and item_map.json are saved.")

        return item_map
    except Exception as e:
        logger.error("Fail to update item_map.")
        logger.error(e)
        return dict()
    
def load_item_map(update = False) -> dict[str, str]: 
    if not isfile("./data/item_map.json"):
        logger.warning(f"item_map.json is not found. Download data from {URL_ITEM}")
        
    if update or not isfile("./data/item_map.json"):
        return update_item_map()
    else:
        with open("./data/item_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_stage_map() -> dict[str, list[str]]: 
    try:
        with requests.get(URL_STAGE) as response:
            txt = json.loads(response.text)

        stage_map = dict() # stage_id2stage_name_list | stage_name2stage_ids_list, actually stage_code
        
        for stage in txt:
            stage_id = stage["stageId"].strip()
            stage_code = stage["code"].strip()
            
            stage_map[stage_id] = [stage_code]
            if stage_code in stage_map:
                stage_map[stage_code].append(stage_id)
            else:
                stage_map[stage_code] = [stage_id]


        # raw data        
        with open("./data/raw/stage.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"stage.json is successfully downloaded from {URL_STAGE}.")

        # stage_map
        with open("./data/stage_map.json", 'w', encoding="utf-8") as fw:
            json.dump(stage_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"stage.json and stage_map.json are saved.")

        return stage_map
    except Exception as e:
        logger.error("Fail to update stage_map.")
        logger.error(e)
        return dict()

def load_stage_map(update = False) -> dict[str, list[str]]:
    if not isfile("./data/stage_map.json"):
        logger.warning(f"stage_map.json is not found. Download data from {URL_STAGE}")   
        
    if update or not isfile("./data/stage_map.json"):
        return save_stage_map()
    else:
        with open("./data/stage_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_operator_map() -> dict[str, str]: 
    try:
        with requests.get(URL_OPERATOR) as response:
            txt = json.loads(response.text)

        operator_map = dict() # operator_id2operator_name | operator_name2operator_ids
        for _id, name in txt.items():
            _id = _id.strip()
            name = name.strip()
   
            operator_map[_id] = name
            operator_map[name] = _id

        # raw data        
        with open("./data/raw/operator.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"operator.json is successfully downloaded from {URL_OPERATOR}.")

        # operator_map
        with open("./data/operator_map.json", 'w', encoding="utf-8") as fw:
            json.dump(operator_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"operator.json and operator_map.json are saved.")

        return operator_map
    except Exception as e:
        logger.error("Fail to update operator_map.")
        logger.error(e)
        return dict()

def load_operator_map(update = False) -> dict[str, list[str]]:
    if not isfile("./data/operator_map.json"):
        logger.warning(f"operator_map.json is not found. Download data from {URL_OPERATOR}")   
        
    if update or not isfile("./data/operator_map.json"):
        return save_operator_map()
    else:
        with open("./data/operator_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_skill_map() -> dict[str, str]: 
    try:
        with requests.get(URL_SKILL) as response:
            txt = json.loads(response.text)

        skill_map = dict() # skill_id2skill_name | skill_name2skill_ids
        for _id, name in txt.items():
            _id = _id.strip()
            name = name.strip()
   
            skill_map[_id] = name
            skill_map[name] = _id

        # raw data        
        with open("./data/raw/skill.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"skill.json is successfully downloaded from {URL_SKILL}.")

        # skill_map
        with open("./data/skill_map.json", 'w', encoding="utf-8") as fw:
            json.dump(skill_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"skill.json and skill_map.json are saved.")

        return skill_map
    except Exception as e:
        logger.error("Fail to update skill_map.")
        logger.error(e)
        return dict()

def load_skill_map(update = False) -> dict[str, list[str]]:
    if not isfile("./data/skill_map.json"):
        logger.warning(f"skill_map.json is not found. Download data from {URL_SKILL}")   
        
    if update or not isfile("./data/skill_map.json"):
        return save_skill_map()
    else:
        with open("./data/skill_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_uniequip_map() -> dict[str, str]: 
    try:
        with requests.get(URL_UNIEQUIP) as response:
            txt = json.loads(response.text)

        uniequip_map = dict() # uniequip_id2uniequip_name| uniequip_name2uniequip_ids
        for _id, name in txt.items():
            _id = _id.strip()
            name = name.strip()
   
            uniequip_map[_id] = name
            uniequip_map[name] = _id

        # raw data        
        with open("./data/raw/uniequip.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"uniequip.json is successfully downloaded from {URL_UNIEQUIP}.")

        # uniequip_map
        with open("./data/uniequip_map.json", 'w', encoding="utf-8") as fw:
            json.dump(uniequip_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"uniequip.json and uniequip_map.json are saved.")

        return uniequip_map
    except Exception as e:
        logger.error("Fail to update uniequip_map.")
        logger.error(e)
        return dict()

def load_uniequip_map(update = False) -> dict[str, list[str]]:
    if not isfile("./data/uniequip_map.json"):
        logger.warning(f"uniequip_map.json is not found. Download data from {URL_UNIEQUIP}")   
        
    if update or not isfile("./data/uniequip_map.json"):
        return save_uniequip_map()
    else:
        with open("./data/uniequip_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_cultivate_map() -> dict[str, str]: 
    try:
        with requests.get(URL_CULTIVATE) as response:
            txt = json.loads(response.text)

        item_map = load_item_map()
        operator_map = load_operator_map()
        skill_map = load_skill_map()
        uniequip_map = load_uniequip_map()
        cultivate_map = {operator_map[_id]: {
                            "evolve": [{item_map[item]: count for item, count in items.items()} for items in v["evolve"]],
                            "skills": {
                                "normal": [{item_map[item]: count for item, count in items.items()} for items in v["skills"]["normal"]],
                                "elite": [{
                                    "name": skill_map[skill["name"]],
                                    "cost": [{item_map[item]: count for item, count in items.items()} for items in skill["cost"]]
                                } for skill in v["skills"]["elite"]]},
                            "uniequip": [{
                                "id": uniequip_map[uniequip["id"]],
                                "cost": [{item_map[item]: count for item, count in items.items()} for items in uniequip["cost"]]
                            } for uniequip in v["uniequip"]]
                         } for _id, v in txt.items()}


        # raw data        
        with open("./data/raw/cultivate.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"cultivate.json is successfully downloaded from {URL_CULTIVATE}.")

        # operator_map
        with open("./data/cultivate_map.json", 'w', encoding="utf-8") as fw:
            json.dump(cultivate_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"cultivate.json and cultivate_map.json are saved.")

        return cultivate_map
    except Exception as e:
        logger.error("Fail to update cultivate_map.")
        logger.error(e)
        return dict()

def load_cultivate_map(update = False) -> dict[str, ]:
    if not isfile("./data/cultivate_map.json"):
        logger.warning(f"cultivate_map.json is not found. Download data from {URL_CULTIVATE}")   
        
    if update or not isfile("./data/cultivate_map.json"):
        return save_cultivate_map()
    else:
        with open("./data/cultivate_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_event_list() -> list: 
    try:
        with requests.get(URL_EVENT) as response:
            txt = json.loads(response.text)

        event_list = dict()
        event_list = {event["label_i18n"]["zh"].replace("·", "・"): [event["start"], event["end"]] for event in txt if event["existence"]["CN"]["exist"]}

        # raw data        
        with open("./data/raw/event.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"event.json is successfully downloaded from {URL_EVENT}.")

        # event_list
        with open("./data/event_list.json", 'w', encoding="utf-8") as fw:
            json.dump(event_list, fw, indent=2, ensure_ascii=False)
        logger.info(f"event.json and event_list.json are saved.")

        return event_list
    except Exception as e:
        logger.error("Fail to update event_list.")
        logger.error(e)
        return dict()

def load_event_list(update = False) -> dict:
    if not isfile("./data/event_list.json"):
        logger.warning(f"event_list.json is not found. Download data from {URL_EVENT}")   
        
    if update or not isfile("./data/event_list.json"):
        return save_event_list()
    else:
        with open("./data/event_list.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_zone_map() -> dict[str, str]: 
    try:
        with requests.get(URL_ZONE) as response:
            txt = json.loads(response.text)

        zone_map = dict() # zone_id2zone_name | zone_name2zone_ids
        for _id, name in txt.items():
            if "@" in name:
                _id = "_".join(_id.split("_")[:3])
                name = name.replace("@", "・永久@").split("@")[0].strip()
            else:
                _id = _id.strip()
                name = name.strip().replace("·", "・")
                
                
            zone_map[_id] = name
            zone_map[name] = _id

        # raw data        
        with open("./data/raw/zone.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"zone.json is successfully downloaded from {URL_ZONE}.")

        # zone_map
        with open("./data/zone_map.json", 'w', encoding="utf-8") as fw:
            json.dump(zone_map, fw, indent=2, ensure_ascii=False)
        logger.info(f"zone.json and zone_map.json are saved.")

        return zone_map
    except Exception as e:
        logger.error("Fail to update zone_map.")
        logger.error(e)
        return dict()

def load_zone_map(update = False) -> dict[str, list[str]]:
    if not isfile("./data/zone_map.json"):
        logger.warning(f"zone_map.json is not found. Download data from {URL_ZONE}")   
        
    if update or not isfile("./data/zone_map.json"):
        return save_zone_map()
    else:
        with open("./data/zone_map.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
def save_zone_matrix() -> dict: 
    """
    {
        <ZONE_ID>: {
            <STAGE_ID>: {
                "stage_type": <STAGE_TYPE>,
                "santity": <SANTITY>,
                "drop_info": {
                    <ITEM_NAME>: {"times": <TIMES>, "quantity": <QUANTITY>, "std_dev": <STD_DEV>},
                    ...,
                    <ITEM_NAME>: {"times": <TIMES>, "quantity": <QUANTITY>, "std_dev": <STD_DEV>}
                }
            }
        }
    }
    """
    try:
        item_map = load_item_map()
        stage_map = load_stage_map()
        zone_map = load_zone_map()
        
        zone_matrix = dict()

        # MATRIX
        with requests.get(URL_MATRIX_PRIVATE) as response:
            txt = json.loads(response.text)
        txt = txt["matrix"]

        stage_id2matrix = dict()
        for t in txt:
            stage_id = t["stageId"]
            item_name = item_map[t["itemId"]]
            times = t["times"]
            quantity = t["quantity"]
            std_dev = t["stdDev"]

            if stage_id not in stage_id2matrix: 
                stage_id2matrix[stage_id] = dict()
            stage_id2matrix[stage_id][item_name] = {"times": times, "quantity": quantity, "std_dev": std_dev}

        # STAGE
        with requests.get(URL_STAGE) as response:
            txt = json.loads(response.text)

        for stage in txt:
            stage_id = stage["stageId"]
            stage_name = stage_map[stage_id][0]
            zone_id = stage["zoneId"].replace("_zone1", "")
            zone_name = zone_map[zone_id] if zone_id in zone_map else stage["code"].split("-")[0]
            stage_type = stage["stageType"]
            sanity = stage["apCost"]

            if zone_name not in zone_matrix:
                zone_matrix[zone_name] = dict()
            zone_matrix[zone_name][stage_name] = {
                "stage_type": stage_type,
                "sanity": sanity,
                "drop_info": stage_id2matrix[stage_id] if stage_id in stage_id2matrix else dict()
            }



        # raw data        
        with open("./data/raw/matrix.json", 'w', encoding="utf-8") as fw:
            json.dump(txt, fw, indent=2, ensure_ascii=False)  
        logger.info(f"matrix.json is successfully downloaded from {URL_MATRIX}.")

        # zone_matrix
        with open("./data/zone_matrix.json", 'w', encoding="utf-8") as fw:
            json.dump(zone_matrix, fw, indent=2, ensure_ascii=False)
        logger.info(f"matrix.json and zone_matrix.json are saved.")

        return zone_matrix
    except Exception as e:
        logger.error("Fail to update stage_matrix.")
        logger.error(e)
        return dict()

def load_zone_matrix(update = False) -> dict[str, list[str]]:
    if not isfile("./data/zone_matrix.json"):
        logger.warning(f"zone_matrix.json is not found. Download data from {URL_MATRIX_PRIVATE} & {URL_STAGE}")   
        
    if update or not isfile("./data/zone_matrix.json"):
        return save_zone_matrix()
    else:
        with open("./data/zone_matrix.json", 'r', encoding="utf-8-sig") as fr:
            return json.loads(fr.read())

# %%
item_map = load_item_map()
stage_map = load_stage_map()
operator_map = load_operator_map()
skill_map = load_skill_map()
uniequip_map = load_uniequip_map()
cultivate_map = load_cultivate_map()
event_list = load_event_list()
zone_map = load_zone_map()
zone_matrix = load_zone_matrix()
# Out:
# 2022-07-05 01:04:03.525 | INFO     | __main__:save_zone_matrix:66 - matrix.json is successfully downloaded from https://penguin-stats.io/PenguinStats/api/v2/result/matrix?show_closed_zone=true.
# 2022-07-05 01:04:03.567 | INFO     | __main__:save_zone_matrix:71 - matrix.json and zone_matrix.json are saved.

# %%
event_list
# Out:
# {'开服': [1556676000000, None],
#  '第五章开放': [1562659200000, None],
#  '第六章开放': [1577174400000, None],
#  '第七章开放': [1588320000000, None],
#  '骑兵与猎人': [1559181600000, 1560369600000],
#  '火蓝之心': [1566892800000, 1568059200000],
#  '战地秘闻': [1571126400000, 1571688000000],
#  '喧闹法则': [1574150400000, 1575316800000],
#  '洪炉示岁': [1578513600000, 1579118400000],
#  '午间逸话': [1582617600000, 1583179200000],
#  '生于黑夜': [1587456000000, 1589486400000],
#  '第六章开放限时掉落': [1577174400000, 1578340800000],
#  '岁过华灯限时掉落': [1581105600000, 1582315200000],
#  '一周年庆典限时掉落': [1589529600000, 1590696000000],
#  '乌萨斯的孩子们': [1592467200000, 1593028800000],
#  '沃伦姆德的薄暮': [1594281600000, 1595448000000],
#  '密林悍将归来': [1598342400000, 1599508800000],
#  '踏寻往昔之风': [1600934400000, 1601496000000],
#  '骑兵与猎人・复刻': [1601539200000, 1602360000000],
#  '玛莉娅・临光': [1602748800000, 1603915200000],
#  '第八章开放': [1604217600000, None],
#  '喧闹法则・复刻': [1606809600000, 1607630400000],
#  '孤岛风云': [1608192000000, 1609358400000],
#  '此地之外': [1609833600000, 1610395200000],
#  '画中人': [1612512000000, 1613678400000],
#  '源石尘行动': [1615276800000, 1616443200000],
#  '生于黑夜・复刻': [1617091200000, 1617912000000],
#  '遗尘漫步': [1618473600000, 1619640000000],
#  '覆潮之下': [1619856000000, 1621022400000],
#  '灯火序曲': [1622534400000, 1623096000000],
#  '沃伦姆德的薄暮・复刻': [1623916800000, 1624737600000],
#  '如我所见': [1626163200000, 1626724800000],
#  '密林悍将归来・复刻': [1626768000000, 1627588800000],
#  '多索雷斯假日': [1627977600000, 1629748800000],
#  '第九章开放': [1631865600000, None],
#  '玛莉娅・临光・复刻': [1633075200000, 1633896000000],
#  '红松林': [1634284800000, 1634846400000],
#  '孤岛风云・复刻': [1638864000000, 1639684800000],
#  '画中人・复刻': [1641801600000, 1642622400000],
#  '将进酒': [1643097600000, 1644264000000],
#  '风雪过境': [1640073600000, 1641240000000],
#  '阴云火花': [1644912000000, 1645473600000],
#  '吾导先路': [1647331200000, 1648497600000],
#  '遗尘漫步・复刻': [1648540800000, 1649361600000],
#  '第十章开放': [1649923200000, None],
#  '长夜临光': [1635753600000, 1637524800000],
#  '愚人号': [1651392000000, 1653163200000],
#  '覆潮之下・复刻': [1653897600000, 1654718400000],
#  '尘影余音': [1654761600000, 1655928000000]}

# %%
# build activity_material.txt
### event_list -> stage_matrix
CURRENT_TIME = event_list["第九章开放"][0]
BLUE_MATERIAL = {"全新装置", "RMA70-12", "研磨石", "凝胶", "炽合金", "酮凝集组", "轻锰矿", "异铁组", "扭转醇",
                    "聚酸酯组", "糖组", "固源岩组", "晶体元件", "化合切削液", "半自然溶剂"}
sanity_per_day = 310

activity_record = dict()

power = 1.2
for zone, time in event_list.items():
    if zone in zone_matrix and time[0] > CURRENT_TIME:
        activity_record[zone] = {"start_date": time[0], "stage": dict()}
        if "mini" in zone_map[zone]:
            continue
        
        # sanity_list
        sanity_list = [list(v["drop_info"].values())[0]["times"] * v["sanity"]  for v in zone_matrix[zone].values() if v["drop_info"]]

        
        threshold = max(0.2 * np.mean(sanity_list),0)
        sanity_list = [t if t > threshold else 0 for t in sanity_list]
        sanity_list_ = np.array(sanity_list) ** power
        
        total = sanity_list_.sum()
        
        
        for k, v in zone_matrix[zone].items():
            if v["drop_info"]:
                sanity_cost = list(v["drop_info"].values())[0]["times"] * v["sanity"] # total snaity cost in penguin-stats
                if sanity_cost > threshold:
                    times = (sanity_cost**power / total) * (sanity_per_day * (time[1] - time[0]) / 86400000) / v["sanity"]
                    activity_record[zone]["stage"][k] = {
                        "times": times,
                        "drop": {item: times*content["quantity"]/content["times"] for item, content in v["drop_info"].items() if item in BLUE_MATERIAL},
                    }
                    
                    
## TODO: expected drop number
## todo : 用default -> 算價格 -> 每關cp值

# %%
activity_record
# Out:
# {'玛莉娅・临光・复刻': {'start_date': 1633075200000,
#   'stage': {'MN-6': {'times': 168.84756098277026,
#     'drop': {'凝胶': 84.39741528724564}},
#    'MN-7': {'times': 8.808144952567547, 'drop': {'聚酸酯组': 7.264605147779476}},
#    'MN-8': {'times': 14.09666533956834, 'drop': {'轻锰矿': 9.425001043952411}}}},
#  '红松林': {'start_date': 1634284800000, 'stage': {}},
#  '孤岛风云・复刻': {'start_date': 1638864000000,
#   'stage': {'MB-6': {'times': 7.887531341547493,
#     'drop': {'糖组': 5.40525781152862}},
#    'MB-7': {'times': 48.091954235940335, 'drop': {'酮凝集组': 32.03032358180856}},
#    'MB-8': {'times': 108.94621409054785, 'drop': {'异铁组': 71.37934106382914}}}},
#  '画中人・复刻': {'start_date': 1641801600000,
#   'stage': {'WR-8': {'times': 108.05433000788521,
#     'drop': {'炽合金': 63.321137424563716}},
#    'WR-9': {'times': 7.664305765036021, 'drop': {'聚酸酯组': 6.347003211670455}},
#    'WR-10': {'times': 65.90153033950408,
#     'drop': {'固源岩组': 61.71295298320532}}}},
#  '将进酒': {'start_date': 1643097600000,
#   'stage': {'IW-6': {'times': 137.60171007189575,
#     'drop': {'全新装置': 68.34157175460122}},
#    'IW-7': {'times': 23.698526124585264, 'drop': {'固源岩组': 26.05023696768275}},
#    'IW-8': {'times': 57.64286524236125,
#     'drop': {'RMA70-12': 33.41047909875595}}}},
#  '风雪过境': {'start_date': 1640073600000,
#   'stage': {'BI-6': {'times': 48.11898035397539,
#     'drop': {'炽合金': 27.946468719002738}},
#    'BI-7': {'times': 10.606008790211604, 'drop': {'聚酸酯组': 8.914510607721194}},
#    'BI-8': {'times': 181.7948409148089, 'drop': {'研磨石': 103.03685200618784}}}},
#  '阴云火花': {'start_date': 1644912000000, 'stage': {}},
#  '吾导先路': {'start_date': 1647331200000,
#   'stage': {'GA-4': {'times': 10.18440383782339, 'drop': {}},
#    'GA-6': {'times': 25.171029386289213, 'drop': {'糖组': 21.01474944238351}},
#    'GA-7': {'times': 40.84308073736026, 'drop': {'扭转醇': 37.60040696941436}},
#    'GA-8': {'times': 131.04780616706415, 'drop': {'凝胶': 91.44959535094182}}}},
#  '遗尘漫步・复刻': {'start_date': 1648540800000,
#   'stage': {'WD-6': {'times': 12.232346582059966,
#     'drop': {'聚酸酯组': 8.504669875420918}},
#    'WD-7': {'times': 87.70970797552081, 'drop': {'酮凝集组': 58.66567623410479}},
#    'WD-8': {'times': 65.70778098387365,
#     'drop': {'RMA70-12': 32.775349853612894}}}},
#  '长夜临光': {'start_date': 1635753600000,
#   'stage': {'NL-8': {'times': 42.03141554859225,
#     'drop': {'糖组': 34.42246474810768}},
#    'NL-9': {'times': 88.35774152821475, 'drop': {'晶体元件': 65.77251059602506}},
#    'NL-10': {'times': 222.66639847874856,
#     'drop': {'扭转醇': 174.14007981939812}}}},
#  '愚人号': {'start_date': 1651392000000,
#   'stage': {'SN-8': {'times': 115.3269754841582,
#     'drop': {'异铁组': 89.56443581546377}},
#    'SN-9': {'times': 140.49753505079553, 'drop': {'轻锰矿': 109.23641717775641}},
#    'SN-10': {'times': 46.79453708409388,
#     'drop': {'化合切削液': 32.760168270713926}}}},
#  '覆潮之下・复刻': {'start_date': 1653897600000,
#   'stage': {'SV-7': {'times': 30.28830866265281,
#     'drop': {'固源岩组': 23.645685347522797}},
#    'SV-8': {'times': 3.0172071666019322, 'drop': {'晶体元件': 2.2619285344135545}},
#    'SV-9': {'times': 135.35364672563185, 'drop': {'全新装置': 67.5701619176353}}}},
#  '尘影余音': {'start_date': 1654761600000,
#   'stage': {'LE-3': {'times': 9.615202342186064, 'drop': {}},
#    'LE-5': {'times': 21.581965413047513, 'drop': {'糖组': 17.97892911791857}},
#    'LE-6': {'times': 147.32882660545835, 'drop': {'研磨石': 99.61500339502241}},
#    'LE-7': {'times': 27.96365884496603,
#     'drop': {'半自然溶剂': 19.546742625543768}}}}}

# %%
activity_material = dict()
decay_rate_per_week = 0.95
for k, v in activity_record.items():
    week = (v["start_date"] - CURRENT_TIME) / 86400000 / 7
    ratio = decay_rate_per_week ** week
    for stage, info in v["stage"].items():
        for item, quantity in info["drop"].items():
            if item in activity_material:
                activity_material[item] += quantity*ratio
            else:
                activity_material[item] = quantity*ratio

# %%
activity_material
# Out:
# {'凝胶': 100.80309922991093,
#  '聚酸酯组': 15.800657433214022,
#  '轻锰矿': 29.35856356417162,
#  '糖组': 35.97904598428404,
#  '酮凝集组': 31.954979955433963,
#  '异铁组': 56.525076047534526,
#  '炽合金': 41.19506964398916,
#  '固源岩组': 40.269261241235704,
#  '全新装置': 36.791491085884175,
#  'RMA70-12': 20.855893260965903,
#  '研磨石': 65.6544043107,
#  '扭转醇': 135.35435511558563,
#  '晶体元件': 47.64671694617417,
#  '化合切削液': 6.253696619784936,
#  '半自然溶剂': 2.803843295869719}

# %%
0.95**2
# Out:
# 0.9025

# %%
np.array(sanity) ** power
# Out:
# 31.622776601683793

# %%
np.array(sanity)
# Out:
# 40500.0

# %%
stage_matrix["act18d3_07_rep"]
# Out:
# {'zone_name': '覆潮之下・复刻',
#  'stage_type': 'ACTIVITY',
#  'santity': 15,
#  'drop_info': {'家具': {'times': 146895, 'quantity': 2812, 'std_dev': 0.137},
#   '固源岩组': {'times': 146895, 'quantity': 114679, 'std_dev': 0.4138}}}

# %%
zone_map["长夜临光"]
# Out:
# 'act13side'

# %%
d
# Out:
# {'a': 1, 'b': 4}

# %%
URL_ZONE
# Out:
# 'https://raw.githubusercontent.com/arkntools/arknights-toolbox/master/src/locales/cn/zone.json'

# %%
URL_MATRIX_PRIVATE
# Out:
# 'https://penguin-stats.io/PenguinStats/api/v2/_private/result/matrix/CN/global'

# %%
t = [event for event in txt if event["existence"]["CN"]["exist"]]

# %%
event_list = {event["label_i18n"]["zh"]: event["start"] for event in txt if event["existence"]["CN"]["exist"]}

# %%
zone_matrix = dict()

# MATRIX
with requests.get(URL_MATRIX_PRIVATE) as response:
    txt = json.loads(response.text)
txt = txt["matrix"]

stage_id2matrix = dict()
for t in txt:
    stage_id = t["stageId"]
    item_name = item_map[t["itemId"]]
    times = t["times"]
    quantity = t["quantity"]
    std_dev = t["stdDev"]
    
    if stage_id not in stage_id2matrix: 
        stage_id2matrix[stage_id] = dict()
    stage_id2matrix[stage_id][item_name] = {"times": times, "quantity": quantity, "std_dev": std_dev}

# STAGE
with requests.get(URL_STAGE) as response:
    txt = json.loads(response.text)

for stage in txt:
    stage_id = stage["stageId"]
    stage_name = stage_map[stage_id][0]
    zone_id = stage["zoneId"].replace("_zone1", "")
    zone_name = zone_map[zone_id] if zone_id in zone_map else stage["code"].split("-")[0]
    stage_type = stage["stageType"]
    sanity = stage["apCost"]
    
    if zone_name not in zone_matrix:
        zone_matrix[zone_name] = dict()
    zone_matrix[zone_name][stage_name] = {
        "stage_type": stage_type,
        "santity": sanity,
        "drop_info": stage_id2matrix[stage_id] if stage_id in stage_id2matrix else dict()
    }



# raw data        
with open("./data/raw/matrix.json", 'w', encoding="utf-8") as fw:
    json.dump(txt, fw, indent=2, ensure_ascii=False)  
logger.info(f"matrix.json is successfully downloaded from {URL_MATRIX}.")

# zone_matrix
with open("./data/zone_matrix.json", 'w', encoding="utf-8") as fw:
    json.dump(zone_matrix, fw, indent=2, ensure_ascii=False)
logger.info(f"matrix.json and zone_matrix.json are saved.")
# Out:
# {'stageId': 'main_01-08', 'itemId': '2001', 'times': 1440, 'quantity': 1774, 'stdDev': 0.4221, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_4', 'times': 4, 'quantity': 0, 'stdDev': 0, 'start': 1604217600000, 'end': 1605384000000}
# {'stageId': 'main_01-08', 'itemId': '30061', 'times': 1440, 'quantity': 48, 'stdDev': 0.1796, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'furni', 'times': 1440, 'quantity': 16, 'stdDev': 0.1048, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': '30031', 'times': 1440, 'quantity': 90, 'stdDev': 0.2421, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': '3003', 'times': 1440, 'quantity': 135, 'stdDev': 0.2915, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_3', 'times': 51, 'quantity': 5, 'stdDev': 0.2974, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-08', 'itemId': 'ap_supply_lt_010', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-08', 'itemId': '30011', 'times': 1440, 'quantity': 174, 'stdDev': 0.326, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': '30051', 'times': 1440, 'quantity': 74, 'stdDev': 0.2209, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_1', 'times': 12, 'quantity': 0, 'stdDev': 0, 'start': 1577174400000, 'end': 1578340800000}
# {'stageId': 'main_01-08', 'itemId': '30021', 'times': 1440, 'quantity': 88, 'stdDev': 0.2395, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_2', 'times': 7, 'quantity': 0, 'stdDev': 0, 'start': 1581105600000, 'end': 1582315200000}
# {'stageId': 'main_01-08', 'itemId': '30032', 'times': 1440, 'quantity': 1269, 'stdDev': 0.3235, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_5', 'times': 7, 'quantity': 1, 'stdDev': 0.3499, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-08', 'itemId': '30041', 'times': 1440, 'quantity': 80, 'stdDev': 0.2291, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-08', 'itemId': 'randomMaterial_6', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-01', 'itemId': 'furni', 'times': 572, 'quantity': 13, 'stdDev': 0.1492, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '2001', 'times': 572, 'quantity': 635, 'stdDev': 0.6003, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '30041', 'times': 572, 'quantity': 21, 'stdDev': 0.1881, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '30011', 'times': 572, 'quantity': 32, 'stdDev': 0.2299, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '30061', 'times': 572, 'quantity': 13, 'stdDev': 0.1491, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': 'randomMaterial_2', 'times': 3, 'quantity': 0, 'stdDev': 0, 'start': 1581105600000, 'end': 1582315200000}
# {'stageId': 'main_01-01', 'itemId': 'randomMaterial_3', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-01', 'itemId': 'randomMaterial_4', 'times': 3, 'quantity': 0, 'stdDev': 0, 'start': 1604217600000, 'end': 1605384000000}
# {'stageId': 'main_01-01', 'itemId': 'randomMaterial_6', 'times': 2, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-01', 'itemId': 'ap_supply_lt_010', 'times': 2, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-01', 'itemId': '3003', 'times': 572, 'quantity': 52, 'stdDev': 0.2876, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '30021', 'times': 572, 'quantity': 23, 'stdDev': 0.1965, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': 'randomMaterial_5', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-01', 'itemId': '30051', 'times': 572, 'quantity': 20, 'stdDev': 0.1837, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-01', 'itemId': '30031', 'times': 572, 'quantity': 18, 'stdDev': 0.1746, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '30011', 'times': 579, 'quantity': 72, 'stdDev': 0.33, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '30031', 'times': 579, 'quantity': 35, 'stdDev': 0.2383, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': 'randomMaterial_3', 'times': 2, 'quantity': 0, 'stdDev': 0, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-09', 'itemId': '30021', 'times': 579, 'quantity': 31, 'stdDev': 0.2251, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '2001', 'times': 579, 'quantity': 698, 'stdDev': 0.4042, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '30051', 'times': 579, 'quantity': 18, 'stdDev': 0.1736, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '3003', 'times': 579, 'quantity': 54, 'stdDev': 0.2908, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '3112', 'times': 579, 'quantity': 1158, 'stdDev': 0, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '30061', 'times': 579, 'quantity': 23, 'stdDev': 0.1952, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': 'furni', 'times': 579, 'quantity': 8, 'stdDev': 0.1168, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-09', 'itemId': '30041', 'times': 579, 'quantity': 41, 'stdDev': 0.2565, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': '30021', 'times': 419, 'quantity': 8, 'stdDev': 0.1368, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': 'randomMaterial_5', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-06', 'itemId': 'randomMaterial_2', 'times': 3, 'quantity': 0, 'stdDev': 0, 'start': 1581105600000, 'end': 1582315200000}
# {'stageId': 'main_01-06', 'itemId': 'randomMaterial_4', 'times': 5, 'quantity': 0, 'stdDev': 0, 'start': 1604217600000, 'end': 1605384000000}
# {'stageId': 'main_01-06', 'itemId': '2001', 'times': 419, 'quantity': 540, 'stdDev': 0.4533, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': 'randomMaterial_6', 'times': 5, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-06', 'itemId': '30041', 'times': 419, 'quantity': 6, 'stdDev': 0.119, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': '30061', 'times': 419, 'quantity': 5, 'stdDev': 0.1086, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': '30031', 'times': 419, 'quantity': 1, 'stdDev': 0.0487, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': '3003', 'times': 419, 'quantity': 45, 'stdDev': 0.3095, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': 'furni', 'times': 419, 'quantity': 3, 'stdDev': 0.0843, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': '30051', 'times': 419, 'quantity': 379, 'stdDev': 0.3597, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': 'randomMaterial_1', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1577174400000, 'end': 1578340800000}
# {'stageId': 'main_01-06', 'itemId': '30011', 'times': 419, 'quantity': 11, 'stdDev': 0.1599, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-06', 'itemId': 'ap_supply_lt_010', 'times': 5, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-03', 'itemId': '30011', 'times': 318, 'quantity': 6, 'stdDev': 0.1361, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': 'furni', 'times': 318, 'quantity': 0, 'stdDev': 0, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': '30061', 'times': 318, 'quantity': 3, 'stdDev': 0.0966, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': 'randomMaterial_1', 'times': 4, 'quantity': 0, 'stdDev': 0, 'start': 1577174400000, 'end': 1578340800000}
# {'stageId': 'main_01-03', 'itemId': '30051', 'times': 318, 'quantity': 6, 'stdDev': 0.1361, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': '2001', 'times': 318, 'quantity': 390, 'stdDev': 0.4185, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': '3003', 'times': 318, 'quantity': 31, 'stdDev': 0.2966, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': 'randomMaterial_5', 'times': 3, 'quantity': 0, 'stdDev': 0, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-03', 'itemId': '30041', 'times': 318, 'quantity': 299, 'stdDev': 0.3065, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': '30031', 'times': 318, 'quantity': 8, 'stdDev': 0.1565, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-03', 'itemId': '30021', 'times': 318, 'quantity': 4, 'stdDev': 0.1115, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_4', 'times': 33460, 'quantity': 3687, 'stdDev': 0.3131, 'start': 1604217600000, 'end': 1605384000000}
# {'stageId': 'main_01-07', 'itemId': '30021', 'times': 2634777, 'quantity': 151268, 'stdDev': 0.2327, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_6', 'times': 18386, 'quantity': 1942, 'stdDev': 0.3074, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_3', 'times': 48826, 'quantity': 5398, 'stdDev': 0.3136, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-07', 'itemId': 'furni', 'times': 2634777, 'quantity': 18868, 'stdDev': 0.0841, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30012', 'times': 2634777, 'quantity': 3281488, 'stdDev': 0.4309, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30061', 'times': 2634777, 'quantity': 90203, 'stdDev': 0.1818, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30041', 'times': 2634777, 'quantity': 121582, 'stdDev': 0.2099, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30051', 'times': 2634777, 'quantity': 122209, 'stdDev': 0.2103, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '2001', 'times': 2634777, 'quantity': 3263787, 'stdDev': 0.4278, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30031', 'times': 2634777, 'quantity': 153012, 'stdDev': 0.2338, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_5', 'times': 26158, 'quantity': 2612, 'stdDev': 0.2998, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-07', 'itemId': '3003', 'times': 2634777, 'quantity': 230611, 'stdDev': 0.2826, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': '30011', 'times': 2634777, 'quantity': 309815, 'stdDev': 0.322, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-07', 'itemId': 'ap_supply_lt_010', 'times': 18386, 'quantity': 1749, 'stdDev': 0.2934, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_1', 'times': 29655, 'quantity': 3619, 'stdDev': 0.3275, 'start': 1577174400000, 'end': 1578340800000}
# {'stageId': 'main_01-07', 'itemId': 'randomMaterial_2', 'times': 17265, 'quantity': 2051, 'stdDev': 0.3235, 'start': 1581105600000, 'end': 1582315200000}
# {'stageId': 'main_01-04', 'itemId': '2001', 'times': 282, 'quantity': 340, 'stdDev': 0.4042, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': '30021', 'times': 282, 'quantity': 4, 'stdDev': 0.1183, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': 'furni', 'times': 282, 'quantity': 36, 'stdDev': 0.3336, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': 'randomMaterial_3', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-04', 'itemId': 'randomMaterial_1', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1577174400000, 'end': 1578340800000}
# {'stageId': 'main_01-04', 'itemId': '30041', 'times': 282, 'quantity': 7, 'stdDev': 0.1556, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': '30051', 'times': 282, 'quantity': 7, 'stdDev': 0.1556, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': 'randomMaterial_4', 'times': 9, 'quantity': 1, 'stdDev': 0.3143, 'start': 1604217600000, 'end': 1605384000000}
# {'stageId': 'main_01-04', 'itemId': '30011', 'times': 282, 'quantity': 4, 'stdDev': 0.1182, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': '30031', 'times': 282, 'quantity': 5, 'stdDev': 0.132, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': '30061', 'times': 282, 'quantity': 2, 'stdDev': 0.0839, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-04', 'itemId': '3003', 'times': 282, 'quantity': 18, 'stdDev': 0.2444, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': 'randomMaterial_5', 'times': 1, 'quantity': 0, 'stdDev': 0, 'start': 1631865600000, 'end': 1633032000000}
# {'stageId': 'main_01-05', 'itemId': '3003', 'times': 398, 'quantity': 40, 'stdDev': 0.3007, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': 'ap_supply_lt_010', 'times': 8, 'quantity': 0, 'stdDev': 0, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-05', 'itemId': '30051', 'times': 398, 'quantity': 8, 'stdDev': 0.1404, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': 'furni', 'times': 398, 'quantity': 5, 'stdDev': 0.1114, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': '30031', 'times': 398, 'quantity': 4, 'stdDev': 0.0998, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': 'randomMaterial_3', 'times': 4, 'quantity': 1, 'stdDev': 0.433, 'start': 1589529600000, 'end': 1590696000000}
# {'stageId': 'main_01-05', 'itemId': '30021', 'times': 398, 'quantity': 1, 'stdDev': 0.0501, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': '2001', 'times': 398, 'quantity': 497, 'stdDev': 0.4323, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': 'randomMaterial_6', 'times': 8, 'quantity': 1, 'stdDev': 0.3307, 'start': 1649923200000, 'end': 1651089600000}
# {'stageId': 'main_01-05', 'itemId': '30041', 'times': 398, 'quantity': 7, 'stdDev': 0.1314, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': '30061', 'times': 398, 'quantity': 277, 'stdDev': 0.4708, 'start': 1556676000000, 'end': 1656867152482}
# {'stageId': 'main_01-05', 'itemId': '30011', 'times': 398, 'quantity': 16, 'stdDev': 0.1964, 'start': 1556676000000, 'end': 1656867152482}
# 2022-07-04 01:07:06.458 | INFO     | __main__:<cell line: 47>:47 - matrix.json is successfully downloaded from https://penguin-stats.io/PenguinStats/api/v2/result/matrix?show_closed_zone=true.
# 2022-07-04 01:07:06.500 | INFO     | __main__:<cell line: 52>:52 - matrix.json and zone_matrix.json are saved.

# %%
zone_matrix
# Out:
# {'序章': {'0-1': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'基础作战记录': {'times': 548, 'quantity': 2230, 'std_dev': 0.701},
#     '罗德岛物资补给III': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '应急理智小样': {'times': 3, 'quantity': 1, 'std_dev': 0.4714},
#     '32h战略配给': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 548, 'quantity': 7, 'std_dev': 0.1122},
#     '赤金': {'times': 548, 'quantity': 78, 'std_dev': 0.3493},
#     '酯原料': {'times': 548, 'quantity': 16, 'std_dev': 0.1683},
#     '源岩': {'times': 548, 'quantity': 38, 'std_dev': 0.254},
#     '罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 548, 'quantity': 15, 'std_dev': 0.1632},
#     '异铁碎片': {'times': 548, 'quantity': 3, 'std_dev': 0.0738},
#     '代糖': {'times': 548, 'quantity': 17, 'std_dev': 0.1733},
#     '家具': {'times': 548, 'quantity': 10, 'std_dev': 0.1338}}},
#   '0-2': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'双酮': {'times': 100, 'quantity': 2, 'std_dev': 0.14},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 100, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 100, 'quantity': 3, 'std_dev': 0.1705},
#     '基础作战记录': {'times': 100, 'quantity': 416, 'std_dev': 0.6592},
#     '酯原料': {'times': 100, 'quantity': 2, 'std_dev': 0.1399},
#     '赤金': {'times': 100, 'quantity': 16, 'std_dev': 0.3665},
#     '异铁碎片': {'times': 100, 'quantity': 1, 'std_dev': 0.0995},
#     '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 100, 'quantity': 3, 'std_dev': 0.1706},
#     '破损装置': {'times': 100, 'quantity': 1, 'std_dev': 0.0995}}},
#   '0-3': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'源岩': {'times': 130, 'quantity': 2, 'std_dev': 0.1231},
#     '破损装置': {'times': 130, 'quantity': 3, 'std_dev': 0.1501},
#     '代糖': {'times': 130, 'quantity': 2, 'std_dev': 0.1231},
#     '赤金': {'times': 130, 'quantity': 12, 'std_dev': 0.2894},
#     '岁过华灯': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 130, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 130, 'quantity': 2, 'std_dev': 0.1231},
#     '酯原料': {'times': 130, 'quantity': 3, 'std_dev': 0.1502},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 130, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 21, 'quantity': 2, 'std_dev': 0.2935},
#     '基础作战记录': {'times': 130, 'quantity': 559, 'std_dev': 0.6032}}},
#   '0-4': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'家具': {'times': 57, 'quantity': 1, 'std_dev': 0.1313},
#     '源岩': {'times': 57, 'quantity': 1, 'std_dev': 0.1313},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 57, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 57, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 57, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '基础作战记录': {'times': 57, 'quantity': 224, 'std_dev': 0.7459},
#     '赤金': {'times': 57, 'quantity': 4, 'std_dev': 0.2554},
#     '异铁碎片': {'times': 57, 'quantity': 1, 'std_dev': 0.1313},
#     '代糖': {'times': 57, 'quantity': 1, 'std_dev': 0.1313}}},
#   '0-5': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'赤金': {'times': 51, 'quantity': 2, 'std_dev': 0.1941},
#     '基础作战记录': {'times': 51, 'quantity': 205, 'std_dev': 0.6414},
#     '代糖': {'times': 51, 'quantity': 2, 'std_dev': 0.1942},
#     '酯原料': {'times': 51, 'quantity': 2, 'std_dev': 0.1941},
#     '源岩': {'times': 51, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 51, 'quantity': 1, 'std_dev': 0.1387},
#     '双酮': {'times': 51, 'quantity': 2, 'std_dev': 0.1941},
#     '破损装置': {'times': 51, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 51, 'quantity': 0, 'std_dev': 0}}},
#   '0-6': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'酯原料': {'times': 145, 'quantity': 2, 'std_dev': 0.1166},
#     '代糖': {'times': 145, 'quantity': 3, 'std_dev': 0.1423},
#     '破损装置': {'times': 145, 'quantity': 4, 'std_dev': 0.1638},
#     '基础作战记录': {'times': 145, 'quantity': 610, 'std_dev': 0.6422},
#     '异铁碎片': {'times': 145, 'quantity': 2, 'std_dev': 0.1167},
#     '双酮': {'times': 145, 'quantity': 0, 'std_dev': 0},
#     '赤金': {'times': 145, 'quantity': 11, 'std_dev': 0.2647},
#     '家具': {'times': 145, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 145, 'quantity': 4, 'std_dev': 0.1638}}},
#   '0-7': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'代糖': {'times': 437, 'quantity': 489, 'std_dev': 0.3309},
#     '家具': {'times': 437, 'quantity': 2, 'std_dev': 0.0676},
#     '异铁碎片': {'times': 437, 'quantity': 5, 'std_dev': 0.1064},
#     '双酮': {'times': 437, 'quantity': 7, 'std_dev': 0.1255},
#     '岁过华灯': {'times': 12, 'quantity': 2, 'std_dev': 0.3727},
#     '罗德岛物资补给': {'times': 6, 'quantity': 1, 'std_dev': 0.3727},
#     '基础作战记录': {'times': 437, 'quantity': 547, 'std_dev': 0.4341},
#     '赤金': {'times': 437, 'quantity': 34, 'std_dev': 0.2679},
#     '32h战略配给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 437, 'quantity': 3, 'std_dev': 0.0826},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 437, 'quantity': 16, 'std_dev': 0.1878},
#     '酯原料': {'times': 437, 'quantity': 9, 'std_dev': 0.142}}},
#   '0-8': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'破损装置': {'times': 75, 'quantity': 1, 'std_dev': 0.1148},
#     '异铁碎片': {'times': 75, 'quantity': 1, 'std_dev': 0.1148},
#     '双酮': {'times': 75, 'quantity': 1, 'std_dev': 0.1148},
#     '赤金': {'times': 75, 'quantity': 10, 'std_dev': 0.3399},
#     '代糖': {'times': 75, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 75, 'quantity': 1, 'std_dev': 0.1148},
#     '家具': {'times': 75, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 75, 'quantity': 1, 'std_dev': 0.1148},
#     '基础作战记录': {'times': 75, 'quantity': 314, 'std_dev': 0.5339},
#     '岁过华灯': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0}}},
#   '0-9': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'破损装置': {'times': 264, 'quantity': 3, 'std_dev': 0.106},
#     '罗德岛物资补给II': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 264, 'quantity': 2, 'std_dev': 0.0867},
#     '赤金': {'times': 264, 'quantity': 28, 'std_dev': 0.3079},
#     '应急理智小样': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给': {'times': 18, 'quantity': 2, 'std_dev': 0.3143},
#     '罗德岛物资补给III': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 264, 'quantity': 8, 'std_dev': 0.1715},
#     '异铁碎片': {'times': 264, 'quantity': 3, 'std_dev': 0.106},
#     '双酮': {'times': 264, 'quantity': 4, 'std_dev': 0.1222},
#     '基础作战记录': {'times': 264, 'quantity': 327, 'std_dev': 0.4262},
#     '源岩': {'times': 264, 'quantity': 435, 'std_dev': 0.4932},
#     '家具': {'times': 264, 'quantity': 0, 'std_dev': 0},
#     '岁过华灯': {'times': 2, 'quantity': 0, 'std_dev': 0}}},
#   '0-10': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'代糖': {'times': 55, 'quantity': 2, 'std_dev': 0.1872},
#     '异铁碎片': {'times': 55, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 55, 'quantity': 1, 'std_dev': 0.1337},
#     '双酮': {'times': 55, 'quantity': 1, 'std_dev': 0.1337},
#     '酯原料': {'times': 55, 'quantity': 2, 'std_dev': 0.1872},
#     '基础作战记录': {'times': 55, 'quantity': 239, 'std_dev': 0.579},
#     '破损装置': {'times': 55, 'quantity': 1, 'std_dev': 0.1337},
#     '家具': {'times': 55, 'quantity': 1, 'std_dev': 0.1337},
#     '赤金': {'times': 55, 'quantity': 5, 'std_dev': 0.2875}}},
#   '0-11': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'家具': {'times': 243, 'quantity': 5, 'std_dev': 0.142},
#     '源岩': {'times': 243, 'quantity': 9, 'std_dev': 0.1889},
#     '基础作战记录': {'times': 243, 'quantity': 294, 'std_dev': 0.4072},
#     '岁过华灯': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 243, 'quantity': 3, 'std_dev': 0.1104},
#     '双酮': {'times': 243, 'quantity': 2, 'std_dev': 0.0903},
#     '32h战略配给': {'times': 7, 'quantity': 3, 'std_dev': 0.4949},
#     '酯原料': {'times': 243, 'quantity': 278, 'std_dev': 0.3513},
#     '破损装置': {'times': 243, 'quantity': 3, 'std_dev': 0.1105},
#     '代糖': {'times': 243, 'quantity': 4, 'std_dev': 0.1273},
#     '赤金': {'times': 243, 'quantity': 27, 'std_dev': 0.3142}}}},
#  '第一章': {'1-1': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'家具': {'times': 572, 'quantity': 13, 'std_dev': 0.1492},
#     '基础作战记录': {'times': 572, 'quantity': 635, 'std_dev': 0.6003},
#     '异铁碎片': {'times': 572, 'quantity': 21, 'std_dev': 0.1881},
#     '源岩': {'times': 572, 'quantity': 32, 'std_dev': 0.2299},
#     '破损装置': {'times': 572, 'quantity': 13, 'std_dev': 0.1491},
#     '岁过华灯': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '32h战略配给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '赤金': {'times': 572, 'quantity': 52, 'std_dev': 0.2876},
#     '代糖': {'times': 572, 'quantity': 23, 'std_dev': 0.1965},
#     '罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 572, 'quantity': 20, 'std_dev': 0.1837},
#     '酯原料': {'times': 572, 'quantity': 18, 'std_dev': 0.1746}}},
#   '1-2': {'stage_type': 'MAIN', 'santity': 0, 'drop_info': {}},
#   '1-3': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'源岩': {'times': 318, 'quantity': 6, 'std_dev': 0.1361},
#     '家具': {'times': 318, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 318, 'quantity': 3, 'std_dev': 0.0966},
#     '罗德岛物资补给': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 318, 'quantity': 6, 'std_dev': 0.1361},
#     '基础作战记录': {'times': 318, 'quantity': 390, 'std_dev': 0.4185},
#     '赤金': {'times': 318, 'quantity': 31, 'std_dev': 0.2966},
#     '罗德岛物资补给II': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 318, 'quantity': 299, 'std_dev': 0.3065},
#     '酯原料': {'times': 318, 'quantity': 8, 'std_dev': 0.1565},
#     '代糖': {'times': 318, 'quantity': 4, 'std_dev': 0.1115}}},
#   '1-4': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'基础作战记录': {'times': 282, 'quantity': 340, 'std_dev': 0.4042},
#     '代糖': {'times': 282, 'quantity': 4, 'std_dev': 0.1183},
#     '家具': {'times': 282, 'quantity': 36, 'std_dev': 0.3336},
#     '32h战略配给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 282, 'quantity': 7, 'std_dev': 0.1556},
#     '双酮': {'times': 282, 'quantity': 7, 'std_dev': 0.1556},
#     '感谢庆典物资补给': {'times': 9, 'quantity': 1, 'std_dev': 0.3143},
#     '源岩': {'times': 282, 'quantity': 4, 'std_dev': 0.1182},
#     '酯原料': {'times': 282, 'quantity': 5, 'std_dev': 0.132},
#     '破损装置': {'times': 282, 'quantity': 2, 'std_dev': 0.0839},
#     '赤金': {'times': 282, 'quantity': 18, 'std_dev': 0.2444}}},
#   '1-5': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '赤金': {'times': 398, 'quantity': 40, 'std_dev': 0.3007},
#     '应急理智小样': {'times': 8, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 398, 'quantity': 8, 'std_dev': 0.1404},
#     '家具': {'times': 398, 'quantity': 5, 'std_dev': 0.1114},
#     '酯原料': {'times': 398, 'quantity': 4, 'std_dev': 0.0998},
#     '32h战略配给': {'times': 4, 'quantity': 1, 'std_dev': 0.433},
#     '代糖': {'times': 398, 'quantity': 1, 'std_dev': 0.0501},
#     '基础作战记录': {'times': 398, 'quantity': 497, 'std_dev': 0.4323},
#     '罗德岛物资补给III': {'times': 8, 'quantity': 1, 'std_dev': 0.3307},
#     '异铁碎片': {'times': 398, 'quantity': 7, 'std_dev': 0.1314},
#     '破损装置': {'times': 398, 'quantity': 277, 'std_dev': 0.4708},
#     '源岩': {'times': 398, 'quantity': 16, 'std_dev': 0.1964}}},
#   '1-6': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'代糖': {'times': 419, 'quantity': 8, 'std_dev': 0.1368},
#     '罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '岁过华灯': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 5, 'quantity': 0, 'std_dev': 0},
#     '基础作战记录': {'times': 419, 'quantity': 540, 'std_dev': 0.4533},
#     '罗德岛物资补给III': {'times': 5, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 419, 'quantity': 6, 'std_dev': 0.119},
#     '破损装置': {'times': 419, 'quantity': 5, 'std_dev': 0.1086},
#     '酯原料': {'times': 419, 'quantity': 1, 'std_dev': 0.0487},
#     '赤金': {'times': 419, 'quantity': 45, 'std_dev': 0.3095},
#     '家具': {'times': 419, 'quantity': 3, 'std_dev': 0.0843},
#     '双酮': {'times': 419, 'quantity': 379, 'std_dev': 0.3597},
#     '罗德岛物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 419, 'quantity': 11, 'std_dev': 0.1599},
#     '应急理智小样': {'times': 5, 'quantity': 0, 'std_dev': 0}}},
#   '1-7': {'stage_type': 'MAIN',
#    'santity': 6,
#    'drop_info': {'感谢庆典物资补给': {'times': 33460,
#      'quantity': 3687,
#      'std_dev': 0.3131},
#     '代糖': {'times': 2634777, 'quantity': 151268, 'std_dev': 0.2327},
#     '罗德岛物资补给III': {'times': 18386, 'quantity': 1942, 'std_dev': 0.3074},
#     '32h战略配给': {'times': 48826, 'quantity': 5398, 'std_dev': 0.3136},
#     '家具': {'times': 2634777, 'quantity': 18868, 'std_dev': 0.0841},
#     '固源岩': {'times': 2634777, 'quantity': 3281488, 'std_dev': 0.4309},
#     '破损装置': {'times': 2634777, 'quantity': 90203, 'std_dev': 0.1818},
#     '异铁碎片': {'times': 2634777, 'quantity': 121582, 'std_dev': 0.2099},
#     '双酮': {'times': 2634777, 'quantity': 122209, 'std_dev': 0.2103},
#     '基础作战记录': {'times': 2634777, 'quantity': 3263787, 'std_dev': 0.4278},
#     '酯原料': {'times': 2634777, 'quantity': 153012, 'std_dev': 0.2338},
#     '罗德岛物资补给II': {'times': 26158, 'quantity': 2612, 'std_dev': 0.2998},
#     '赤金': {'times': 2634777, 'quantity': 230611, 'std_dev': 0.2826},
#     '源岩': {'times': 2634777, 'quantity': 309815, 'std_dev': 0.322},
#     '应急理智小样': {'times': 18386, 'quantity': 1749, 'std_dev': 0.2934},
#     '罗德岛物资补给': {'times': 29655, 'quantity': 3619, 'std_dev': 0.3275},
#     '岁过华灯': {'times': 17265, 'quantity': 2051, 'std_dev': 0.3235}}},
#   '1-8': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'基础作战记录': {'times': 1440,
#      'quantity': 1774,
#      'std_dev': 0.4221},
#     '感谢庆典物资补给': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 1440, 'quantity': 48, 'std_dev': 0.1796},
#     '家具': {'times': 1440, 'quantity': 16, 'std_dev': 0.1048},
#     '酯原料': {'times': 1440, 'quantity': 90, 'std_dev': 0.2421},
#     '赤金': {'times': 1440, 'quantity': 135, 'std_dev': 0.2915},
#     '32h战略配给': {'times': 51, 'quantity': 5, 'std_dev': 0.2974},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 1440, 'quantity': 174, 'std_dev': 0.326},
#     '双酮': {'times': 1440, 'quantity': 74, 'std_dev': 0.2209},
#     '罗德岛物资补给': {'times': 12, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 1440, 'quantity': 88, 'std_dev': 0.2395},
#     '岁过华灯': {'times': 7, 'quantity': 0, 'std_dev': 0},
#     '聚酸酯': {'times': 1440, 'quantity': 1269, 'std_dev': 0.3235},
#     '罗德岛物资补给II': {'times': 7, 'quantity': 1, 'std_dev': 0.3499},
#     '异铁碎片': {'times': 1440, 'quantity': 80, 'std_dev': 0.2291},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0}}},
#   '1-9': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'源岩': {'times': 579, 'quantity': 72, 'std_dev': 0.33},
#     '酯原料': {'times': 579, 'quantity': 35, 'std_dev': 0.2383},
#     '32h战略配给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 579, 'quantity': 31, 'std_dev': 0.2251},
#     '基础作战记录': {'times': 579, 'quantity': 698, 'std_dev': 0.4042},
#     '双酮': {'times': 579, 'quantity': 18, 'std_dev': 0.1736},
#     '赤金': {'times': 579, 'quantity': 54, 'std_dev': 0.2908},
#     '碳': {'times': 579, 'quantity': 1158, 'std_dev': 0},
#     '破损装置': {'times': 579, 'quantity': 23, 'std_dev': 0.1952},
#     '家具': {'times': 579, 'quantity': 8, 'std_dev': 0.1168},
#     '异铁碎片': {'times': 579, 'quantity': 41, 'std_dev': 0.2565}}},
#   '1-10': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'异铁碎片': {'times': 202, 'quantity': 10, 'std_dev': 0.2169},
#     '基础作战记录': {'times': 202, 'quantity': 248, 'std_dev': 0.4194},
#     '应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 202, 'quantity': 8, 'std_dev': 0.1949},
#     '代糖': {'times': 202, 'quantity': 10, 'std_dev': 0.217},
#     '家具': {'times': 202, 'quantity': 1, 'std_dev': 0.0701},
#     '罗德岛物资补给': {'times': 14, 'quantity': 1, 'std_dev': 0.2575},
#     '酯原料': {'times': 202, 'quantity': 21, 'std_dev': 0.3052},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 1, 'std_dev': 0.5},
#     '赤金': {'times': 202, 'quantity': 18, 'std_dev': 0.2849},
#     '技巧概要·卷1': {'times': 202, 'quantity': 404, 'std_dev': 0},
#     '源岩': {'times': 202, 'quantity': 28, 'std_dev': 0.3455},
#     '32h战略配给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 202, 'quantity': 15, 'std_dev': 0.2622}}},
#   '1-11': {'stage_type': 'MAIN', 'santity': 0, 'drop_info': {}},
#   '1-12': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'家具': {'times': 4294, 'quantity': 44, 'std_dev': 0.1008},
#     '罗德岛物资补给': {'times': 90, 'quantity': 10, 'std_dev': 0.3143},
#     '32h战略配给': {'times': 72, 'quantity': 7, 'std_dev': 0.2963},
#     '源岩': {'times': 4294, 'quantity': 552, 'std_dev': 0.3347},
#     '罗德岛物资补给III': {'times': 6, 'quantity': 1, 'std_dev': 0.3727},
#     '装置': {'times': 4294, 'quantity': 2187, 'std_dev': 0.5},
#     '异铁碎片': {'times': 4294, 'quantity': 202, 'std_dev': 0.2117},
#     '应急理智小样': {'times': 6, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给II': {'times': 7, 'quantity': 2, 'std_dev': 0.4518},
#     '破损装置': {'times': 4294, 'quantity': 184, 'std_dev': 0.2025},
#     '代糖': {'times': 4294, 'quantity': 268, 'std_dev': 0.2418},
#     '酯原料': {'times': 4294, 'quantity': 282, 'std_dev': 0.2478},
#     '岁过华灯': {'times': 81, 'quantity': 9, 'std_dev': 0.3143},
#     '感谢庆典物资补给': {'times': 95, 'quantity': 11, 'std_dev': 0.32},
#     '基础作战记录': {'times': 4294, 'quantity': 5208, 'std_dev': 0.4093},
#     '双酮': {'times': 4294, 'quantity': 241, 'std_dev': 0.2303},
#     '赤金': {'times': 4294, 'quantity': 471, 'std_dev': 0.3125}}}},
#  '第二章': {'2-1': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'应急理智小样': {'times': 5, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 13, 'quantity': 1, 'std_dev': 0.2665},
#     '赤金': {'times': 1168, 'quantity': 102, 'std_dev': 0.2823},
#     '32h战略配给': {'times': 22, 'quantity': 1, 'std_dev': 0.2083},
#     '罗德岛物资补给II': {'times': 7, 'quantity': 1, 'std_dev': 0.3499},
#     '双酮': {'times': 1168, 'quantity': 60, 'std_dev': 0.2208},
#     '罗德岛物资补给III': {'times': 5, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 1168, 'quantity': 56, 'std_dev': 0.2137},
#     '基础作战记录': {'times': 1168, 'quantity': 1451, 'std_dev': 0.4285},
#     '异铁': {'times': 1168, 'quantity': 762, 'std_dev': 0.4762},
#     '破损装置': {'times': 1168, 'quantity': 46, 'std_dev': 0.1945},
#     '罗德岛物资补给': {'times': 21, 'quantity': 0, 'std_dev': 0},
#     '岁过华灯': {'times': 20, 'quantity': 2, 'std_dev': 0.3},
#     '代糖': {'times': 1168, 'quantity': 66, 'std_dev': 0.2309},
#     '家具': {'times': 1168, 'quantity': 23, 'std_dev': 0.1389},
#     '源岩': {'times': 1168, 'quantity': 152, 'std_dev': 0.3364},
#     '酯原料': {'times': 1168, 'quantity': 92, 'std_dev': 0.2694}}},
#   '2-2': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'糖': {'times': 1036, 'quantity': 846, 'std_dev': 0.3871},
#     '源岩': {'times': 1036, 'quantity': 120, 'std_dev': 0.32},
#     '双酮': {'times': 1036, 'quantity': 52, 'std_dev': 0.2183},
#     '罗德岛物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给II': {'times': 4, 'quantity': 1, 'std_dev': 0.433},
#     '代糖': {'times': 1036, 'quantity': 75, 'std_dev': 0.2591},
#     '基础作战记录': {'times': 1036, 'quantity': 1293, 'std_dev': 0.4319},
#     '岁过华灯': {'times': 19, 'quantity': 3, 'std_dev': 0.3646},
#     '破损装置': {'times': 1036, 'quantity': 37, 'std_dev': 0.1857},
#     '家具': {'times': 1036, 'quantity': 13, 'std_dev': 0.1113},
#     '32h战略配给': {'times': 12, 'quantity': 0, 'std_dev': 0},
#     '感谢庆典物资补给': {'times': 15, 'quantity': 3, 'std_dev': 0.4},
#     '异铁碎片': {'times': 1036, 'quantity': 67, 'std_dev': 0.2459},
#     '赤金': {'times': 1036, 'quantity': 107, 'std_dev': 0.3043},
#     '酯原料': {'times': 1036, 'quantity': 69, 'std_dev': 0.2493}}},
#   '2-3': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'罗德岛物资补给III': {'times': 11, 'quantity': 1, 'std_dev': 0.2875},
#     '赤金': {'times': 951, 'quantity': 93, 'std_dev': 0.2969},
#     '酯原料': {'times': 951, 'quantity': 228, 'std_dev': 0.4269},
#     '岁过华灯': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '32h战略配给': {'times': 27, 'quantity': 2, 'std_dev': 0.2619},
#     '源岩': {'times': 951, 'quantity': 378, 'std_dev': 0.4894},
#     '感谢庆典物资补给': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '聚酸酯': {'times': 951, 'quantity': 13, 'std_dev': 0.1162},
#     '应急理智小样': {'times': 11, 'quantity': 2, 'std_dev': 0.3857},
#     '装置': {'times': 951, 'quantity': 16, 'std_dev': 0.1285},
#     '家具': {'times': 951, 'quantity': 16, 'std_dev': 0.1286},
#     '罗德岛物资补给': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '固源岩': {'times': 951, 'quantity': 27, 'std_dev': 0.1662},
#     '基础作战记录': {'times': 951, 'quantity': 1176, 'std_dev': 0.425},
#     '破损装置': {'times': 951, 'quantity': 1387, 'std_dev': 0.5729}}},
#   '2-4': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'岁过华灯': {'times': 111, 'quantity': 18, 'std_dev': 0.3686},
#     '基础作战记录': {'times': 9336, 'quantity': 11544, 'std_dev': 0.4249},
#     '罗德岛物资补给': {'times': 215, 'quantity': 35, 'std_dev': 0.3692},
#     '家具': {'times': 9336, 'quantity': 136, 'std_dev': 0.1198},
#     '罗德岛物资补给II': {'times': 17, 'quantity': 2, 'std_dev': 0.3222},
#     '聚酸酯': {'times': 9336, 'quantity': 151, 'std_dev': 0.1261},
#     '酯原料': {'times': 9336, 'quantity': 2573, 'std_dev': 0.4468},
#     '32h战略配给': {'times': 53, 'quantity': 7, 'std_dev': 0.3386},
#     '破损装置': {'times': 9336, 'quantity': 1475, 'std_dev': 0.3647},
#     '源岩': {'times': 9336, 'quantity': 3809, 'std_dev': 0.4915},
#     '固源岩组': {'times': 9336, 'quantity': 3932, 'std_dev': 0.4938},
#     '应急理智小样': {'times': 85, 'quantity': 9, 'std_dev': 0.3077},
#     '装置': {'times': 9336, 'quantity': 124, 'std_dev': 0.1145},
#     '固源岩': {'times': 9336, 'quantity': 263, 'std_dev': 0.1654},
#     '罗德岛物资补给III': {'times': 85, 'quantity': 9, 'std_dev': 0.3077},
#     '赤金': {'times': 9336, 'quantity': 851, 'std_dev': 0.2878},
#     '感谢庆典物资补给': {'times': 129, 'quantity': 12, 'std_dev': 0.2905}}},
#   '2-5': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'糖组': {'times': 16743, 'quantity': 6155, 'std_dev': 0.4822},
#     '罗德岛物资补给': {'times': 155, 'quantity': 24, 'std_dev': 0.3618},
#     '32h战略配给': {'times': 477, 'quantity': 63, 'std_dev': 0.3386},
#     '罗德岛物资补给II': {'times': 82, 'quantity': 13, 'std_dev': 0.3652},
#     '异铁碎片': {'times': 16743, 'quantity': 3434, 'std_dev': 0.4038},
#     '双酮': {'times': 16743, 'quantity': 3400, 'std_dev': 0.4022},
#     '基础作战记录': {'times': 16743, 'quantity': 24471, 'std_dev': 0.5981},
#     '应急理智小样': {'times': 37, 'quantity': 3, 'std_dev': 0.273},
#     '糖': {'times': 16743, 'quantity': 376, 'std_dev': 0.1482},
#     '岁过华灯': {'times': 289, 'quantity': 37, 'std_dev': 0.3341},
#     '感谢庆典物资补给': {'times': 220, 'quantity': 25, 'std_dev': 0.3174},
#     '代糖': {'times': 16743, 'quantity': 4258, 'std_dev': 0.4354},
#     '酮凝集': {'times': 16743, 'quantity': 293, 'std_dev': 0.1311},
#     '异铁': {'times': 16743, 'quantity': 254, 'std_dev': 0.1222},
#     '初级作战记录': {'times': 16743, 'quantity': 851, 'std_dev': 0.2196},
#     '家具': {'times': 16743, 'quantity': 234, 'std_dev': 0.1174},
#     '罗德岛物资补给III': {'times': 37, 'quantity': 4, 'std_dev': 0.3105}}},
#   '2-6': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'岁过华灯': {'times': 183, 'quantity': 36, 'std_dev': 0.3975},
#     '家具': {'times': 9239, 'quantity': 136, 'std_dev': 0.1204},
#     '聚酸酯': {'times': 9239, 'quantity': 184, 'std_dev': 0.1397},
#     '罗德岛物资补给': {'times': 32, 'quantity': 9, 'std_dev': 0.4496},
#     '感谢庆典物资补给': {'times': 16, 'quantity': 0, 'std_dev': 0},
#     '赤金': {'times': 9239, 'quantity': 922, 'std_dev': 0.2997},
#     '32h战略配给': {'times': 424, 'quantity': 57, 'std_dev': 0.3411},
#     '聚酸酯组': {'times': 9239, 'quantity': 3366, 'std_dev': 0.4812},
#     '罗德岛物资补给II': {'times': 13, 'quantity': 1, 'std_dev': 0.2665},
#     '破损装置': {'times': 9239, 'quantity': 1445, 'std_dev': 0.3632},
#     '固源岩': {'times': 9239, 'quantity': 246, 'std_dev': 0.161},
#     '源岩': {'times': 9239, 'quantity': 3787, 'std_dev': 0.4918},
#     '装置': {'times': 9239, 'quantity': 126, 'std_dev': 0.1159},
#     '酯原料': {'times': 9239, 'quantity': 2456, 'std_dev': 0.4418},
#     '基础作战记录': {'times': 9239, 'quantity': 11494, 'std_dev': 0.4296}}},
#   '2-7': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'感谢庆典物资补给': {'times': 2, 'quantity': 1, 'std_dev': 0.5},
#     '基础作战记录': {'times': 187, 'quantity': 267, 'std_dev': 0.5653},
#     '异铁碎片': {'times': 187, 'quantity': 39, 'std_dev': 0.4063},
#     '糖': {'times': 187, 'quantity': 2, 'std_dev': 0.1029},
#     '初级作战记录': {'times': 187, 'quantity': 10, 'std_dev': 0.225},
#     '家具': {'times': 187, 'quantity': 7, 'std_dev': 0.1898},
#     '异铁': {'times': 187, 'quantity': 4, 'std_dev': 0.1448},
#     '岁过华灯': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 187, 'quantity': 39, 'std_dev': 0.4062},
#     '酮凝集': {'times': 187, 'quantity': 7, 'std_dev': 0.1899},
#     '代糖': {'times': 187, 'quantity': 54, 'std_dev': 0.4531}}},
#   '2-8': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'酮凝集': {'times': 5717, 'quantity': 98, 'std_dev': 0.1298},
#     '32h战略配给': {'times': 22, 'quantity': 6, 'std_dev': 0.4454},
#     '异铁': {'times': 5717, 'quantity': 106, 'std_dev': 0.1349},
#     '初级作战记录': {'times': 5717, 'quantity': 308, 'std_dev': 0.2257},
#     '感谢庆典物资补给': {'times': 25, 'quantity': 3, 'std_dev': 0.325},
#     '家具': {'times': 5717, 'quantity': 90, 'std_dev': 0.1245},
#     '罗德岛物资补给': {'times': 241, 'quantity': 39, 'std_dev': 0.3683},
#     '罗德岛物资补给II': {'times': 7, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 5717, 'quantity': 1429, 'std_dev': 0.433},
#     '基础作战记录': {'times': 5717, 'quantity': 8265, 'std_dev': 0.5787},
#     '罗德岛物资补给III': {'times': 127, 'quantity': 18, 'std_dev': 0.3488},
#     '异铁碎片': {'times': 5717, 'quantity': 1198, 'std_dev': 0.407},
#     '糖': {'times': 5717, 'quantity': 106, 'std_dev': 0.1349},
#     '应急理智小样': {'times': 127, 'quantity': 13, 'std_dev': 0.3031},
#     '异铁组': {'times': 5717, 'quantity': 1277, 'std_dev': 0.4166},
#     '岁过华灯': {'times': 170, 'quantity': 26, 'std_dev': 0.3599},
#     '双酮': {'times': 5717, 'quantity': 1247, 'std_dev': 0.4131}}},
#   '2-9': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'罗德岛物资补给': {'times': 98, 'quantity': 13, 'std_dev': 0.3392},
#     '32h战略配给': {'times': 21, 'quantity': 3, 'std_dev': 0.3499},
#     '源岩': {'times': 6755, 'quantity': 2853, 'std_dev': 0.4939},
#     '固源岩': {'times': 6755, 'quantity': 192, 'std_dev': 0.1663},
#     '破损装置': {'times': 6755, 'quantity': 1066, 'std_dev': 0.3646},
#     '应急理智小样': {'times': 15, 'quantity': 5, 'std_dev': 0.4714},
#     '扭转醇': {'times': 6755, 'quantity': 1771, 'std_dev': 0.4398},
#     '罗德岛物资补给III': {'times': 15, 'quantity': 0, 'std_dev': 0},
#     '装置': {'times': 6755, 'quantity': 89, 'std_dev': 0.1141},
#     '聚酸酯': {'times': 6755, 'quantity': 121, 'std_dev': 0.1326},
#     '岁过华灯': {'times': 117, 'quantity': 16, 'std_dev': 0.3436},
#     '罗德岛物资补给II': {'times': 7, 'quantity': 1, 'std_dev': 0.3499},
#     '赤金': {'times': 6755, 'quantity': 609, 'std_dev': 0.2864},
#     '家具': {'times': 6755, 'quantity': 86, 'std_dev': 0.1121},
#     '基础作战记录': {'times': 6755, 'quantity': 8420, 'std_dev': 0.431},
#     '感谢庆典物资补给': {'times': 86, 'quantity': 9, 'std_dev': 0.3061},
#     '酯原料': {'times': 6755, 'quantity': 1778, 'std_dev': 0.4404}}},
#   '2-10': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'RMA70-12': {'times': 38157,
#      'quantity': 10536,
#      'std_dev': 0.4471},
#     '应急理智小样': {'times': 58, 'quantity': 13, 'std_dev': 0.417},
#     '感谢庆典物资补给': {'times': 236, 'quantity': 28, 'std_dev': 0.3234},
#     '代糖': {'times': 38157, 'quantity': 5978, 'std_dev': 0.3635},
#     '异铁碎片': {'times': 38157, 'quantity': 4773, 'std_dev': 0.3308},
#     '异铁': {'times': 38157, 'quantity': 3987, 'std_dev': 0.3059},
#     '酮凝集': {'times': 38157, 'quantity': 3981, 'std_dev': 0.3057},
#     '双酮': {'times': 38157, 'quantity': 4687, 'std_dev': 0.3282},
#     '32h战略配给': {'times': 1639, 'quantity': 306, 'std_dev': 0.3897},
#     '糖': {'times': 38157, 'quantity': 4983, 'std_dev': 0.3369},
#     '基础作战记录': {'times': 38157, 'quantity': 3830, 'std_dev': 0.3005},
#     '家具': {'times': 38157, 'quantity': 672, 'std_dev': 0.1315},
#     '岁过华灯': {'times': 823, 'quantity': 168, 'std_dev': 0.4031},
#     '罗德岛物资补给II': {'times': 118, 'quantity': 17, 'std_dev': 0.3512},
#     '罗德岛物资补给': {'times': 292, 'quantity': 56, 'std_dev': 0.3937},
#     '初级作战记录': {'times': 38157, 'quantity': 6004, 'std_dev': 0.3642},
#     '罗德岛物资补给III': {'times': 58, 'quantity': 10, 'std_dev': 0.3777}}},
#   'S2-1': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'岁过华灯': {'times': 8, 'quantity': 2, 'std_dev': 0.433},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '赤金': {'times': 995, 'quantity': 81, 'std_dev': 0.2734},
#     '32h战略配给': {'times': 30, 'quantity': 7, 'std_dev': 0.423},
#     '酯原料': {'times': 995, 'quantity': 71, 'std_dev': 0.2575},
#     '破损装置': {'times': 995, 'quantity': 42, 'std_dev': 0.201},
#     '代糖': {'times': 995, 'quantity': 87, 'std_dev': 0.2824},
#     '双酮': {'times': 995, 'quantity': 46, 'std_dev': 0.2099},
#     '基础作战记录': {'times': 995, 'quantity': 1176, 'std_dev': 0.4809},
#     '酮凝集': {'times': 995, 'quantity': 682, 'std_dev': 0.4644},
#     '源岩': {'times': 995, 'quantity': 107, 'std_dev': 0.3097},
#     '异铁碎片': {'times': 995, 'quantity': 56, 'std_dev': 0.2305},
#     '罗德岛物资补给': {'times': 8, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 995, 'quantity': 13, 'std_dev': 0.1136},
#     '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0}}},
#   'S2-2': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'源岩': {'times': 198, 'quantity': 35, 'std_dev': 0.3815},
#     '双酮': {'times': 198, 'quantity': 9, 'std_dev': 0.2084},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '代糖': {'times': 198, 'quantity': 13, 'std_dev': 0.2477},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 198, 'quantity': 11, 'std_dev': 0.2291},
#     '赤金': {'times': 198, 'quantity': 19, 'std_dev': 0.2945},
#     '破损装置': {'times': 198, 'quantity': 13, 'std_dev': 0.2477},
#     '酯原料': {'times': 198, 'quantity': 10, 'std_dev': 0.219},
#     '家具': {'times': 198, 'quantity': 3, 'std_dev': 0.1221},
#     '基础作战记录': {'times': 198, 'quantity': 245, 'std_dev': 0.4254}}},
#   'S2-3': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'酯原料': {'times': 103, 'quantity': 4, 'std_dev': 0.1931},
#     '双酮': {'times': 103, 'quantity': 9, 'std_dev': 0.2824},
#     '代糖': {'times': 103, 'quantity': 17, 'std_dev': 0.3711},
#     '基础作战记录': {'times': 103, 'quantity': 646, 'std_dev': 0.6563},
#     '赤金': {'times': 103, 'quantity': 14, 'std_dev': 0.3427},
#     '家具': {'times': 103, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 103, 'quantity': 2, 'std_dev': 0.1379},
#     '源岩': {'times': 103, 'quantity': 10, 'std_dev': 0.2961},
#     '异铁碎片': {'times': 103, 'quantity': 6, 'std_dev': 0.2342}}},
#   'S2-4': {'stage_type': 'MAIN',
#    'santity': 9,
#    'drop_info': {'应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 178, 'quantity': 13, 'std_dev': 0.2602},
#     '赤金': {'times': 178, 'quantity': 21, 'std_dev': 0.3225},
#     '源岩': {'times': 178, 'quantity': 30, 'std_dev': 0.3743},
#     '代糖': {'times': 178, 'quantity': 14, 'std_dev': 0.2691},
#     '基础作战记录': {'times': 178, 'quantity': 222, 'std_dev': 0.4314},
#     '酯原料': {'times': 178, 'quantity': 6, 'std_dev': 0.1805},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 2, 'std_dev': 0},
#     '双酮': {'times': 178, 'quantity': 6, 'std_dev': 0.1805},
#     '异铁碎片': {'times': 178, 'quantity': 13, 'std_dev': 0.2602},
#     '岁过华灯': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 178, 'quantity': 9, 'std_dev': 0.2192}}},
#   'S2-5': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'聚酸酯': {'times': 671, 'quantity': 10, 'std_dev': 0.1211},
#     '装置': {'times': 671, 'quantity': 13, 'std_dev': 0.1378},
#     '罗德岛物资补给II': {'times': 3, 'quantity': 1, 'std_dev': 0.4714},
#     '家具': {'times': 671, 'quantity': 11, 'std_dev': 0.127},
#     '32h战略配给': {'times': 11, 'quantity': 1, 'std_dev': 0.2875},
#     '罗德岛物资补给III': {'times': 21, 'quantity': 4, 'std_dev': 0.3927},
#     '源岩': {'times': 671, 'quantity': 2469, 'std_dev': 0.6344},
#     '固源岩': {'times': 671, 'quantity': 13, 'std_dev': 0.1378},
#     '罗德岛物资补给': {'times': 6, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 671, 'quantity': 168, 'std_dev': 0.4332},
#     '破损装置': {'times': 671, 'quantity': 94, 'std_dev': 0.3472},
#     '感谢庆典物资补给': {'times': 8, 'quantity': 3, 'std_dev': 0.4841},
#     '岁过华灯': {'times': 7, 'quantity': 2, 'std_dev': 0.4518},
#     '赤金': {'times': 671, 'quantity': 51, 'std_dev': 0.265},
#     '基础作战记录': {'times': 671, 'quantity': 825, 'std_dev': 0.4204},
#     '应急理智小样': {'times': 21, 'quantity': 3, 'std_dev': 0.3499}}},
#   'S2-6': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'基础作战记录': {'times': 576, 'quantity': 868, 'std_dev': 0.64},
#     '家具': {'times': 576, 'quantity': 11, 'std_dev': 0.1369},
#     '感谢庆典物资补给': {'times': 16, 'quantity': 1, 'std_dev': 0.2421},
#     '异铁': {'times': 576, 'quantity': 12, 'std_dev': 0.1428},
#     '糖': {'times': 576, 'quantity': 16, 'std_dev': 0.1643},
#     '应急理智小样': {'times': 20, 'quantity': 2, 'std_dev': 0.3},
#     '罗德岛物资补给': {'times': 10, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 20, 'quantity': 2, 'std_dev': 0.3},
#     '双酮': {'times': 576, 'quantity': 100, 'std_dev': 0.3787},
#     '罗德岛物资补给II': {'times': 4, 'quantity': 0, 'std_dev': 0},
#     '32h战略配给': {'times': 12, 'quantity': 3, 'std_dev': 0.433},
#     '异铁碎片': {'times': 576, 'quantity': 125, 'std_dev': 0.4122},
#     '初级作战记录': {'times': 576, 'quantity': 26, 'std_dev': 0.2076},
#     '代糖': {'times': 576, 'quantity': 1420, 'std_dev': 0.5762},
#     '酮凝集': {'times': 576, 'quantity': 7, 'std_dev': 0.1096},
#     '岁过华灯': {'times': 10, 'quantity': 0, 'std_dev': 0}}},
#   'S2-7': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 453, 'quantity': 1146, 'std_dev': 0.6032},
#     '聚酸酯': {'times': 453, 'quantity': 6, 'std_dev': 0.1143},
#     '罗德岛物资补给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '固源岩': {'times': 453, 'quantity': 13, 'std_dev': 0.1669},
#     '基础作战记录': {'times': 453, 'quantity': 555, 'std_dev': 0.4176},
#     '家具': {'times': 453, 'quantity': 8, 'std_dev': 0.1317},
#     '赤金': {'times': 453, 'quantity': 62, 'std_dev': 0.3437},
#     '装置': {'times': 453, 'quantity': 7, 'std_dev': 0.1233},
#     '32h战略配给': {'times': 12, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 453, 'quantity': 159, 'std_dev': 0.4773},
#     '罗德岛物资补给II': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 453, 'quantity': 76, 'std_dev': 0.3737}}},
#   'S2-8': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'异铁': {'times': 917, 'quantity': 15, 'std_dev': 0.1269},
#     '酮凝集': {'times': 917, 'quantity': 12, 'std_dev': 0.1137},
#     '异铁碎片': {'times': 917, 'quantity': 1768, 'std_dev': 0.5636},
#     '双酮': {'times': 917, 'quantity': 205, 'std_dev': 0.4167},
#     '应急理智小样': {'times': 22, 'quantity': 3, 'std_dev': 0.3432},
#     '糖': {'times': 917, 'quantity': 21, 'std_dev': 0.1495},
#     '感谢庆典物资补给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '基础作战记录': {'times': 917, 'quantity': 1325, 'std_dev': 0.593},
#     '代糖': {'times': 917, 'quantity': 233, 'std_dev': 0.4354},
#     '罗德岛物资补给': {'times': 9, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 22, 'quantity': 1, 'std_dev': 0.2083},
#     '家具': {'times': 917, 'quantity': 14, 'std_dev': 0.1226},
#     '32h战略配给': {'times': 9, 'quantity': 3, 'std_dev': 0.4714},
#     '初级作战记录': {'times': 917, 'quantity': 47, 'std_dev': 0.2205},
#     '岁过华灯': {'times': 3, 'quantity': 0, 'std_dev': 0}}},
#   'S2-9': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'双酮': {'times': 773, 'quantity': 1529, 'std_dev': 0.5806},
#     '糖': {'times': 773, 'quantity': 19, 'std_dev': 0.1548},
#     '家具': {'times': 773, 'quantity': 10, 'std_dev': 0.1129},
#     '感谢庆典物资补给': {'times': 5, 'quantity': 1, 'std_dev': 0.4},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '基础作战记录': {'times': 773, 'quantity': 1117, 'std_dev': 0.572},
#     '初级作战记录': {'times': 773, 'quantity': 50, 'std_dev': 0.2461},
#     '32h战略配给': {'times': 9, 'quantity': 1, 'std_dev': 0.3143},
#     '岁过华灯': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 773, 'quantity': 151, 'std_dev': 0.3964},
#     '罗德岛物资补给': {'times': 4, 'quantity': 1, 'std_dev': 0.433},
#     '代糖': {'times': 773, 'quantity': 198, 'std_dev': 0.4364},
#     '异铁': {'times': 773, 'quantity': 9, 'std_dev': 0.1072},
#     '酮凝集': {'times': 773, 'quantity': 9, 'std_dev': 0.1073}}},
#   'S2-10': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'基础作战记录': {'times': 131, 'quantity': 175, 'std_dev': 0.4723},
#     '固源岩': {'times': 131, 'quantity': 4, 'std_dev': 0.1721},
#     '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 131, 'quantity': 51, 'std_dev': 0.4876},
#     '装置': {'times': 131, 'quantity': 2, 'std_dev': 0.1225},
#     '聚酸酯': {'times': 131, 'quantity': 2, 'std_dev': 0.1226},
#     '罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#     '酯原料': {'times': 131, 'quantity': 32, 'std_dev': 0.4296},
#     '破损装置': {'times': 131, 'quantity': 21, 'std_dev': 0.3669},
#     '家具': {'times': 131, 'quantity': 2, 'std_dev': 0.1226},
#     '赤金': {'times': 131, 'quantity': 11, 'std_dev': 0.2773},
#     '初级作战记录': {'times': 131, 'quantity': 524, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 1, 'quantity': 1, 'std_dev': 0},
#     '罗德岛物资补给': {'times': 41, 'quantity': 8, 'std_dev': 0.3963}}},
#   'S2-11': {'stage_type': 'MAIN',
#    'santity': 12,
#    'drop_info': {'代糖': {'times': 130, 'quantity': 39, 'std_dev': 0.4582},
#     '家具': {'times': 130, 'quantity': 16, 'std_dev': 0.3285},
#     '应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 130, 'quantity': 27, 'std_dev': 0.4057},
#     '初级作战记录': {'times': 130, 'quantity': 5, 'std_dev': 0.1923},
#     '基础作战记录': {'times': 130, 'quantity': 178, 'std_dev': 0.4982},
#     '异铁': {'times': 130, 'quantity': 2, 'std_dev': 0.123},
#     '异铁碎片': {'times': 130, 'quantity': 30, 'std_dev': 0.4213},
#     '糖': {'times': 130, 'quantity': 2, 'std_dev': 0.1231},
#     '酮凝集': {'times': 130, 'quantity': 5, 'std_dev': 0.1922}}},
#   'S2-12': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'源岩': {'times': 15330, 'quantity': 3200, 'std_dev': 0.4064},
#     '赤金': {'times': 15330, 'quantity': 1794, 'std_dev': 0.3215},
#     '装置': {'times': 15330, 'quantity': 1365, 'std_dev': 0.2848},
#     '酯原料': {'times': 15330, 'quantity': 2110, 'std_dev': 0.3446},
#     '破损装置': {'times': 15330, 'quantity': 1255, 'std_dev': 0.2741},
#     '固源岩': {'times': 15330, 'quantity': 35142, 'std_dev': 0.7549},
#     '岁过华灯': {'times': 189, 'quantity': 37, 'std_dev': 0.3968},
#     '罗德岛物资补给III': {'times': 454, 'quantity': 68, 'std_dev': 0.3569},
#     '聚酸酯': {'times': 15330, 'quantity': 2130, 'std_dev': 0.346},
#     '感谢庆典物资补给': {'times': 85, 'quantity': 20, 'std_dev': 0.4242},
#     '罗德岛物资补给': {'times': 119, 'quantity': 11, 'std_dev': 0.2896},
#     '32h战略配给': {'times': 26, 'quantity': 2, 'std_dev': 0.2665},
#     '罗德岛物资补给II': {'times': 589, 'quantity': 103, 'std_dev': 0.3799},
#     '家具': {'times': 15330, 'quantity': 285, 'std_dev': 0.1351},
#     '应急理智小样': {'times': 454, 'quantity': 58, 'std_dev': 0.3338}}}},
#  '第三章': {'3-1': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'家具': {'times': 49199, 'quantity': 887, 'std_dev': 0.1331},
#     '岁过华灯': {'times': 1565, 'quantity': 303, 'std_dev': 0.3951},
#     '异铁碎片': {'times': 49199, 'quantity': 5993, 'std_dev': 0.327},
#     '32h战略配给': {'times': 2488, 'quantity': 446, 'std_dev': 0.3836},
#     '基础作战记录': {'times': 49199, 'quantity': 4932, 'std_dev': 0.3004},
#     '罗德岛物资补给': {'times': 1986, 'quantity': 394, 'std_dev': 0.3988},
#     '双酮': {'times': 49199, 'quantity': 6157, 'std_dev': 0.3309},
#     '代糖': {'times': 49199, 'quantity': 7715, 'std_dev': 0.3635},
#     '初级作战记录': {'times': 49199, 'quantity': 7835, 'std_dev': 0.3659},
#     '应急理智小样': {'times': 237, 'quantity': 26, 'std_dev': 0.3125},
#     '罗德岛物资补给II': {'times': 310, 'quantity': 64, 'std_dev': 0.4048},
#     '异铁': {'times': 49199, 'quantity': 5080, 'std_dev': 0.3043},
#     '罗德岛物资补给III': {'times': 237, 'quantity': 55, 'std_dev': 0.4222},
#     '感谢庆典物资补给': {'times': 1388, 'quantity': 230, 'std_dev': 0.3718},
#     '酮凝集': {'times': 49199, 'quantity': 5214, 'std_dev': 0.3078},
#     '酮凝集组': {'times': 49199, 'quantity': 18096, 'std_dev': 0.4823},
#     '糖': {'times': 49199, 'quantity': 6324, 'std_dev': 0.3347}}},
#   '3-2': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'酯原料': {'times': 60725, 'quantity': 8484, 'std_dev': 0.3467},
#     '感谢庆典物资补给': {'times': 62, 'quantity': 5, 'std_dev': 0.2723},
#     '聚酸酯': {'times': 60725, 'quantity': 8542, 'std_dev': 0.3477},
#     '家具': {'times': 60725, 'quantity': 1239, 'std_dev': 0.1413},
#     '罗德岛物资补给III': {'times': 378, 'quantity': 67, 'std_dev': 0.3819},
#     '源岩': {'times': 60725, 'quantity': 13178, 'std_dev': 0.4121},
#     '固源岩': {'times': 60725, 'quantity': 12690, 'std_dev': 0.4066},
#     '装置': {'times': 60725, 'quantity': 5160, 'std_dev': 0.2789},
#     '岁过华灯': {'times': 1291, 'quantity': 233, 'std_dev': 0.3846},
#     '32h战略配给': {'times': 3170, 'quantity': 517, 'std_dev': 0.3694},
#     '罗德岛物资补给II': {'times': 200, 'quantity': 29, 'std_dev': 0.3521},
#     '轻锰矿': {'times': 60725, 'quantity': 22445, 'std_dev': 0.4845},
#     '罗德岛物资补给': {'times': 1044, 'quantity': 215, 'std_dev': 0.4044},
#     '应急理智小样': {'times': 378, 'quantity': 61, 'std_dev': 0.3679},
#     '破损装置': {'times': 60725, 'quantity': 5316, 'std_dev': 0.2827},
#     '赤金': {'times': 60725, 'quantity': 7396, 'std_dev': 0.3271}}},
#   '3-3': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'破损装置': {'times': 37429, 'quantity': 3235, 'std_dev': 0.281},
#     '32h战略配给': {'times': 1493, 'quantity': 278, 'std_dev': 0.3893},
#     '聚酸酯': {'times': 37429, 'quantity': 5271, 'std_dev': 0.3478},
#     '赤金': {'times': 37429, 'quantity': 4379, 'std_dev': 0.3214},
#     '罗德岛物资补给II': {'times': 524, 'quantity': 98, 'std_dev': 0.3899},
#     '罗德岛物资补给III': {'times': 254, 'quantity': 38, 'std_dev': 0.3567},
#     '固源岩': {'times': 37429, 'quantity': 7853, 'std_dev': 0.4071},
#     '感谢庆典物资补给': {'times': 326, 'quantity': 53, 'std_dev': 0.369},
#     '装置': {'times': 37429, 'quantity': 3152, 'std_dev': 0.2778},
#     '罗德岛物资补给': {'times': 987, 'quantity': 176, 'std_dev': 0.3828},
#     '应急理智小样': {'times': 254, 'quantity': 27, 'std_dev': 0.3082},
#     '岁过华灯': {'times': 421, 'quantity': 83, 'std_dev': 0.3978},
#     '源岩': {'times': 37429, 'quantity': 8201, 'std_dev': 0.4137},
#     '酯原料': {'times': 37429, 'quantity': 5356, 'std_dev': 0.3502},
#     '研磨石': {'times': 37429, 'quantity': 11982, 'std_dev': 0.4666},
#     '家具': {'times': 37429, 'quantity': 727, 'std_dev': 0.138}}},
#   '3-4': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'罗德岛物资补给III': {'times': 157,
#      'quantity': 29,
#      'std_dev': 0.3881},
#     '聚酸酯': {'times': 35773, 'quantity': 4987, 'std_dev': 0.3464},
#     '罗德岛物资补给': {'times': 876, 'quantity': 148, 'std_dev': 0.3747},
#     '岁过华灯': {'times': 1217, 'quantity': 213, 'std_dev': 0.38},
#     '应急理智小样': {'times': 157, 'quantity': 20, 'std_dev': 0.3334},
#     '全新装置': {'times': 35773, 'quantity': 9800, 'std_dev': 0.446},
#     '装置': {'times': 35773, 'quantity': 3124, 'std_dev': 0.2823},
#     '固源岩': {'times': 35773, 'quantity': 7536, 'std_dev': 0.4079},
#     '赤金': {'times': 35773, 'quantity': 4307, 'std_dev': 0.3254},
#     '破损装置': {'times': 35773, 'quantity': 3028, 'std_dev': 0.2784},
#     '酯原料': {'times': 35773, 'quantity': 5049, 'std_dev': 0.3482},
#     '源岩': {'times': 35773, 'quantity': 7777, 'std_dev': 0.4125},
#     '家具': {'times': 35773, 'quantity': 681, 'std_dev': 0.1367},
#     '罗德岛物资补给II': {'times': 194, 'quantity': 38, 'std_dev': 0.3969},
#     '32h战略配给': {'times': 1610, 'quantity': 272, 'std_dev': 0.3747},
#     '感谢庆典物资补给': {'times': 544, 'quantity': 86, 'std_dev': 0.3648}}},
#   '3-5': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'聚酸酯': {'times': 69, 'quantity': 10, 'std_dev': 0.3521},
#     '罗德岛物资补给': {'times': 55, 'quantity': 11, 'std_dev': 0.4},
#     '固源岩': {'times': 69, 'quantity': 17, 'std_dev': 0.4309},
#     '家具': {'times': 69, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 69, 'quantity': 5, 'std_dev': 0.2593},
#     '装置': {'times': 69, 'quantity': 7, 'std_dev': 0.3019},
#     '初级作战记录': {'times': 69, 'quantity': 345, 'std_dev': 0},
#     '源岩': {'times': 69, 'quantity': 16, 'std_dev': 0.4221},
#     '酯原料': {'times': 69, 'quantity': 6, 'std_dev': 0.2818},
#     '赤金': {'times': 69, 'quantity': 8, 'std_dev': 0.3202}}},
#   '3-6': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '双酮': {'times': 355, 'quantity': 40, 'std_dev': 0.3161},
#     '罗德岛物资补给II': {'times': 13, 'quantity': 6, 'std_dev': 0.4985},
#     '代糖': {'times': 355, 'quantity': 62, 'std_dev': 0.3796},
#     '异铁': {'times': 355, 'quantity': 38, 'std_dev': 0.3091},
#     '糖': {'times': 355, 'quantity': 41, 'std_dev': 0.3197},
#     '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#     '异铁碎片': {'times': 355, 'quantity': 54, 'std_dev': 0.3592},
#     '酮凝集': {'times': 355, 'quantity': 35, 'std_dev': 0.298},
#     '初级作战记录': {'times': 355, 'quantity': 68, 'std_dev': 0.3935},
#     '基础作战记录': {'times': 355, 'quantity': 25, 'std_dev': 0.2559},
#     '罗德岛物资补给': {'times': 9, 'quantity': 1, 'std_dev': 0.3143},
#     '家具': {'times': 355, 'quantity': 11, 'std_dev': 0.1734}}},
#   '3-7': {'stage_type': 'MAIN',
#    'santity': 15,
#    'drop_info': {'罗德岛物资补给': {'times': 54, 'quantity': 7, 'std_dev': 0.3359},
#     '代糖': {'times': 7144, 'quantity': 1078, 'std_dev': 0.3579},
#     '异铁': {'times': 7144, 'quantity': 767, 'std_dev': 0.3096},
#     '32h战略配给': {'times': 146, 'quantity': 19, 'std_dev': 0.3365},
#     '初级作战记录': {'times': 7144, 'quantity': 1094, 'std_dev': 0.3602},
#     '岁过华灯': {'times': 97, 'quantity': 11, 'std_dev': 0.3171},
#     '应急理智小样': {'times': 15, 'quantity': 1, 'std_dev': 0.2494},
#     '酮凝集': {'times': 7144, 'quantity': 8730, 'std_dev': 0.4495},
#     '罗德岛物资补给II': {'times': 45, 'quantity': 11, 'std_dev': 0.4298},
#     '罗德岛物资补给III': {'times': 15, 'quantity': 5, 'std_dev': 0.4714},
#     '家具': {'times': 7144, 'quantity': 148, 'std_dev': 0.1425},
#     '感谢庆典物资补给': {'times': 67, 'quantity': 17, 'std_dev': 0.4351},
#     '双酮': {'times': 7144, 'quantity': 888, 'std_dev': 0.3299},
#     '糖': {'times': 7144, 'quantity': 885, 'std_dev': 0.3294},
#     '异铁碎片': {'times': 7144, 'quantity': 837, 'std_dev': 0.3216},
#     '基础作战记录': {'times': 7144, 'quantity': 736, 'std_dev': 0.3041}}},
#   '3-8': {'stage_type': 'MAIN',
#    'santity': 18,
#    'drop_info': {'32h战略配给': {'times': 171, 'quantity': 32, 'std_dev': 0.39},
#     '罗德岛物资补给III': {'times': 3, 'quantity': 2, 'std_dev': 0.4714},
#     '晶体元件': {'times': 748, 'quantity': 5, 'std_dev': 0.0815},
#     '双酮': {'times': 10747, 'quantity': 3451, 'std_dev': 0.4669},
#     '化合切削液': {'times': 560, 'quantity': 5, 'std_dev': 0.094},
#     '岁过华灯': {'times': 86, 'quantity': 13, 'std_dev': 0.3582},
#     '研磨石': {'times': 10747, 'quantity': 123, 'std_dev': 0.1064},
#     '聚酸酯': {'times': 10747, 'quantity': 1129, 'std_dev': 0.3066},
#     '家具': {'times': 10747, 'quantity': 230, 'std_dev': 0.1447},
#     '酯原料': {'times': 10747, 'quantity': 4490, 'std_dev': 0.4932},
#     '酮凝集': {'times': 10747, 'quantity': 961, 'std_dev': 0.2853},
#     '酮凝集组': {'times': 10747, 'quantity': 175, 'std_dev': 0.1266},
#     '聚酸酯块': {'times': 10747, 'quantity': 397, 'std_dev': 0.1886},
#     '感谢庆典物资补给': {'times': 8, 'quantity': 2, 'std_dev': 0.433},
#     '应急理智小样': {'times': 3, 'quantity': 0, 'std_dev': 0},
#     '罗德岛物资补给': {'times': 63, 'quantity': 13, 'std_dev': 0.4047},
# ...
#     '扭转醇': {'times': 2009, 'quantity': 982, 'std_dev': 0.4998},
#     '酯原料': {'times': 2009, 'quantity': 818, 'std_dev': 0.4913},
#     'RMA70-12': {'times': 2009, 'quantity': 33, 'std_dev': 0.1271},
#     '应急理智小样': {'times': 104, 'quantity': 22, 'std_dev': 0.4084},
#     '酮凝集组': {'times': 2009, 'quantity': 63, 'std_dev': 0.1743},
#     '双酮': {'times': 2009, 'quantity': 673, 'std_dev': 0.472},
#     '化合切削液': {'times': 2009, 'quantity': 38, 'std_dev': 0.1362}}},
#   '10-16': {'stage_type': 'MAIN',
#    'santity': 21,
#    'drop_info': {'聚酸酯': {'times': 3521, 'quantity': 2760, 'std_dev': 0.8899},
#     '轻锰矿': {'times': 3521, 'quantity': 1871, 'std_dev': 0.499},
#     '家具': {'times': 3521, 'quantity': 76, 'std_dev': 0.1453},
#     '应急理智小样': {'times': 2427, 'quantity': 477, 'std_dev': 0.3974},
#     '罗德岛物资补给III': {'times': 2427, 'quantity': 582, 'std_dev': 0.427}}},
#   '10-17': {'stage_type': 'MAIN',
#    'santity': 24,
#    'drop_info': {'固源岩': {'times': 239, 'quantity': 69, 'std_dev': 0.4532},
#     '固源岩组': {'times': 239, 'quantity': 14, 'std_dev': 0.2348},
#     '家具': {'times': 239, 'quantity': 7, 'std_dev': 0.1687},
#     '赤金': {'times': 239, 'quantity': 22, 'std_dev': 0.2891},
#     '全新装置': {'times': 239, 'quantity': 8, 'std_dev': 0.1799},
#     '破损装置': {'times': 239, 'quantity': 16, 'std_dev': 0.2499},
#     '源岩': {'times': 239, 'quantity': 48, 'std_dev': 0.4006},
#     '化合切削液': {'times': 239, 'quantity': 137, 'std_dev': 0.4946},
#     '应急理智小样': {'times': 152, 'quantity': 39, 'std_dev': 0.4367},
#     '扭转醇': {'times': 239, 'quantity': 14, 'std_dev': 0.2348},
#     '凝胶': {'times': 239, 'quantity': 5, 'std_dev': 0.1431},
#     '装置': {'times': 239, 'quantity': 43, 'std_dev': 0.3841},
#     '罗德岛物资补给III': {'times': 152, 'quantity': 39, 'std_dev': 0.4367}}}},
#  '罗德岛物资补给III': {'罗德岛物资补给III': {'stage_type': 'ACTIVITY',
#    'santity': 99,
#    'drop_info': {'化合切削液': {'times': 5668, 'quantity': 83, 'std_dev': 0.1454},
#     '酮凝集组': {'times': 5668, 'quantity': 94, 'std_dev': 0.1693},
#     '聚酸酯组': {'times': 5668, 'quantity': 116, 'std_dev': 0.178},
#     '装置': {'times': 5668, 'quantity': 710, 'std_dev': 0.8866},
#     '异铁组': {'times': 5668, 'quantity': 101, 'std_dev': 0.1827},
#     '研磨石': {'times': 5668, 'quantity': 99, 'std_dev': 0.1634},
#     '半自然溶剂': {'times': 5668, 'quantity': 70, 'std_dev': 0.1486},
#     'RMA70-12': {'times': 5668, 'quantity': 104, 'std_dev': 0.1879},
#     '晶体元件': {'times': 5668, 'quantity': 98, 'std_dev': 0.1713},
#     '聚酸酯': {'times': 5668, 'quantity': 748, 'std_dev': 0.957},
#     '糖组': {'times': 5668, 'quantity': 90, 'std_dev': 0.1575},
#     '酮凝集': {'times': 5668, 'quantity': 706, 'std_dev': 0.9042},
#     '扭转醇': {'times': 5668, 'quantity': 98, 'std_dev': 0.1661},
#     '全新装置': {'times': 5668, 'quantity': 91, 'std_dev': 0.1678},
#     '固源岩': {'times': 5668, 'quantity': 693, 'std_dev': 0.8123},
#     '异铁': {'times': 5668, 'quantity': 702, 'std_dev': 0.9018},
#     '家具': {'times': 5668, 'quantity': 0, 'std_dev': 0},
#     '固源岩组': {'times': 5668, 'quantity': 90, 'std_dev': 0.1494},
#     '炽合金': {'times': 5668, 'quantity': 99, 'std_dev': 0.1644},
#     '轻锰矿': {'times': 5668, 'quantity': 95, 'std_dev': 0.1677},
#     '凝胶': {'times': 5668, 'quantity': 98, 'std_dev': 0.165},
#     '糖': {'times': 5668, 'quantity': 683, 'std_dev': 0.8113}}}},
#  '愚人号': {'SN-1': {'stage_type': 'ACTIVITY',
#    'santity': 9,
#    'drop_info': {'异铁碎片': {'times': 4356, 'quantity': 1254, 'std_dev': 0.4533},
#     '双酮': {'times': 4356, 'quantity': 1378, 'std_dev': 0.4655},
#     '家具': {'times': 4356, 'quantity': 60, 'std_dev': 0.1166},
#     '源岩': {'times': 4356, 'quantity': 2629, 'std_dev': 0.4938},
#     '破损装置': {'times': 4356, 'quantity': 918, 'std_dev': 0.4078},
#     '酯原料': {'times': 4356, 'quantity': 1670, 'std_dev': 0.4862},
#     '代糖': {'times': 4356, 'quantity': 1666, 'std_dev': 0.4865}}},
#   'SN-2': {'stage_type': 'ACTIVITY',
#    'santity': 9,
#    'drop_info': {'双酮': {'times': 1936, 'quantity': 582, 'std_dev': 0.4585},
#     '家具': {'times': 1936, 'quantity': 19, 'std_dev': 0.0986},
#     '源岩': {'times': 1936, 'quantity': 1169, 'std_dev': 0.4891},
#     '破损装置': {'times': 1936, 'quantity': 418, 'std_dev': 0.4115},
#     '酯原料': {'times': 1936, 'quantity': 754, 'std_dev': 0.4876},
#     '代糖': {'times': 1936, 'quantity': 748, 'std_dev': 0.488},
#     '异铁碎片': {'times': 1936, 'quantity': 591, 'std_dev': 0.4672}}},
#   'SN-3': {'stage_type': 'ACTIVITY',
#    'santity': 9,
#    'drop_info': {'代糖': {'times': 2270, 'quantity': 880, 'std_dev': 0.4881},
#     '异铁碎片': {'times': 2270, 'quantity': 706, 'std_dev': 0.4676},
#     '双酮': {'times': 2270, 'quantity': 691, 'std_dev': 0.4611},
#     '家具': {'times': 2270, 'quantity': 29, 'std_dev': 0.1123},
#     '源岩': {'times': 2270, 'quantity': 1388, 'std_dev': 0.4964},
#     '破损装置': {'times': 2270, 'quantity': 539, 'std_dev': 0.4296},
#     '酯原料': {'times': 2270, 'quantity': 923, 'std_dev': 0.4983}}},
#   'SN-4': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'装置': {'times': 6069, 'quantity': 1996, 'std_dev': 0.4698},
#     '家具': {'times': 6069, 'quantity': 70, 'std_dev': 0.1068},
#     '聚酸酯': {'times': 6069, 'quantity': 6708, 'std_dev': 0.3069}}},
#   'SN-5': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'异铁': {'times': 5783, 'quantity': 5119, 'std_dev': 0.3188},
#     '酮凝集': {'times': 5783, 'quantity': 2621, 'std_dev': 0.4982},
#     '家具': {'times': 5783, 'quantity': 94, 'std_dev': 0.1265}}},
#   'SN-6': {'stage_type': 'ACTIVITY',
#    'santity': 15,
#    'drop_info': {'糖': {'times': 16815, 'quantity': 23462, 'std_dev': 0.4893},
#     '固源岩': {'times': 16815, 'quantity': 17524, 'std_dev': 0.201},
#     '家具': {'times': 16815, 'quantity': 255, 'std_dev': 0.1222}}},
#   'SN-7': {'stage_type': 'ACTIVITY',
#    'santity': 15,
#    'drop_info': {'异铁': {'times': 4316, 'quantity': 2371, 'std_dev': 0.499},
#     '家具': {'times': 4316, 'quantity': 78, 'std_dev': 0.1332},
#     '装置': {'times': 4316, 'quantity': 3606, 'std_dev': 0.3714}}},
#   'SN-8': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'家具': {'times': 320632, 'quantity': 7046, 'std_dev': 0.1466},
#     '异铁组': {'times': 320632, 'quantity': 249007, 'std_dev': 0.4165}}},
#   'SN-9': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'轻锰矿': {'times': 377968,
#      'quantity': 293869,
#      'std_dev': 0.4159},
#     '家具': {'times': 377968, 'quantity': 8321, 'std_dev': 0.1467}}},
#   'SN-10': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'化合切削液': {'times': 151203,
#      'quantity': 105855,
#      'std_dev': 0.4582},
#     '家具': {'times': 151203, 'quantity': 3439, 'std_dev': 0.1491}}}},
#  '愚人号・永久': {'SN-1': {'stage_type': 'ACTIVITY', 'santity': 9, 'drop_info': {}},
#   'SN-2': {'stage_type': 'ACTIVITY', 'santity': 9, 'drop_info': {}},
#   'SN-3': {'stage_type': 'ACTIVITY', 'santity': 9, 'drop_info': {}},
#   'SN-4': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'酯原料': {'times': 11, 'quantity': 27, 'std_dev': 0.4979},
#     '赤金': {'times': 11, 'quantity': 0, 'std_dev': 0},
#     '源岩': {'times': 11, 'quantity': 7, 'std_dev': 0.481},
#     '固源岩': {'times': 11, 'quantity': 0, 'std_dev': 0},
#     '破损装置': {'times': 11, 'quantity': 3, 'std_dev': 0.4454},
#     '装置': {'times': 11, 'quantity': 0, 'std_dev': 0},
#     '聚酸酯': {'times': 11, 'quantity': 0, 'std_dev': 0},
#     '家具': {'times': 11, 'quantity': 0, 'std_dev': 0}}},
#   'SN-5': {'stage_type': 'ACTIVITY', 'santity': 12, 'drop_info': {}},
#   'SN-6': {'stage_type': 'ACTIVITY', 'santity': 15, 'drop_info': {}},
#   'SN-7': {'stage_type': 'ACTIVITY', 'santity': 15, 'drop_info': {}},
#   'SN-8': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'家具': {'times': 506, 'quantity': 0, 'std_dev': 0},
#     '固源岩': {'times': 506, 'quantity': 184, 'std_dev': 0.481},
#     '破损装置': {'times': 506, 'quantity': 41, 'std_dev': 0.2729},
#     '异铁组': {'times': 506, 'quantity': 182, 'std_dev': 0.4799},
#     '异铁块': {'times': 506, 'quantity': 22, 'std_dev': 0.2039},
#     '固源岩组': {'times': 506, 'quantity': 14, 'std_dev': 0.164},
#     '凝胶': {'times': 506, 'quantity': 8, 'std_dev': 0.1247},
#     '扭转醇': {'times': 506, 'quantity': 25, 'std_dev': 0.2167},
#     '赤金': {'times': 506, 'quantity': 37, 'std_dev': 0.2603},
#     '源岩': {'times': 506, 'quantity': 103, 'std_dev': 0.4026},
#     '装置': {'times': 506, 'quantity': 85, 'std_dev': 0.3739},
#     '全新装置': {'times': 506, 'quantity': 9, 'std_dev': 0.1322}}},
#   'SN-9': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'异铁组': {'times': 345, 'quantity': 10, 'std_dev': 0.1678},
#     '初级作战记录': {'times': 345, 'quantity': 58, 'std_dev': 0.374},
#     '糖组': {'times': 345, 'quantity': 12, 'std_dev': 0.1832},
#     '异铁': {'times': 345, 'quantity': 49, 'std_dev': 0.3491},
#     '炽合金': {'times': 345, 'quantity': 4, 'std_dev': 0.1071},
#     '基础作战记录': {'times': 345, 'quantity': 43, 'std_dev': 0.3303},
#     '代糖': {'times': 345, 'quantity': 35, 'std_dev': 0.3019},
#     '三水锰矿': {'times': 345, 'quantity': 11, 'std_dev': 0.1757},
#     '中级作战记录': {'times': 345, 'quantity': 25, 'std_dev': 0.2593},
#     '糖': {'times': 345, 'quantity': 62, 'std_dev': 0.3839},
#     '家具': {'times': 345, 'quantity': 0, 'std_dev': 0},
#     '轻锰矿': {'times': 345, 'quantity': 150, 'std_dev': 0.5297},
#     '异铁碎片': {'times': 345, 'quantity': 31, 'std_dev': 0.286}}},
#   'SN-10': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'家具': {'times': 60, 'quantity': 0, 'std_dev': 0},
#     '聚酸酯': {'times': 60, 'quantity': 6, 'std_dev': 0.3},
#     '双酮': {'times': 60, 'quantity': 13, 'std_dev': 0.412},
#     '切削原液': {'times': 60, 'quantity': 3, 'std_dev': 0.2179},
#     '酮凝集组': {'times': 60, 'quantity': 1, 'std_dev': 0.128},
#     '研磨石': {'times': 60, 'quantity': 1, 'std_dev': 0.128},
#     '酯原料': {'times': 60, 'quantity': 29, 'std_dev': 0.4997},
#     '聚酸酯组': {'times': 60, 'quantity': 2, 'std_dev': 0.1795},
#     'RMA70-12': {'times': 60, 'quantity': 2, 'std_dev': 0.1795},
#     '晶体元件': {'times': 60, 'quantity': 1, 'std_dev': 0.128},
#     '化合切削液': {'times': 60, 'quantity': 20, 'std_dev': 0.4714},
#     '酮凝集': {'times': 60, 'quantity': 5, 'std_dev': 0.2764}}}},
#  '覆潮之下・复刻': {'SV-1': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'酯原料': {'times': 1108, 'quantity': 553, 'std_dev': 0.5018},
#     '家具': {'times': 1108, 'quantity': 14, 'std_dev': 0.1117},
#     '源岩': {'times': 1108, 'quantity': 926, 'std_dev': 0.3705},
#     '代糖': {'times': 1108, 'quantity': 594, 'std_dev': 0.4987},
#     '双酮': {'times': 1108, 'quantity': 464, 'std_dev': 0.6184},
#     '异铁碎片': {'times': 1108, 'quantity': 502, 'std_dev': 0.6531},
#     '破损装置': {'times': 1108, 'quantity': 352, 'std_dev': 0.4656}}},
#   'SV-2': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'家具': {'times': 674, 'quantity': 9, 'std_dev': 0.1148},
#     '代糖': {'times': 674, 'quantity': 362, 'std_dev': 0.4986},
#     '双酮': {'times': 674, 'quantity': 312, 'std_dev': 0.6206},
#     '酯原料': {'times': 674, 'quantity': 338, 'std_dev': 0.5},
#     '异铁碎片': {'times': 674, 'quantity': 285, 'std_dev': 0.6145},
#     '源岩': {'times': 674, 'quantity': 588, 'std_dev': 0.3336},
#     '破损装置': {'times': 674, 'quantity': 209, 'std_dev': 0.4625}}},
#   'SV-3': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'家具': {'times': 401, 'quantity': 4, 'std_dev': 0.0994},
#     '源岩': {'times': 401, 'quantity': 461, 'std_dev': 0.8835},
#     '糖': {'times': 401, 'quantity': 436, 'std_dev': 0.2822}}},
#   'SV-4': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'酮凝集': {'times': 6688, 'quantity': 4552, 'std_dev': 0.4662},
#     '家具': {'times': 6688, 'quantity': 106, 'std_dev': 0.1249},
#     '固源岩': {'times': 6688, 'quantity': 5901, 'std_dev': 0.3222}}},
#   'SV-5': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'聚酸酯': {'times': 2486, 'quantity': 2083, 'std_dev': 0.5403},
#     '家具': {'times': 2486, 'quantity': 35, 'std_dev': 0.1178},
#     '糖': {'times': 2486, 'quantity': 1664, 'std_dev': 0.4713}}},
#   'SV-6': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'固源岩': {'times': 10083, 'quantity': 8839, 'std_dev': 0.3289},
#     '家具': {'times': 10083, 'quantity': 145, 'std_dev': 0.1191},
#     '异铁': {'times': 10083, 'quantity': 7296, 'std_dev': 0.4472}}},
#   'SV-7': {'stage_type': 'ACTIVITY',
#    'santity': 15,
#    'drop_info': {'固源岩组': {'times': 146895,
#      'quantity': 114679,
#      'std_dev': 0.4138},
#     '家具': {'times': 146895, 'quantity': 2812, 'std_dev': 0.137}}},
#   'SV-8': {'stage_type': 'ACTIVITY',
#    'santity': 18,
#    'drop_info': {'家具': {'times': 20849, 'quantity': 489, 'std_dev': 0.1513},
#     '晶体元件': {'times': 20849, 'quantity': 15630, 'std_dev': 0.4332}}},
#   'SV-9': {'stage_type': 'ACTIVITY',
#    'santity': 18,
#    'drop_info': {'全新装置': {'times': 496180, 'quantity': 247699, 'std_dev': 0.5},
#     '家具': {'times': 496180, 'quantity': 11699, 'std_dev': 0.1517}}}},
#  '渊默行动物资补给': {'渊默行动物资补给': {'stage_type': 'ACTIVITY',
#    'santity': 99,
#    'drop_info': {'固源岩组': {'times': 902, 'quantity': 84, 'std_dev': 0.4804},
#     '研磨石': {'times': 902, 'quantity': 47, 'std_dev': 0.2988},
#     '扭转醇': {'times': 902, 'quantity': 68, 'std_dev': 0.4063},
#     'RMA70-12': {'times': 902, 'quantity': 40, 'std_dev': 0.2869},
#     '凝胶': {'times': 902, 'quantity': 60, 'std_dev': 0.3617},
#     '聚酸酯组': {'times': 902, 'quantity': 71, 'std_dev': 0.4151},
#     '半自然溶剂': {'times': 902, 'quantity': 51, 'std_dev': 0.323},
#     '家具': {'times': 902, 'quantity': 0, 'std_dev': 0},
#     '晶体元件': {'times': 902, 'quantity': 64, 'std_dev': 0.4071},
#     '轻锰矿': {'times': 902, 'quantity': 58, 'std_dev': 0.3943},
#     '炽合金': {'times': 902, 'quantity': 78, 'std_dev': 0.4532},
#     '糖组': {'times': 902, 'quantity': 78, 'std_dev': 0.4483},
#     '全新装置': {'times': 902, 'quantity': 39, 'std_dev': 0.2564},
#     '异铁组': {'times': 902, 'quantity': 51, 'std_dev': 0.3126},
#     '酮凝集组': {'times': 902, 'quantity': 67, 'std_dev': 0.394},
#     '化合切削液': {'times': 902, 'quantity': 46, 'std_dev': 0.3612}}}},
#  '尘影余音': {'LE-1': {'stage_type': 'ACTIVITY',
#    'santity': 9,
#    'drop_info': {'异铁碎片': {'times': 2826, 'quantity': 946, 'std_dev': 0.4719},
#     '双酮': {'times': 2826, 'quantity': 879, 'std_dev': 0.4629},
#     '家具': {'times': 2826, 'quantity': 29, 'std_dev': 0.1008},
#     '源岩': {'times': 2826, 'quantity': 1788, 'std_dev': 0.485},
#     '破损装置': {'times': 2826, 'quantity': 718, 'std_dev': 0.4353},
#     '酯原料': {'times': 2826, 'quantity': 1150, 'std_dev': 0.4913},
#     '代糖': {'times': 2826, 'quantity': 1194, 'std_dev': 0.4961}}},
#   'LE-2': {'stage_type': 'ACTIVITY',
#    'santity': 9,
#    'drop_info': {'破损装置': {'times': 1939, 'quantity': 462, 'std_dev': 0.426},
#     '酯原料': {'times': 1939, 'quantity': 822, 'std_dev': 0.4942},
#     '代糖': {'times': 1939, 'quantity': 809, 'std_dev': 0.4931},
#     '异铁碎片': {'times': 1939, 'quantity': 657, 'std_dev': 0.4733},
#     '双酮': {'times': 1939, 'quantity': 640, 'std_dev': 0.4702},
#     '家具': {'times': 1939, 'quantity': 19, 'std_dev': 0.0985},
#     '源岩': {'times': 1939, 'quantity': 1185, 'std_dev': 0.4875}}},
#   'LE-3': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'固源岩': {'times': 57798, 'quantity': 48029, 'std_dev': 0.3748},
#     '装置': {'times': 57798, 'quantity': 38432, 'std_dev': 0.472},
#     '家具': {'times': 57798, 'quantity': 700, 'std_dev': 0.1094}}},
#   'LE-4': {'stage_type': 'ACTIVITY',
#    'santity': 12,
#    'drop_info': {'糖': {'times': 2663, 'quantity': 1470, 'std_dev': 0.4973},
#     '异铁': {'times': 2663, 'quantity': 2360, 'std_dev': 0.3175},
#     '家具': {'times': 2663, 'quantity': 28, 'std_dev': 0.102}}},
#   'LE-5': {'stage_type': 'ACTIVITY',
#    'santity': 18,
#    'drop_info': {'糖组': {'times': 105968, 'quantity': 88277, 'std_dev': 0.3729},
#     '家具': {'times': 105968, 'quantity': 1772, 'std_dev': 0.1282}}},
#   'LE-6': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'家具': {'times': 511895, 'quantity': 10271, 'std_dev': 0.1402},
#     '研磨石': {'times': 511895, 'quantity': 346113, 'std_dev': 0.4679}}},
#   'LE-7': {'stage_type': 'ACTIVITY',
#    'santity': 21,
#    'drop_info': {'半自然溶剂': {'times': 128165,
#      'quantity': 89588,
#      'std_dev': 0.4587},
#     '家具': {'times': 128165, 'quantity': 2574, 'std_dev': 0.1403}}},
#   'LE-8': {'stage_type': 'ACTIVITY',
#    'santity': 10,
#    'drop_info': {'家具': {'times': 3250, 'quantity': 3, 'std_dev': 0.0304}}}}}

# %%
stage_id2matrix
# Out:
# {'act14side_05': {'家具': {'times': 236, 'quantity': 7, 'std_dev': 0.1697},
#   '聚酸酯': {'times': 236, 'quantity': 257, 'std_dev': 0.3391},
#   '糖': {'times': 236, 'quantity': 123, 'std_dev': 0.5244}},
#  'act18d0_07_perm': {'聚酸酯': {'times': 632, 'quantity': 59, 'std_dev': 0.2909},
#   '酮阵列': {'times': 632, 'quantity': 26, 'std_dev': 0.1986},
#   '酯原料': {'times': 632, 'quantity': 260, 'std_dev': 0.4921},
#   '研磨石': {'times': 632, 'quantity': 5, 'std_dev': 0.0886},
#   '双酮': {'times': 632, 'quantity': 210, 'std_dev': 0.471},
#   '晶体元件': {'times': 632, 'quantity': 4, 'std_dev': 0.0793},
#   'RMA70-12': {'times': 632, 'quantity': 8, 'std_dev': 0.1118},
#   '家具': {'times': 632, 'quantity': 0, 'std_dev': 0},
#   '酮凝集组': {'times': 632, 'quantity': 197, 'std_dev': 0.47},
#   '聚酸酯组': {'times': 632, 'quantity': 22, 'std_dev': 0.1833},
#   '酮凝集': {'times': 632, 'quantity': 54, 'std_dev': 0.2796}},
#  'act9d0_06_perm': {'糖': {'times': 2415, 'quantity': 335, 'std_dev': 0.3457},
#   '异铁': {'times': 2415, 'quantity': 268, 'std_dev': 0.3141},
#   '酮凝集': {'times': 2415, 'quantity': 252, 'std_dev': 0.3057},
#   '初级作战记录': {'times': 2415, 'quantity': 376, 'std_dev': 0.3625},
#   '家具': {'times': 2415, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 2415, 'quantity': 295, 'std_dev': 0.3275},
#   '糖组': {'times': 2415, 'quantity': 1125, 'std_dev': 0.4989},
#   '双酮': {'times': 2415, 'quantity': 282, 'std_dev': 0.3212},
#   '基础作战记录': {'times': 2415, 'quantity': 280, 'std_dev': 0.3228},
#   '代糖': {'times': 2415, 'quantity': 339, 'std_dev': 0.3474}},
#  'act16side_01': {'酯原料': {'times': 1782, 'quantity': 306, 'std_dev': 0.3771},
#   '代糖': {'times': 1782, 'quantity': 440, 'std_dev': 0.4312},
#   '异铁碎片': {'times': 1782, 'quantity': 235, 'std_dev': 0.3384},
#   '双酮': {'times': 1782, 'quantity': 470, 'std_dev': 0.4407},
#   '家具': {'times': 1782, 'quantity': 29, 'std_dev': 0.1265},
#   '源岩': {'times': 1782, 'quantity': 1070, 'std_dev': 0.4898},
#   '破损装置': {'times': 1782, 'quantity': 134, 'std_dev': 0.2679}},
#  'main_05-08': {'化合切削液': {'times': 999, 'quantity': 5, 'std_dev': 0.0706},
#   '酮凝集组': {'times': 10291, 'quantity': 3201, 'std_dev': 0.4717},
#   '聚酸酯': {'times': 10291, 'quantity': 1113, 'std_dev': 0.3106},
#   '罗德岛物资补给II': {'times': 14, 'quantity': 1, 'std_dev': 0.2575},
#   '应急理智小样': {'times': 6, 'quantity': 3, 'std_dev': 0.5},
#   '感谢庆典物资补给': {'times': 192, 'quantity': 35, 'std_dev': 0.3861},
#   '酮凝集': {'times': 10291, 'quantity': 952, 'std_dev': 0.2898},
#   '罗德岛物资补给': {'times': 294, 'quantity': 71, 'std_dev': 0.428},
#   '罗德岛物资补给III': {'times': 6, 'quantity': 1, 'std_dev': 0.3727},
#   '酯原料': {'times': 10291, 'quantity': 4220, 'std_dev': 0.4918},
#   '聚酸酯组': {'times': 10291, 'quantity': 177, 'std_dev': 0.13},
#   '32h战略配给': {'times': 1120, 'quantity': 236, 'std_dev': 0.4078},
#   '双酮': {'times': 10291, 'quantity': 3367, 'std_dev': 0.4692},
#   '研磨石': {'times': 10291, 'quantity': 123, 'std_dev': 0.1087},
#   'RMA70-12': {'times': 10291, 'quantity': 105, 'std_dev': 0.1005},
#   '岁过华灯': {'times': 683, 'quantity': 147, 'std_dev': 0.411},
#   '酮阵列': {'times': 10291, 'quantity': 346, 'std_dev': 0.1803},
#   '家具': {'times': 10291, 'quantity': 179, 'std_dev': 0.1307},
#   '晶体元件': {'times': 1622, 'quantity': 20, 'std_dev': 0.1104}},
#  'main_02-04': {'岁过华灯': {'times': 111, 'quantity': 18, 'std_dev': 0.3686},
#   '基础作战记录': {'times': 9336, 'quantity': 11544, 'std_dev': 0.4249},
#   '罗德岛物资补给': {'times': 215, 'quantity': 35, 'std_dev': 0.3692},
#   '家具': {'times': 9336, 'quantity': 136, 'std_dev': 0.1198},
#   '罗德岛物资补给II': {'times': 17, 'quantity': 2, 'std_dev': 0.3222},
#   '聚酸酯': {'times': 9336, 'quantity': 151, 'std_dev': 0.1261},
#   '酯原料': {'times': 9336, 'quantity': 2573, 'std_dev': 0.4468},
#   '32h战略配给': {'times': 53, 'quantity': 7, 'std_dev': 0.3386},
#   '破损装置': {'times': 9336, 'quantity': 1475, 'std_dev': 0.3647},
#   '源岩': {'times': 9336, 'quantity': 3809, 'std_dev': 0.4915},
#   '固源岩组': {'times': 9336, 'quantity': 3932, 'std_dev': 0.4938},
#   '应急理智小样': {'times': 85, 'quantity': 9, 'std_dev': 0.3077},
#   '装置': {'times': 9336, 'quantity': 124, 'std_dev': 0.1145},
#   '固源岩': {'times': 9336, 'quantity': 263, 'std_dev': 0.1654},
#   '罗德岛物资补给III': {'times': 85, 'quantity': 9, 'std_dev': 0.3077},
#   '赤金': {'times': 9336, 'quantity': 851, 'std_dev': 0.2878},
#   '感谢庆典物资补给': {'times': 129, 'quantity': 12, 'std_dev': 0.2905}},
#  'act16d5_03_rep': {'源岩': {'times': 45, 'quantity': 79, 'std_dev': 0.4298},
#   '家具': {'times': 45, 'quantity': 1, 'std_dev': 0.1474},
#   '异铁碎片': {'times': 45, 'quantity': 81, 'std_dev': 0.4}},
#  'act5d0_10_rep': {'初级作战记录': {'times': 8, 'quantity': 16, 'std_dev': 0.5},
#   '中级作战记录': {'times': 8, 'quantity': 22, 'std_dev': 0.433},
#   '家具': {'times': 8, 'quantity': 0, 'std_dev': 0}},
#  'act17side_10': {'化合切削液': {'times': 151203,
#    'quantity': 105855,
#    'std_dev': 0.4582},
#   '家具': {'times': 151203, 'quantity': 3439, 'std_dev': 0.1491}},
#  'act10mini_05': {'异铁': {'times': 379, 'quantity': 419, 'std_dev': 0.3072},
#   '酯原料': {'times': 379, 'quantity': 46, 'std_dev': 0.3266},
#   '固源岩': {'times': 379, 'quantity': 84, 'std_dev': 0.4153},
#   '破损装置': {'times': 379, 'quantity': 35, 'std_dev': 0.2895},
#   '赤金': {'times': 379, 'quantity': 48, 'std_dev': 0.3326},
#   '聚酸酯': {'times': 379, 'quantity': 49, 'std_dev': 0.3355},
#   '源岩': {'times': 379, 'quantity': 87, 'std_dev': 0.4205},
#   '装置': {'times': 379, 'quantity': 30, 'std_dev': 0.27},
#   '家具': {'times': 379, 'quantity': 6, 'std_dev': 0.1248}},
#  'main_04-01': {'全新装置': {'times': 528, 'quantity': 12, 'std_dev': 0.149},
#   '赤金': {'times': 528, 'quantity': 49, 'std_dev': 0.2902},
#   '岁过华灯': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 528, 'quantity': 52, 'std_dev': 0.298},
#   '32h战略配给': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '固源岩': {'times': 528, 'quantity': 141, 'std_dev': 0.4424},
#   '凝胶': {'times': 528, 'quantity': 12, 'std_dev': 0.149},
#   '半自然溶剂': {'times': 37, 'quantity': 1, 'std_dev': 0.1622},
#   '家具': {'times': 528, 'quantity': 17, 'std_dev': 0.1765},
#   '罗德岛物资补给II': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '固源岩组': {'times': 528, 'quantity': 26, 'std_dev': 0.2164},
#   '感谢庆典物资补给': {'times': 9, 'quantity': 1, 'std_dev': 0.3143},
#   '罗德岛物资补给': {'times': 1, 'quantity': 1, 'std_dev': 0},
#   '扭转醇': {'times': 528, 'quantity': 37, 'std_dev': 0.2553},
#   '源岩': {'times': 528, 'quantity': 122, 'std_dev': 0.4215},
#   '装置': {'times': 528, 'quantity': 53, 'std_dev': 0.3004}},
#  'main_01-12': {'家具': {'times': 4294, 'quantity': 44, 'std_dev': 0.1008},
#   '罗德岛物资补给': {'times': 90, 'quantity': 10, 'std_dev': 0.3143},
#   '32h战略配给': {'times': 72, 'quantity': 7, 'std_dev': 0.2963},
#   '源岩': {'times': 4294, 'quantity': 552, 'std_dev': 0.3347},
#   '罗德岛物资补给III': {'times': 6, 'quantity': 1, 'std_dev': 0.3727},
#   '装置': {'times': 4294, 'quantity': 2187, 'std_dev': 0.5},
#   '异铁碎片': {'times': 4294, 'quantity': 202, 'std_dev': 0.2117},
#   '应急理智小样': {'times': 6, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给II': {'times': 7, 'quantity': 2, 'std_dev': 0.4518},
#   '破损装置': {'times': 4294, 'quantity': 184, 'std_dev': 0.2025},
#   '代糖': {'times': 4294, 'quantity': 268, 'std_dev': 0.2418},
#   '酯原料': {'times': 4294, 'quantity': 282, 'std_dev': 0.2478},
#   '岁过华灯': {'times': 81, 'quantity': 9, 'std_dev': 0.3143},
#   '感谢庆典物资补给': {'times': 95, 'quantity': 11, 'std_dev': 0.32},
#   '基础作战记录': {'times': 4294, 'quantity': 5208, 'std_dev': 0.4093},
#   '双酮': {'times': 4294, 'quantity': 241, 'std_dev': 0.2303},
#   '赤金': {'times': 4294, 'quantity': 471, 'std_dev': 0.3125}},
#  'act16d5_08_rep': {'炽合金': {'times': 32914,
#    'quantity': 19288,
#    'std_dev': 0.4925},
#   '家具': {'times': 32914, 'quantity': 749, 'std_dev': 0.1491}},
#  'act10mini_04': {'异铁': {'times': 227, 'quantity': 1, 'std_dev': 0.0662},
#   '酯原料': {'times': 227, 'quantity': 79, 'std_dev': 0.4763},
#   '异铁碎片': {'times': 227, 'quantity': 53, 'std_dev': 0.4333},
#   '酮凝集': {'times': 227, 'quantity': 2, 'std_dev': 0.0935},
#   '初级作战记录': {'times': 227, 'quantity': 1, 'std_dev': 0.0662},
#   '破损装置': {'times': 227, 'quantity': 39, 'std_dev': 0.3772},
#   '双酮': {'times': 227, 'quantity': 69, 'std_dev': 0.46},
#   '源岩': {'times': 227, 'quantity': 185, 'std_dev': 0.3883},
#   '基础作战记录': {'times': 227, 'quantity': 16, 'std_dev': 0.256},
#   '糖': {'times': 227, 'quantity': 1, 'std_dev': 0.0662},
#   '家具': {'times': 227, 'quantity': 3, 'std_dev': 0.1142},
#   '代糖': {'times': 227, 'quantity': 89, 'std_dev': 0.5314}},
#  'act13d5_07': {'聚酸酯组': {'times': 5601, 'quantity': 4670, 'std_dev': 0.3723},
#   '家具': {'times': 5601, 'quantity': 130, 'std_dev': 0.1506}},
#  'main_04-10': {'32h战略配给': {'times': 1328, 'quantity': 310, 'std_dev': 0.423},
#   '应急理智小样': {'times': 46, 'quantity': 9, 'std_dev': 0.3967},
#   '赤金': {'times': 18072, 'quantity': 1809, 'std_dev': 0.3001},
#   '破损装置': {'times': 18072, 'quantity': 1547, 'std_dev': 0.2797},
#   '固源岩': {'times': 18072, 'quantity': 6473, 'std_dev': 0.4795},
#   '岁过华灯': {'times': 650, 'quantity': 167, 'std_dev': 0.4369},
#   '感谢庆典物资补给': {'times': 385, 'quantity': 82, 'std_dev': 0.4094},
#   '罗德岛物资补给II': {'times': 47, 'quantity': 13, 'std_dev': 0.4473},
#   '源岩': {'times': 18072, 'quantity': 3842, 'std_dev': 0.4091},
#   '改量装置': {'times': 18072, 'quantity': 576, 'std_dev': 0.1757},
#   '固源岩组': {'times': 18072, 'quantity': 602, 'std_dev': 0.1794},
#   '家具': {'times': 18072, 'quantity': 405, 'std_dev': 0.1481},
#   '罗德岛物资补给III': {'times': 46, 'quantity': 15, 'std_dev': 0.4688},
#   '凝胶': {'times': 18072, 'quantity': 364, 'std_dev': 0.1405},
#   '装置': {'times': 18072, 'quantity': 2595, 'std_dev': 0.3507},
#   '扭转醇': {'times': 18072, 'quantity': 493, 'std_dev': 0.1629},
#   '罗德岛物资补给': {'times': 1106, 'quantity': 293, 'std_dev': 0.4413},
#   '全新装置': {'times': 18072, 'quantity': 5437, 'std_dev': 0.4698}},
#  'act15d0_06_perm': {'代糖': {'times': 182, 'quantity': 25, 'std_dev': 0.3442},
#   '基础作战记录': {'times': 182, 'quantity': 12, 'std_dev': 0.2482},
#   '家具': {'times': 182, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 182, 'quantity': 24, 'std_dev': 0.3383},
#   '糖': {'times': 182, 'quantity': 21, 'std_dev': 0.3195},
#   '初级作战记录': {'times': 182, 'quantity': 27, 'std_dev': 0.3554},
#   '糖组': {'times': 182, 'quantity': 82, 'std_dev': 0.4975},
#   '双酮': {'times': 182, 'quantity': 24, 'std_dev': 0.3383},
#   '酮凝集': {'times': 182, 'quantity': 25, 'std_dev': 0.3442},
#   '异铁': {'times': 182, 'quantity': 24, 'std_dev': 0.3383}},
#  'act18side_01': {'异铁碎片': {'times': 2826, 'quantity': 946, 'std_dev': 0.4719},
#   '双酮': {'times': 2826, 'quantity': 879, 'std_dev': 0.4629},
#   '家具': {'times': 2826, 'quantity': 29, 'std_dev': 0.1008},
#   '源岩': {'times': 2826, 'quantity': 1788, 'std_dev': 0.485},
#   '破损装置': {'times': 2826, 'quantity': 718, 'std_dev': 0.4353},
#   '酯原料': {'times': 2826, 'quantity': 1150, 'std_dev': 0.4913},
#   '代糖': {'times': 2826, 'quantity': 1194, 'std_dev': 0.4961}},
#  'main_07-09': {'应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '32h战略配给': {'times': 11, 'quantity': 1, 'std_dev': 0.2875},
#   '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给III': {'times': 2, 'quantity': 2, 'std_dev': 0},
#   '异铁': {'times': 83, 'quantity': 64, 'std_dev': 0.4201},
#   '中级作战记录': {'times': 83, 'quantity': 92, 'std_dev': 0.311},
#   '家具': {'times': 83, 'quantity': 0, 'std_dev': 0}},
#  'act15d0_08_perm': {'异铁碎片': {'times': 370, 'quantity': 63, 'std_dev': 0.3759},
#   '糖': {'times': 370, 'quantity': 69, 'std_dev': 0.3895},
#   '炽合金': {'times': 370, 'quantity': 3, 'std_dev': 0.0897},
#   '中级作战记录': {'times': 370, 'quantity': 31, 'std_dev': 0.2771},
#   '家具': {'times': 370, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 370, 'quantity': 36, 'std_dev': 0.2964},
#   '异铁': {'times': 370, 'quantity': 58, 'std_dev': 0.3636},
#   '轻锰矿': {'times': 370, 'quantity': 6, 'std_dev': 0.1263},
#   '初级作战记录': {'times': 370, 'quantity': 30, 'std_dev': 0.273},
#   '糖组': {'times': 370, 'quantity': 3, 'std_dev': 0.0897},
#   '异铁组': {'times': 370, 'quantity': 107, 'std_dev': 0.4652},
#   '异铁块': {'times': 370, 'quantity': 12, 'std_dev': 0.1771},
#   '代糖': {'times': 370, 'quantity': 67, 'std_dev': 0.3851}},
#  'act11d0_05_perm': {'源岩': {'times': 11, 'quantity': 2, 'std_dev': 0.3857},
#   '酯原料': {'times': 11, 'quantity': 5, 'std_dev': 0.4979},
#   '破损装置': {'times': 11, 'quantity': 0, 'std_dev': 0},
#   '赤金': {'times': 11, 'quantity': 2, 'std_dev': 0.3857},
#   '固源岩': {'times': 11, 'quantity': 2, 'std_dev': 0.3857},
#   '聚酸酯': {'times': 11, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 11, 'quantity': 8, 'std_dev': 0.4454},
#   '家具': {'times': 11, 'quantity': 0, 'std_dev': 0}},
#  'act18d0_02_rep': {'源岩': {'times': 15, 'quantity': 0, 'std_dev': 0},
#   '代糖': {'times': 15, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 15, 'quantity': 0, 'std_dev': 0},
#   '双酮': {'times': 15, 'quantity': 10, 'std_dev': 0.4714},
#   '异铁碎片': {'times': 15, 'quantity': 9, 'std_dev': 0.4899},
#   '酯原料': {'times': 15, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 15, 'quantity': 2, 'std_dev': 0.3399}},
#  'main_08-02': {'异铁组': {'times': 4738, 'quantity': 63, 'std_dev': 0.1146},
#   '家具': {'times': 4738, 'quantity': 95, 'std_dev': 0.1402},
#   '糖组': {'times': 4738, 'quantity': 83, 'std_dev': 0.1312},
#   '基础作战记录': {'times': 4738, 'quantity': 513, 'std_dev': 0.3107},
#   '初级作战记录': {'times': 4738, 'quantity': 457, 'std_dev': 0.2952},
#   '炽合金': {'times': 4738, 'quantity': 55, 'std_dev': 0.1072},
#   '异铁': {'times': 4738, 'quantity': 719, 'std_dev': 0.3588},
#   '中级作战记录': {'times': 4738, 'quantity': 420, 'std_dev': 0.2843},
#   '代糖': {'times': 4738, 'quantity': 811, 'std_dev': 0.3766},
#   '罗德岛物资补给II': {'times': 458, 'quantity': 96, 'std_dev': 0.407},
#   '白马醇': {'times': 4738, 'quantity': 221, 'std_dev': 0.2109},
#   '异铁碎片': {'times': 4738, 'quantity': 675, 'std_dev': 0.3495},
#   '糖': {'times': 4738, 'quantity': 886, 'std_dev': 0.3899},
#   '扭转醇': {'times': 4738, 'quantity': 1673, 'std_dev': 0.4779},
#   '轻锰矿': {'times': 4738, 'quantity': 56, 'std_dev': 0.1081},
#   '感谢庆典物资补给': {'times': 144, 'quantity': 30, 'std_dev': 0.4061}},
#  'main_06-05': {'家具': {'times': 20033, 'quantity': 480, 'std_dev': 0.153},
#   '应急理智小样': {'times': 54, 'quantity': 12, 'std_dev': 0.4157},
#   '罗德岛物资补给': {'times': 4592, 'quantity': 950, 'std_dev': 0.4051},
#   '聚酸酯': {'times': 20033, 'quantity': 14499, 'std_dev': 0.9236},
#   '固源岩组': {'times': 20033, 'quantity': 12100, 'std_dev': 0.4891},
#   '岁过华灯': {'times': 643, 'quantity': 144, 'std_dev': 0.4169},
#   '32h战略配给': {'times': 565, 'quantity': 111, 'std_dev': 0.3973},
#   '罗德岛物资补给III': {'times': 54, 'quantity': 15, 'std_dev': 0.4479},
#   '感谢庆典物资补给': {'times': 225, 'quantity': 42, 'std_dev': 0.3896},
#   '罗德岛物资补给II': {'times': 118, 'quantity': 24, 'std_dev': 0.4025}},
#  'act17side_09': {'轻锰矿': {'times': 377968,
#    'quantity': 293869,
#    'std_dev': 0.4159},
#   '家具': {'times': 377968, 'quantity': 8321, 'std_dev': 0.1467}},
#  'pro_b_2': {'狙击芯片组': {'times': 22894, 'quantity': 11476, 'std_dev': 0.5},
#   '术师芯片组': {'times': 22894, 'quantity': 11418, 'std_dev': 0.5},
#   '罗德岛物资补给II': {'times': 83, 'quantity': 29, 'std_dev': 0.4768},
#   '罗德岛物资补给III': {'times': 76, 'quantity': 28, 'std_dev': 0.4824},
#   '家具': {'times': 23372, 'quantity': 3, 'std_dev': 0.0113},
#   '应急理智小样': {'times': 76, 'quantity': 28, 'std_dev': 0.4824},
#   '32h战略配给': {'times': 453, 'quantity': 197, 'std_dev': 0.4957},
#   '感谢庆典物资补给': {'times': 144, 'quantity': 61, 'std_dev': 0.4941}},
#  'tough_10-03': {'酮凝集组': {'times': 4394, 'quantity': 2378, 'std_dev': 0.4983},
#   '家具': {'times': 4394, 'quantity': 113, 'std_dev': 0.1583},
#   '应急理智小样': {'times': 368, 'quantity': 72, 'std_dev': 0.3967},
#   '罗德岛物资补给III': {'times': 368, 'quantity': 88, 'std_dev': 0.4266},
#   '装置': {'times': 4394, 'quantity': 2069, 'std_dev': 0.5219}},
#  'wk_armor_5': {'碳素组': {'times': 4380, 'quantity': 13137, 'std_dev': 0.0453},
#   '家具': {'times': 4380, 'quantity': 237, 'std_dev': 0.2262},
#   '罗德岛物资补给III': {'times': 6, 'quantity': 2, 'std_dev': 0.4714},
#   '应急理智小样': {'times': 6, 'quantity': 3, 'std_dev': 0.5},
#   '罗德岛物资补给': {'times': 55, 'quantity': 19, 'std_dev': 0.4755},
#   '碳素': {'times': 4380, 'quantity': 2187, 'std_dev': 0.5},
#   '罗德岛物资补给II': {'times': 21, 'quantity': 8, 'std_dev': 0.4856},
#   '岁过华灯': {'times': 34, 'quantity': 14, 'std_dev': 0.4922},
#   '32h战略配给': {'times': 60, 'quantity': 26, 'std_dev': 0.4955}},
#  'pro_a_2': {'罗德岛物资补给II': {'times': 41, 'quantity': 20, 'std_dev': 0.4999},
#   '罗德岛物资补给III': {'times': 130, 'quantity': 45, 'std_dev': 0.4757},
#   '家具': {'times': 26611, 'quantity': 7, 'std_dev': 0.0162},
#   '应急理智小样': {'times': 130, 'quantity': 49, 'std_dev': 0.4846},
#   '32h战略配给': {'times': 178, 'quantity': 70, 'std_dev': 0.4885},
#   '感谢庆典物资补给': {'times': 162, 'quantity': 71, 'std_dev': 0.4962},
#   '重装芯片组': {'times': 26377, 'quantity': 13130, 'std_dev': 0.5},
#   '医疗芯片组': {'times': 26377, 'quantity': 13247, 'std_dev': 0.5}},
#  'act18d3_06': {'家具': {'times': 644, 'quantity': 14, 'std_dev': 0.1458},
#   '异铁': {'times': 644, 'quantity': 587, 'std_dev': 0.284},
#   '固源岩': {'times': 644, 'quantity': 565, 'std_dev': 0.3328}},
#  'act16d5_01_perm': {'双酮': {'times': 8, 'quantity': 2, 'std_dev': 0.433},
#   '破损装置': {'times': 8, 'quantity': 1, 'std_dev': 0.3307},
#   '家具': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 8, 'quantity': 5, 'std_dev': 0.4841},
#   '酯原料': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '赤金': {'times': 8, 'quantity': 3, 'std_dev': 0.4841},
#   '源岩': {'times': 8, 'quantity': 2, 'std_dev': 0.433},
#   '代糖': {'times': 8, 'quantity': 0, 'std_dev': 0}},
#  'act11d0_07_rep': {'酮凝集组': {'times': 9507,
#    'quantity': 6407,
#    'std_dev': 0.4688},
#   '家具': {'times': 9507, 'quantity': 217, 'std_dev': 0.1493}},
#  'act18d3_02': {'异铁碎片': {'times': 95, 'quantity': 50, 'std_dev': 0.4993},
#   '双酮': {'times': 95, 'quantity': 39, 'std_dev': 0.4919},
#   '代糖': {'times': 95, 'quantity': 58, 'std_dev': 0.4876},
#   '源岩': {'times': 95, 'quantity': 78, 'std_dev': 0.3833},
#   '家具': {'times': 95, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 95, 'quantity': 44, 'std_dev': 0.4986},
#   '破损装置': {'times': 95, 'quantity': 31, 'std_dev': 0.4689}},
#  'act10mini_07': {'凝胶': {'times': 7149, 'quantity': 142, 'std_dev': 0.1395},
#   '聚酸酯组': {'times': 7149, 'quantity': 4615, 'std_dev': 0.4783},
#   '固源岩组': {'times': 7149, 'quantity': 222, 'std_dev': 0.1735},
#   '赤金': {'times': 7149, 'quantity': 739, 'std_dev': 0.3044},
#   '家具': {'times': 7149, 'quantity': 182, 'std_dev': 0.1575},
#   '全新装置': {'times': 7149, 'quantity': 136, 'std_dev': 0.1366},
#   '固源岩': {'times': 7149, 'quantity': 2536, 'std_dev': 0.4784},
#   '装置': {'times': 7149, 'quantity': 1041, 'std_dev': 0.3527},
#   '扭转醇': {'times': 7149, 'quantity': 189, 'std_dev': 0.1604},
#   '破损装置': {'times': 7149, 'quantity': 527, 'std_dev': 0.2613},
#   '源岩': {'times': 7149, 'quantity': 1501, 'std_dev': 0.4073}},
#  'sub_05-3-1': {'感谢庆典物资补给': {'times': 1, 'quantity': 1, 'std_dev': 0},
#   '装置': {'times': 357, 'quantity': 239, 'std_dev': 0.4704},
#   '罗德岛物资补给': {'times': 3, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 357, 'quantity': 6, 'std_dev': 0.1286}},
#  'main_06-13': {'酯原料': {'times': 3258, 'quantity': 1028, 'std_dev': 0.4647},
#   '酮凝集': {'times': 3258, 'quantity': 232, 'std_dev': 0.2572},
#   'RMA70-12': {'times': 3258, 'quantity': 568, 'std_dev': 0.3889},
#   '聚酸酯组': {'times': 3258, 'quantity': 45, 'std_dev': 0.1167},
#   '罗德岛物资补给': {'times': 145, 'quantity': 20, 'std_dev': 0.3448},
#   '酮凝集组': {'times': 3258, 'quantity': 49, 'std_dev': 0.1217},
#   '聚酸酯': {'times': 3258, 'quantity': 991, 'std_dev': 0.4602},
#   '化合切削液': {'times': 1070, 'quantity': 10, 'std_dev': 0.0962},
#   '32h战略配给': {'times': 117, 'quantity': 21, 'std_dev': 0.3838},
#   '岁过华灯': {'times': 113, 'quantity': 19, 'std_dev': 0.374},
#   '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 3258, 'quantity': 48, 'std_dev': 0.1205},
#   '双酮': {'times': 3258, 'quantity': 811, 'std_dev': 0.4325},
#   '研磨石': {'times': 3258, 'quantity': 26, 'std_dev': 0.0889},
#   '感谢庆典物资补给': {'times': 1, 'quantity': 1, 'std_dev': 0},
#   'RMA70-24': {'times': 3258, 'quantity': 81, 'std_dev': 0.1558},
#   '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '晶体元件': {'times': 1184, 'quantity': 15, 'std_dev': 0.1119}},
#  'sub_03-2-1': {'酮凝集': {'times': 16126, 'quantity': 1675, 'std_dev': 0.3052},
#   '岁过华灯': {'times': 246, 'quantity': 41, 'std_dev': 0.3727},
#   '异铁碎片': {'times': 16126, 'quantity': 1946, 'std_dev': 0.3258},
#   '糖': {'times': 16126, 'quantity': 2083, 'std_dev': 0.3353},
#   '代糖': {'times': 16126, 'quantity': 2447, 'std_dev': 0.3588},
#   '罗德岛物资补给': {'times': 486, 'quantity': 86, 'std_dev': 0.3816},
#   '初级作战记录': {'times': 16126, 'quantity': 2445, 'std_dev': 0.3587},
#   '感谢庆典物资补给': {'times': 149, 'quantity': 23, 'std_dev': 0.3613},
#   '双酮': {'times': 16126, 'quantity': 1929, 'std_dev': 0.3245},
#   '应急理智小样': {'times': 170, 'quantity': 27, 'std_dev': 0.3655},
#   '罗德岛物资补给II': {'times': 70, 'quantity': 12, 'std_dev': 0.3769},
#   '32h战略配给': {'times': 41, 'quantity': 5, 'std_dev': 0.3272},
#   '基础作战记录': {'times': 16126, 'quantity': 1646, 'std_dev': 0.3027},
#   '罗德岛物资补给III': {'times': 170, 'quantity': 29, 'std_dev': 0.3761},
#   '异铁': {'times': 16126, 'quantity': 19780, 'std_dev': 0.4487},
#   '家具': {'times': 16126, 'quantity': 289, 'std_dev': 0.1326}},
#  'a001_06': {'研磨石': {'times': 10649, 'quantity': 5208, 'std_dev': 0.4999},
#   '家具': {'times': 10649, 'quantity': 350, 'std_dev': 0.1783}},
#  'main_09-15': {'源岩': {'times': 1911, 'quantity': 569, 'std_dev': 0.4573},
#   '装置': {'times': 1911, 'quantity': 222, 'std_dev': 0.3204},
#   '扭转醇': {'times': 1911, 'quantity': 29, 'std_dev': 0.1223},
#   '赤金': {'times': 1911, 'quantity': 179, 'std_dev': 0.2913},
#   '罗德岛物资补给III': {'times': 3, 'quantity': 0, 'std_dev': 0},
#   '固源岩组': {'times': 1911, 'quantity': 32, 'std_dev': 0.1283},
#   '异铁组': {'times': 1911, 'quantity': 564, 'std_dev': 0.4561},
#   '异铁块': {'times': 1911, 'quantity': 61, 'std_dev': 0.1758},
#   '罗德岛物资补给II': {'times': 235, 'quantity': 45, 'std_dev': 0.3935},
#   '半自然溶剂': {'times': 1911, 'quantity': 16, 'std_dev': 0.0911},
#   '全新装置': {'times': 1911, 'quantity': 18, 'std_dev': 0.0966},
#   '凝胶': {'times': 1911, 'quantity': 25, 'std_dev': 0.1136},
#   '应急理智小样': {'times': 3, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 1911, 'quantity': 226, 'std_dev': 0.3229},
#   '固源岩': {'times': 1911, 'quantity': 595, 'std_dev': 0.463},
#   '家具': {'times': 1911, 'quantity': 29, 'std_dev': 0.1223}},
#  'tough_10-15': {'家具': {'times': 648, 'quantity': 15, 'std_dev': 0.1504},
#   '应急理智小样': {'times': 430, 'quantity': 94, 'std_dev': 0.4133},
#   '赤金': {'times': 648, 'quantity': 78, 'std_dev': 0.3254},
#   '破损装置': {'times': 648, 'quantity': 38, 'std_dev': 0.2349},
#   '罗德岛物资补给III': {'times': 430, 'quantity': 105, 'std_dev': 0.4296},
#   '化合切削液': {'times': 648, 'quantity': 343, 'std_dev': 0.4991},
#   '源岩': {'times': 648, 'quantity': 133, 'std_dev': 0.4038},
#   '凝胶': {'times': 648, 'quantity': 25, 'std_dev': 0.1926},
#   '固源岩': {'times': 648, 'quantity': 213, 'std_dev': 0.4697},
#   '装置': {'times': 648, 'quantity': 81, 'std_dev': 0.3307},
#   '全新装置': {'times': 648, 'quantity': 16, 'std_dev': 0.1552},
#   '固源岩组': {'times': 648, 'quantity': 32, 'std_dev': 0.2166},
#   '扭转醇': {'times': 648, 'quantity': 32, 'std_dev': 0.2167}},
#  'act15d0_01': {'代糖': {'times': 68, 'quantity': 110, 'std_dev': 0.486},
#   '破损装置': {'times': 68, 'quantity': 31, 'std_dev': 0.498},
#   '家具': {'times': 68, 'quantity': 2, 'std_dev': 0.169}},
#  'act9d0_04_perm': {'异铁碎片': {'times': 16, 'quantity': 26, 'std_dev': 0.4841},
#   '双酮': {'times': 16, 'quantity': 4, 'std_dev': 0.433},
#   '糖': {'times': 16, 'quantity': 0, 'std_dev': 0},
#   '初级作战记录': {'times': 16, 'quantity': 2, 'std_dev': 0.3307},
#   '基础作战记录': {'times': 16, 'quantity': 20, 'std_dev': 0.559},
#   '代糖': {'times': 16, 'quantity': 5, 'std_dev': 0.4635},
#   '异铁': {'times': 16, 'quantity': 0, 'std_dev': 0},
#   '酮凝集': {'times': 16, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 16, 'quantity': 0, 'std_dev': 0}},
#  'main_05-02': {'源岩': {'times': 1643, 'quantity': 482, 'std_dev': 0.4553},
#   '糖聚块': {'times': 1643, 'quantity': 63, 'std_dev': 0.192},
#   '扭转醇': {'times': 1643, 'quantity': 19, 'std_dev': 0.1069},
#   '装置': {'times': 1643, 'quantity': 218, 'std_dev': 0.3393},
#   '固源岩': {'times': 1643, 'quantity': 516, 'std_dev': 0.4641},
#   '破损装置': {'times': 1643, 'quantity': 188, 'std_dev': 0.3182},
#   '固源岩组': {'times': 1643, 'quantity': 24, 'std_dev': 0.12},
#   '应急理智小样': {'times': 3, 'quantity': 1, 'std_dev': 0.4714},
#   '感谢庆典物资补给': {'times': 43, 'quantity': 9, 'std_dev': 0.4068},
#   '全新装置': {'times': 1643, 'quantity': 16, 'std_dev': 0.0982},
#   '赤金': {'times': 1643, 'quantity': 158, 'std_dev': 0.2947},
#   '32h战略配给': {'times': 37, 'quantity': 8, 'std_dev': 0.4117},
#   '罗德岛物资补给': {'times': 7, 'quantity': 2, 'std_dev': 0.4518},
#   '岁过华灯': {'times': 50, 'quantity': 11, 'std_dev': 0.4142},
#   '半自然溶剂': {'times': 583, 'quantity': 8, 'std_dev': 0.1163},
#   '家具': {'times': 1643, 'quantity': 27, 'std_dev': 0.1271},
#   '糖组': {'times': 1643, 'quantity': 590, 'std_dev': 0.4798},
#   '凝胶': {'times': 1643, 'quantity': 18, 'std_dev': 0.1041},
#   '罗德岛物资补给II': {'times': 17, 'quantity': 2, 'std_dev': 0.3222},
#   '罗德岛物资补给III': {'times': 3, 'quantity': 0, 'std_dev': 0}},
#  'wk_kc_6': {'中级作战记录': {'times': 75146, 'quantity': 150292, 'std_dev': 0},
#   '家具': {'times': 75146, 'quantity': 2779, 'std_dev': 0.1887},
#   '高级作战记录': {'times': 75146, 'quantity': 300584, 'std_dev': 0}},
#  'act18d3_05': {'聚酸酯': {'times': 343, 'quantity': 387, 'std_dev': 0.343},
#   '糖': {'times': 343, 'quantity': 203, 'std_dev': 0.4974},
#   '家具': {'times': 343, 'quantity': 4, 'std_dev': 0.1074}},
#  'act12d0_01_perm': {'赤金': {'times': 8, 'quantity': 1, 'std_dev': 0.3307},
#   '源岩': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 8, 'quantity': 2, 'std_dev': 0.433},
#   '异铁碎片': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '双酮': {'times': 8, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 8, 'quantity': 5, 'std_dev': 0.4841},
#   '糖': {'times': 8, 'quantity': 6, 'std_dev': 0.433},
#   '代糖': {'times': 8, 'quantity': 0, 'std_dev': 0}},
#  'wk_fly_4': {'家具': {'times': 552, 'quantity': 19, 'std_dev': 0.1824},
#   '罗德岛物资补给II': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给': {'times': 11, 'quantity': 4, 'std_dev': 0.481},
#   '岁过华灯': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '技巧概要·卷3': {'times': 552, 'quantity': 898, 'std_dev': 0.4835},
#   '技巧概要·卷2': {'times': 552, 'quantity': 552, 'std_dev': 0},
#   '技巧概要·卷1': {'times': 552, 'quantity': 552, 'std_dev': 0},
#   '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0}},
#  'main_09-16': {'半自然溶剂': {'times': 17145, 'quantity': 5647, 'std_dev': 0.47},
#   '罗德岛物资补给II': {'times': 11498, 'quantity': 2758, 'std_dev': 0.427},
#   '异铁': {'times': 17145, 'quantity': 2768, 'std_dev': 0.368},
#   '基础作战记录': {'times': 17145, 'quantity': 1734, 'std_dev': 0.3015},
#   '初级作战记录': {'times': 17145, 'quantity': 2689, 'std_dev': 0.3636},
#   '炽合金': {'times': 17145, 'quantity': 446, 'std_dev': 0.1591},
#   '糖': {'times': 17145, 'quantity': 3423, 'std_dev': 0.3997},
#   '代糖': {'times': 17145, 'quantity': 1947, 'std_dev': 0.3173},
#   '罗德岛物资补给III': {'times': 24, 'quantity': 5, 'std_dev': 0.4061},
#   '异铁碎片': {'times': 17145, 'quantity': 1620, 'std_dev': 0.2925},
#   '糖组': {'times': 17145, 'quantity': 505, 'std_dev': 0.169},
#   '家具': {'times': 17145, 'quantity': 308, 'std_dev': 0.1328},
#   '精炼溶剂': {'times': 17145, 'quantity': 851, 'std_dev': 0.2172},
#   '异铁组': {'times': 17145, 'quantity': 398, 'std_dev': 0.1506},
#   '应急理智小样': {'times': 24, 'quantity': 9, 'std_dev': 0.4841},
#   '轻锰矿': {'times': 17145, 'quantity': 447, 'std_dev': 0.1594},
#   '中级作战记录': {'times': 17145, 'quantity': 1168, 'std_dev': 0.252}},
#  'act9d0_04_rep': {'家具': {'times': 54, 'quantity': 2, 'std_dev': 0.1889},
#   '固源岩': {'times': 54, 'quantity': 87, 'std_dev': 0.4875},
#   '异铁': {'times': 54, 'quantity': 19, 'std_dev': 0.4775}},
#  'act15d5_01': {'赤金': {'times': 48, 'quantity': 8, 'std_dev': 0.3727},
#   '家具': {'times': 48, 'quantity': 2, 'std_dev': 0.1998},
#   '源岩': {'times': 48, 'quantity': 2, 'std_dev': 0.1998},
#   '代糖': {'times': 48, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 48, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 48, 'quantity': 0, 'std_dev': 0},
#   '双酮': {'times': 48, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 48, 'quantity': 34, 'std_dev': 0.5385}},
#  'act13side_04': {'固源岩': {'times': 448, 'quantity': 386, 'std_dev': 0.3517},
#   '家具': {'times': 448, 'quantity': 10, 'std_dev': 0.1477},
#   '聚酸酯': {'times': 448, 'quantity': 485, 'std_dev': 0.2986}},
#  'a003_03': {'汐斯塔的黑曜石': {'times': 23, 'quantity': 368, 'std_dev': 0},
#   '黑曜石节门票': {'times': 23, 'quantity': 92, 'std_dev': 0},
#   '家具': {'times': 23, 'quantity': 0, 'std_dev': 0}},
#  'main_06-14': {'罗德岛物资补给': {'times': 2104, 'quantity': 525, 'std_dev': 0.4327},
#   '岁过华灯': {'times': 930, 'quantity': 252, 'std_dev': 0.4445},
#   '全新装置': {'times': 10742, 'quantity': 3355, 'std_dev': 0.4634},
#   '罗德岛物资补给III': {'times': 13, 'quantity': 1, 'std_dev': 0.2665},
#   '家具': {'times': 10742, 'quantity': 202, 'std_dev': 0.1359},
#   '应急理智小样': {'times': 13, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给II': {'times': 6, 'quantity': 2, 'std_dev': 0.4714},
#   '32h战略配给': {'times': 660, 'quantity': 150, 'std_dev': 0.4191},
#   '感谢庆典物资补给': {'times': 267, 'quantity': 65, 'std_dev': 0.4292},
#   '酮凝集': {'times': 10742, 'quantity': 10754, 'std_dev': 0.7902}},
#  'act17side_08_perm': {'家具': {'times': 506, 'quantity': 0, 'std_dev': 0},
#   '固源岩': {'times': 506, 'quantity': 184, 'std_dev': 0.481},
#   '破损装置': {'times': 506, 'quantity': 41, 'std_dev': 0.2729},
#   '异铁组': {'times': 506, 'quantity': 182, 'std_dev': 0.4799},
#   '异铁块': {'times': 506, 'quantity': 22, 'std_dev': 0.2039},
#   '固源岩组': {'times': 506, 'quantity': 14, 'std_dev': 0.164},
#   '凝胶': {'times': 506, 'quantity': 8, 'std_dev': 0.1247},
#   '扭转醇': {'times': 506, 'quantity': 25, 'std_dev': 0.2167},
#   '赤金': {'times': 506, 'quantity': 37, 'std_dev': 0.2603},
#   '源岩': {'times': 506, 'quantity': 103, 'std_dev': 0.4026},
#   '装置': {'times': 506, 'quantity': 85, 'std_dev': 0.3739},
#   '全新装置': {'times': 506, 'quantity': 9, 'std_dev': 0.1322}},
#  'main_00-07': {'代糖': {'times': 437, 'quantity': 489, 'std_dev': 0.3309},
#   '家具': {'times': 437, 'quantity': 2, 'std_dev': 0.0676},
#   '异铁碎片': {'times': 437, 'quantity': 5, 'std_dev': 0.1064},
#   '双酮': {'times': 437, 'quantity': 7, 'std_dev': 0.1255},
#   '岁过华灯': {'times': 12, 'quantity': 2, 'std_dev': 0.3727},
#   '罗德岛物资补给': {'times': 6, 'quantity': 1, 'std_dev': 0.3727},
#   '基础作战记录': {'times': 437, 'quantity': 547, 'std_dev': 0.4341},
#   '赤金': {'times': 437, 'quantity': 34, 'std_dev': 0.2679},
#   '32h战略配给': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 437, 'quantity': 3, 'std_dev': 0.0826},
#   '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '源岩': {'times': 437, 'quantity': 16, 'std_dev': 0.1878},
#   '酯原料': {'times': 437, 'quantity': 9, 'std_dev': 0.142}},
#  'act18d0_04_rep': {'异铁': {'times': 3067, 'quantity': 2781, 'std_dev': 0.2908},
#   '家具': {'times': 3067, 'quantity': 44, 'std_dev': 0.1189},
#   '固源岩': {'times': 3067, 'quantity': 2622, 'std_dev': 0.355}},
#  'randomMaterialRune_1': {'异铁组': {'times': 8934,
#    'quantity': 780,
#    'std_dev': 0.5105},
#   '扭转醇': {'times': 8934, 'quantity': 861, 'std_dev': 0.5911},
#   '轻锰矿': {'times': 8934, 'quantity': 781, 'std_dev': 0.5335},
#   '凝胶': {'times': 8934, 'quantity': 629, 'std_dev': 0.4459},
#   '糖组': {'times': 8934, 'quantity': 833, 'std_dev': 0.5663},
#   '酮凝集组': {'times': 8934, 'quantity': 698, 'std_dev': 0.4871},
#   '研磨石': {'times': 8934, 'quantity': 631, 'std_dev': 0.4814},
#   'RMA70-12': {'times': 8934, 'quantity': 547, 'std_dev': 0.393},
#   '炽合金': {'times': 8934, 'quantity': 769, 'std_dev': 0.5188},
#   '固源岩组': {'times': 8934, 'quantity': 1025, 'std_dev': 0.6591},
#   '家具': {'times': 8934, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯组': {'times': 8934, 'quantity': 852, 'std_dev': 0.5665},
#   '全新装置': {'times': 8934, 'quantity': 528, 'std_dev': 0.3857}},
#  'act15d0_08': {'异铁组': {'times': 14532, 'quantity': 9774, 'std_dev': 0.4693},
#   '家具': {'times': 14532, 'quantity': 524, 'std_dev': 0.1864}},
#  'act5d0_01_rep': {'家具': {'times': 4, 'quantity': 1, 'std_dev': 0.433}},
#  'act14side_07': {'聚酸酯组': {'times': 6057, 'quantity': 5091, 'std_dev': 0.3661},
#   '家具': {'times': 6057, 'quantity': 141, 'std_dev': 0.1508}},
#  'main_07-03': {'异铁碎片': {'times': 10066, 'quantity': 1353, 'std_dev': 0.3411},
#   '应急理智小样': {'times': 9, 'quantity': 0, 'std_dev': 0},
#   '轻锰矿': {'times': 10066, 'quantity': 159, 'std_dev': 0.1247},
#   '聚酸酯组': {'times': 10066, 'quantity': 5566, 'std_dev': 0.4972},
#   '炽合金': {'times': 10066, 'quantity': 157, 'std_dev': 0.1239},
#   '感谢庆典物资补给': {'times': 65, 'quantity': 13, 'std_dev': 0.4},
#   '初级作战记录': {'times': 10066, 'quantity': 984, 'std_dev': 0.297},
#   '罗德岛物资补给III': {'times': 9, 'quantity': 3, 'std_dev': 0.4714},
#   '糖': {'times': 10066, 'quantity': 1979, 'std_dev': 0.3974},
#   '糖组': {'times': 10066, 'quantity': 178, 'std_dev': 0.1318},
#   '异铁': {'times': 10066, 'quantity': 1510, 'std_dev': 0.3572},
#   '中级作战记录': {'times': 10066, 'quantity': 934, 'std_dev': 0.2901},
#   '基础作战记录': {'times': 10066, 'quantity': 999, 'std_dev': 0.299},
#   '家具': {'times': 10066, 'quantity': 199, 'std_dev': 0.1391},
#   '罗德岛物资补给II': {'times': 129, 'quantity': 21, 'std_dev': 0.3692},
#   '异铁组': {'times': 10066, 'quantity': 145, 'std_dev': 0.1192},
#   '代糖': {'times': 10066, 'quantity': 1667, 'std_dev': 0.3717},
#   '32h战略配给': {'times': 2237, 'quantity': 473, 'std_dev': 0.4083}},
#  'act14side_08': {'研磨石': {'times': 64657,
#    'quantity': 36646,
#    'std_dev': 0.4955},
#   '家具': {'times': 64657, 'quantity': 1691, 'std_dev': 0.1596}},
#  'act12d0_02_perm': {'破损装置': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 5, 'quantity': 4, 'std_dev': 0.4},
#   '源岩': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '赤金': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 5, 'quantity': 5, 'std_dev': 0},
#   '代糖': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '双酮': {'times': 5, 'quantity': 0, 'std_dev': 0}},
#  'act5d0_06': {'初级作战记录': {'times': 3, 'quantity': 15, 'std_dev': 0},
#   '家具': {'times': 3, 'quantity': 0, 'std_dev': 0}},
#  'act9d0_03': {'异铁碎片': {'times': 89, 'quantity': 157, 'std_dev': 0.4246},
#   '双酮': {'times': 89, 'quantity': 78, 'std_dev': 0.3291},
#   '家具': {'times': 89, 'quantity': 2, 'std_dev': 0.1482}},
#  'act18d0_05_perm': {'源岩': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '固源岩': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 2, 'quantity': 1, 'std_dev': 0.5},
#   '赤金': {'times': 2, 'quantity': 1, 'std_dev': 0.5},
#   '基础作战记录': {'times': 2, 'quantity': 0, 'std_dev': 0}},
#  'main_07-13': {'炽合金': {'times': 60898, 'quantity': 892, 'std_dev': 0.1201},
#   '糖组': {'times': 60898, 'quantity': 989, 'std_dev': 0.1264},
#   '全新装置': {'times': 60898, 'quantity': 20291, 'std_dev': 0.4714},
#   '基础作战记录': {'times': 60898, 'quantity': 6066, 'std_dev': 0.2995},
#   '异铁': {'times': 60898, 'quantity': 9694, 'std_dev': 0.366},
#   '初级作战记录': {'times': 60898, 'quantity': 6204, 'std_dev': 0.3025},
#   '中级作战记录': {'times': 60898, 'quantity': 5268, 'std_dev': 0.2811},
#   '异铁组': {'times': 60898, 'quantity': 777, 'std_dev': 0.1122},
#   '罗德岛物资补给II': {'times': 1188, 'quantity': 257, 'std_dev': 0.4117},
#   '代糖': {'times': 60898, 'quantity': 10057, 'std_dev': 0.3712},
#   '轻锰矿': {'times': 60898, 'quantity': 800, 'std_dev': 0.1139},
#   '异铁碎片': {'times': 60898, 'quantity': 8248, 'std_dev': 0.3422},
#   '糖': {'times': 60898, 'quantity': 11906, 'std_dev': 0.3967},
#   '罗德岛物资补给III': {'times': 63, 'quantity': 19, 'std_dev': 0.4589},
#   '应急理智小样': {'times': 63, 'quantity': 12, 'std_dev': 0.3927},
#   '家具': {'times': 60898, 'quantity': 1209, 'std_dev': 0.1396},
#   '32h战略配给': {'times': 8240, 'quantity': 1711, 'std_dev': 0.4056},
#   '感谢庆典物资补给': {'times': 4009, 'quantity': 885, 'std_dev': 0.4148}},
#  'a001_02_rep': {'家具': {'times': 35, 'quantity': 1, 'std_dev': 0.1666},
#   '破损装置': {'times': 35, 'quantity': 16, 'std_dev': 0.4982},
#   '代糖': {'times': 35, 'quantity': 57, 'std_dev': 0.4832}},
#  'main_09-14': {'研磨石': {'times': 5182, 'quantity': 1979, 'std_dev': 0.4859},
#   '异铁': {'times': 5182, 'quantity': 2572, 'std_dev': 0.5076},
#   '罗德岛物资补给II': {'times': 1197, 'quantity': 235, 'std_dev': 0.3972},
#   '家具': {'times': 5182, 'quantity': 94, 'std_dev': 0.1335},
#   '应急理智小样': {'times': 123, 'quantity': 12, 'std_dev': 0.2967},
#   '罗德岛物资补给III': {'times': 123, 'quantity': 20, 'std_dev': 0.369}},
#  'a001_05_rep': {'扭转醇': {'times': 29749, 'quantity': 19547, 'std_dev': 0.4747},
#   '家具': {'times': 29749, 'quantity': 616, 'std_dev': 0.1424}},
#  'main_09-08': {'炽合金': {'times': 15291, 'quantity': 225, 'std_dev': 0.1204},
#   '初级作战记录': {'times': 15291, 'quantity': 1529, 'std_dev': 0.3},
#   '轻锰矿': {'times': 15291, 'quantity': 183, 'std_dev': 0.1087},
#   '应急理智小样': {'times': 868, 'quantity': 144, 'std_dev': 0.372},
#   '罗德岛物资补给II': {'times': 1172, 'quantity': 271, 'std_dev': 0.4216},
#   '糖': {'times': 15291, 'quantity': 3063, 'std_dev': 0.4002},
#   '异铁碎片': {'times': 15291, 'quantity': 2011, 'std_dev': 0.3379},
#   '全新装置': {'times': 15291, 'quantity': 5070, 'std_dev': 0.4709},
#   '异铁': {'times': 15291, 'quantity': 2407, 'std_dev': 0.3641},
#   '代糖': {'times': 15291, 'quantity': 2551, 'std_dev': 0.3729},
#   '罗德岛物资补给III': {'times': 868, 'quantity': 184, 'std_dev': 0.4087},
#   '基础作战记录': {'times': 15291, 'quantity': 1532, 'std_dev': 0.3003},
#   '糖组': {'times': 15291, 'quantity': 249, 'std_dev': 0.1266},
#   '中级作战记录': {'times': 15291, 'quantity': 1339, 'std_dev': 0.2827},
#   '异铁组': {'times': 15291, 'quantity': 202, 'std_dev': 0.1142},
#   '家具': {'times': 15291, 'quantity': 346, 'std_dev': 0.1487}},
#  'a001_05_perm': {'源岩': {'times': 9653, 'quantity': 2133, 'std_dev': 0.4149},
#   '家具': {'times': 9653, 'quantity': 4, 'std_dev': 0.0204},
#   '装置': {'times': 9653, 'quantity': 814, 'std_dev': 0.2778},
#   '酯原料': {'times': 9653, 'quantity': 1354, 'std_dev': 0.3473},
#   '固源岩': {'times': 9653, 'quantity': 2047, 'std_dev': 0.4088},
#   '破损装置': {'times': 9653, 'quantity': 813, 'std_dev': 0.2778},
#   '聚酸酯': {'times': 9653, 'quantity': 1357, 'std_dev': 0.3477},
#   '扭转醇': {'times': 9653, 'quantity': 4277, 'std_dev': 0.4976},
#   '赤金': {'times': 9653, 'quantity': 1147, 'std_dev': 0.3236}},
#  'act11d0_04_rep': {'聚酸酯': {'times': 174, 'quantity': 204, 'std_dev': 0.3927},
#   '固源岩': {'times': 174, 'quantity': 142, 'std_dev': 0.402},
#   '家具': {'times': 174, 'quantity': 3, 'std_dev': 0.1302}},
#  'act9d0_07_rep': {'扭转醇': {'times': 15211,
#    'quantity': 11981,
#    'std_dev': 0.409},
#   '家具': {'times': 15211, 'quantity': 390, 'std_dev': 0.1581}},
#  'act15side_04': {'家具': {'times': 4322, 'quantity': 75, 'std_dev': 0.1306},
#   '酮凝集': {'times': 4322, 'quantity': 3903, 'std_dev': 0.2959},
#   '固源岩': {'times': 4322, 'quantity': 3716, 'std_dev': 0.3472}},
#  'act15d5_07': {'糖': {'times': 209, 'quantity': 25, 'std_dev': 0.3245},
#   '异铁': {'times': 209, 'quantity': 20, 'std_dev': 0.2942},
#   '酮凝集': {'times': 209, 'quantity': 18, 'std_dev': 0.2805},
#   '双酮': {'times': 209, 'quantity': 28, 'std_dev': 0.3406},
#   '基础作战记录': {'times': 209, 'quantity': 21, 'std_dev': 0.3006},
#   '家具': {'times': 209, 'quantity': 3, 'std_dev': 0.1189},
#   '代糖': {'times': 209, 'quantity': 40, 'std_dev': 0.3934},
#   '异铁碎片': {'times': 209, 'quantity': 17, 'std_dev': 0.2734},
#   '初级作战记录': {'times': 209, 'quantity': 28, 'std_dev': 0.3406},
#   '聚酸酯组': {'times': 209, 'quantity': 93, 'std_dev': 0.497}},
#  'act9mini_05': {'酮凝集': {'times': 1476, 'quantity': 146, 'std_dev': 0.2985},
#   '初级作战记录': {'times': 1476, 'quantity': 221, 'std_dev': 0.3568},
#   '代糖': {'times': 1476, 'quantity': 234, 'std_dev': 0.3652},
#   '基础作战记录': {'times': 1476, 'quantity': 158, 'std_dev': 0.3092},
#   '家具': {'times': 1476, 'quantity': 20, 'std_dev': 0.1156},
#   '晶体元件': {'times': 1476, 'quantity': 611, 'std_dev': 0.4925},
#   '异铁碎片': {'times': 1476, 'quantity': 195, 'std_dev': 0.3386},
#   '异铁': {'times': 1476, 'quantity': 140, 'std_dev': 0.293},
#   '双酮': {'times': 1476, 'quantity': 190, 'std_dev': 0.3349},
#   '糖': {'times': 1476, 'quantity': 192, 'std_dev': 0.3364}},
#  'act5d0_01': {'家具': {'times': 3, 'quantity': 2, 'std_dev': 0.4714}},
#  'act7d5_06': {'糖组': {'times': 8239, 'quantity': 128, 'std_dev': 0.1237},
#   '糖': {'times': 8239, 'quantity': 1603, 'std_dev': 0.3959},
#   '异铁': {'times': 8239, 'quantity': 1256, 'std_dev': 0.3595},
#   '家具': {'times': 8239, 'quantity': 235, 'std_dev': 0.1665},
#   '代糖': {'times': 8239, 'quantity': 1391, 'std_dev': 0.3746},
#   '异铁碎片': {'times': 8239, 'quantity': 1090, 'std_dev': 0.3388},
#   '中级作战记录': {'times': 8239, 'quantity': 710, 'std_dev': 0.2806},
#   '初级作战记录': {'times': 8239, 'quantity': 816, 'std_dev': 0.2987},
#   '异铁组': {'times': 8239, 'quantity': 102, 'std_dev': 0.1106},
#   '基础作战记录': {'times': 8239, 'quantity': 836, 'std_dev': 0.3019},
#   '轻锰矿': {'times': 8239, 'quantity': 111, 'std_dev': 0.1153},
#   '炽合金': {'times': 8239, 'quantity': 4124, 'std_dev': 0.5144}},
#  'act10d5_04': {'异铁': {'times': 81, 'quantity': 93, 'std_dev': 0.3552},
#   '固源岩': {'times': 81, 'quantity': 3, 'std_dev': 0.1889},
#   '家具': {'times': 81, 'quantity': 2, 'std_dev': 0.1552},
#   '源岩': {'times': 81, 'quantity': 33, 'std_dev': 0.4914},
#   '赤金': {'times': 81, 'quantity': 12, 'std_dev': 0.3552},
#   '聚酸酯': {'times': 81, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 81, 'quantity': 1, 'std_dev': 0.1104},
#   '酯原料': {'times': 81, 'quantity': 12, 'std_dev': 0.3552},
#   '破损装置': {'times': 81, 'quantity': 14, 'std_dev': 0.3781}},
#  'act17d0_04': {'固源岩': {'times': 164, 'quantity': 143, 'std_dev': 0.3519},
#   '酮凝集': {'times': 164, 'quantity': 143, 'std_dev': 0.3341},
#   '家具': {'times': 164, 'quantity': 9, 'std_dev': 0.2277}},
#  'act16d5_07_rep': {'糖': {'times': 215, 'quantity': 116, 'std_dev': 0.4984},
#   '家具': {'times': 215, 'quantity': 4, 'std_dev': 0.1351},
#   '异铁': {'times': 215, 'quantity': 196, 'std_dev': 0.2838}},
#  'act17side_02': {'双酮': {'times': 1936, 'quantity': 582, 'std_dev': 0.4585},
#   '家具': {'times': 1936, 'quantity': 19, 'std_dev': 0.0986},
#   '源岩': {'times': 1936, 'quantity': 1169, 'std_dev': 0.4891},
#   '破损装置': {'times': 1936, 'quantity': 418, 'std_dev': 0.4115},
#   '酯原料': {'times': 1936, 'quantity': 754, 'std_dev': 0.4876},
#   '代糖': {'times': 1936, 'quantity': 748, 'std_dev': 0.488},
#   '异铁碎片': {'times': 1936, 'quantity': 591, 'std_dev': 0.4672}},
#  'sub_05-2-1': {'感谢庆典物资补给': {'times': 3, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 186, 'quantity': 4, 'std_dev': 0.145},
#   '32h战略配给': {'times': 1, 'quantity': 1, 'std_dev': 0},
#   '岁过华灯': {'times': 2, 'quantity': 1, 'std_dev': 0.5},
#   '聚酸酯': {'times': 186, 'quantity': 208, 'std_dev': 0.323}},
#  'wk_toxic_2': {'家具': {'times': 237, 'quantity': 5, 'std_dev': 0.1436}},
#  'act8mini_06': {'晶体元件': {'times': 1969, 'quantity': 849, 'std_dev': 0.4952},
#   '异铁碎片': {'times': 1969, 'quantity': 218, 'std_dev': 0.3138},
#   '家具': {'times': 1969, 'quantity': 34, 'std_dev': 0.1303},
#   '代糖': {'times': 1969, 'quantity': 312, 'std_dev': 0.3652},
#   '初级作战记录': {'times': 1969, 'quantity': 275, 'std_dev': 0.3466},
#   '酮凝集': {'times': 1969, 'quantity': 186, 'std_dev': 0.2925},
#   '双酮': {'times': 1969, 'quantity': 219, 'std_dev': 0.3144},
#   '基础作战记录': {'times': 1969, 'quantity': 220, 'std_dev': 0.315},
#   '糖': {'times': 1969, 'quantity': 264, 'std_dev': 0.3407},
#   '异铁': {'times': 1969, 'quantity': 204, 'std_dev': 0.3047}},
#  'main_04-06': {'罗德岛物资补给III': {'times': 22, 'quantity': 6, 'std_dev': 0.4454},
#   '源岩': {'times': 28761, 'quantity': 8334, 'std_dev': 0.4537},
#   '全新装置': {'times': 28761, 'quantity': 298, 'std_dev': 0.1011},
#   '罗德岛物资补给': {'times': 1429, 'quantity': 311, 'std_dev': 0.4126},
#   '家具': {'times': 28761, 'quantity': 499, 'std_dev': 0.1305},
#   '固源岩组': {'times': 28761, 'quantity': 12839, 'std_dev': 0.5144},
#   '感谢庆典物资补给': {'times': 1028, 'quantity': 217, 'std_dev': 0.4081},
#   '罗德岛物资补给II': {'times': 399, 'quantity': 77, 'std_dev': 0.3946},
#   '破损装置': {'times': 28761, 'quantity': 3148, 'std_dev': 0.3122},
#   '装置': {'times': 28761, 'quantity': 3602, 'std_dev': 0.331},
#   '提纯源岩': {'times': 28761, 'quantity': 1551, 'std_dev': 0.2258},
#   '32h战略配给': {'times': 681, 'quantity': 152, 'std_dev': 0.4164},
#   '固源岩': {'times': 28761, 'quantity': 9022, 'std_dev': 0.464},
#   '凝胶': {'times': 28761, 'quantity': 364, 'std_dev': 0.1117},
#   '赤金': {'times': 28761, 'quantity': 2823, 'std_dev': 0.2974},
#   '半自然溶剂': {'times': 6149, 'quantity': 52, 'std_dev': 0.0916},
#   '扭转醇': {'times': 28761, 'quantity': 506, 'std_dev': 0.1315},
#   '岁过华灯': {'times': 1539, 'quantity': 283, 'std_dev': 0.3874},
#   '应急理智小样': {'times': 22, 'quantity': 2, 'std_dev': 0.2875}},
#  'main_04-05': {'罗德岛物资补给': {'times': 1725, 'quantity': 389, 'std_dev': 0.4179},
#   '酯原料': {'times': 39656, 'quantity': 16273, 'std_dev': 0.4919},
#   '酮凝集': {'times': 39656, 'quantity': 3699, 'std_dev': 0.2908},
#   '化合切削液': {'times': 5455, 'quantity': 63, 'std_dev': 0.1068},
#   'RMA70-12': {'times': 39656, 'quantity': 398, 'std_dev': 0.0997},
#   '家具': {'times': 39656, 'quantity': 826, 'std_dev': 0.1428},
#   '研磨石': {'times': 39656, 'quantity': 450, 'std_dev': 0.106},
#   '感谢庆典物资补给': {'times': 445, 'quantity': 103, 'std_dev': 0.4218},
#   '双酮': {'times': 39656, 'quantity': 13179, 'std_dev': 0.471},
#   '岁过华灯': {'times': 2372, 'quantity': 516, 'std_dev': 0.4126},
#   '应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '酮阵列': {'times': 39656, 'quantity': 1435, 'std_dev': 0.1867},
#   '晶体元件': {'times': 7194, 'quantity': 70, 'std_dev': 0.0982},
#   '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 39656, 'quantity': 4204, 'std_dev': 0.3078},
#   '聚酸酯组': {'times': 39656, 'quantity': 683, 'std_dev': 0.1301},
#   '罗德岛物资补给II': {'times': 101, 'quantity': 22, 'std_dev': 0.4128},
#   '32h战略配给': {'times': 2252, 'quantity': 493, 'std_dev': 0.4135},
#   '酮凝集组': {'times': 39656, 'quantity': 12352, 'std_dev': 0.4725}},
#  'act6d5_03': {'装置': {'times': 132, 'quantity': 3, 'std_dev': 0.149},
#   '家具': {'times': 132, 'quantity': 1, 'std_dev': 0.0867},
#   '固源岩': {'times': 132, 'quantity': 220, 'std_dev': 0.5318},
#   '源岩': {'times': 132, 'quantity': 54, 'std_dev': 0.4917},
#   '酯原料': {'times': 132, 'quantity': 29, 'std_dev': 0.414},
#   '破损装置': {'times': 132, 'quantity': 16, 'std_dev': 0.3264},
#   '赤金': {'times': 132, 'quantity': 13, 'std_dev': 0.298},
#   '聚酸酯': {'times': 132, 'quantity': 4, 'std_dev': 0.1714}},
#  'act13side_10': {'家具': {'times': 31473, 'quantity': 793, 'std_dev': 0.1567},
#   '扭转醇': {'times': 31473, 'quantity': 24614, 'std_dev': 0.4128}},
#  'main_07-14': {'轻锰矿': {'times': 33750, 'quantity': 14715, 'std_dev': 0.4959},
#   '家具': {'times': 33750, 'quantity': 670, 'std_dev': 0.1395},
#   '应急理智小样': {'times': 350, 'quantity': 51, 'std_dev': 0.3528},
#   '32h战略配给': {'times': 8454, 'quantity': 1700, 'std_dev': 0.4008},
#   '感谢庆典物资补给': {'times': 28, 'quantity': 4, 'std_dev': 0.3499},
#   '罗德岛物资补给II': {'times': 116, 'quantity': 17, 'std_dev': 0.3537},
#   '固源岩': {'times': 33750, 'quantity': 34655, 'std_dev': 0.9475},
#   '罗德岛物资补给III': {'times': 350, 'quantity': 79, 'std_dev': 0.4181}},
#  'act15d5_06': {'扭转醇': {'times': 4983, 'quantity': 1746, 'std_dev': 0.4771},
#   '赤金': {'times': 4983, 'quantity': 493, 'std_dev': 0.2986},
#   '源岩': {'times': 4983, 'quantity': 1984, 'std_dev': 0.4895},
#   '固源岩': {'times': 4983, 'quantity': 127, 'std_dev': 0.1576},
#   '聚酸酯': {'times': 4983, 'quantity': 92, 'std_dev': 0.1346},
#   '家具': {'times': 4983, 'quantity': 81, 'std_dev': 0.1265},
#   '装置': {'times': 4983, 'quantity': 63, 'std_dev': 0.1117},
#   '酯原料': {'times': 4983, 'quantity': 1348, 'std_dev': 0.4442},
#   '破损装置': {'times': 4983, 'quantity': 788, 'std_dev': 0.3649}},
#  'act15d0_01_perm': {'异铁': {'times': 32, 'quantity': 20, 'std_dev': 0.4841},
#   '异铁碎片': {'times': 32, 'quantity': 2, 'std_dev': 0.2421},
#   '酯原料': {'times': 32, 'quantity': 6, 'std_dev': 0.3903},
#   '破损装置': {'times': 32, 'quantity': 1, 'std_dev': 0.174},
#   '家具': {'times': 32, 'quantity': 0, 'std_dev': 0},
#   '源岩': {'times': 32, 'quantity': 11, 'std_dev': 0.475},
#   '代糖': {'times': 32, 'quantity': 5, 'std_dev': 0.3631},
#   '双酮': {'times': 32, 'quantity': 5, 'std_dev': 0.3631},
#   '赤金': {'times': 32, 'quantity': 2, 'std_dev': 0.2421}},
#  'act15d0_07_perm': {'凝胶': {'times': 232, 'quantity': 5, 'std_dev': 0.1452},
#   '家具': {'times': 232, 'quantity': 0, 'std_dev': 0},
# ...
#   '异铁碎片': {'times': 2573, 'quantity': 196, 'std_dev': 0.2653},
#   '异铁': {'times': 2573, 'quantity': 408, 'std_dev': 0.3653},
#   '基础作战记录': {'times': 2573, 'quantity': 470, 'std_dev': 0.5645},
#   '异铁块': {'times': 2573, 'quantity': 109, 'std_dev': 0.2014},
#   '应急理智小样': {'times': 2098, 'quantity': 502, 'std_dev': 0.4266},
#   '家具': {'times': 2573, 'quantity': 60, 'std_dev': 0.1509},
#   '炽合金': {'times': 2573, 'quantity': 76, 'std_dev': 0.1693}},
#  'randomMaterialRune_7': {'凝胶': {'times': 1725,
#    'quantity': 82,
#    'std_dev': 0.3177},
#   '炽合金': {'times': 1725, 'quantity': 122, 'std_dev': 0.4343},
#   '化合切削液': {'times': 1725, 'quantity': 112, 'std_dev': 0.4105},
#   '糖组': {'times': 1725, 'quantity': 149, 'std_dev': 0.5187},
#   '家具': {'times': 1725, 'quantity': 0, 'std_dev': 0},
#   '酮凝集组': {'times': 1725, 'quantity': 126, 'std_dev': 0.4258},
#   'RMA70-12': {'times': 1725, 'quantity': 87, 'std_dev': 0.341},
#   '晶体元件': {'times': 1725, 'quantity': 102, 'std_dev': 0.3867},
#   '聚酸酯组': {'times': 1725, 'quantity': 125, 'std_dev': 0.4252},
#   '异铁组': {'times': 1725, 'quantity': 135, 'std_dev': 0.4913},
#   '全新装置': {'times': 1725, 'quantity': 81, 'std_dev': 0.2999},
#   '研磨石': {'times': 1725, 'quantity': 120, 'std_dev': 0.4411},
#   '轻锰矿': {'times': 1725, 'quantity': 114, 'std_dev': 0.4146},
#   '半自然溶剂': {'times': 1725, 'quantity': 109, 'std_dev': 0.3823},
#   '固源岩组': {'times': 1725, 'quantity': 166, 'std_dev': 0.5626},
#   '扭转醇': {'times': 1725, 'quantity': 95, 'std_dev': 0.3602}},
#  'act13d5_05_rep': {'异铁': {'times': 80, 'quantity': 89, 'std_dev': 0.316},
#   '固源岩': {'times': 80, 'quantity': 87, 'std_dev': 0.2826},
#   '家具': {'times': 80, 'quantity': 3, 'std_dev': 0.19}},
#  'sub_02-05': {'聚酸酯': {'times': 671, 'quantity': 10, 'std_dev': 0.1211},
#   '装置': {'times': 671, 'quantity': 13, 'std_dev': 0.1378},
#   '罗德岛物资补给II': {'times': 3, 'quantity': 1, 'std_dev': 0.4714},
#   '家具': {'times': 671, 'quantity': 11, 'std_dev': 0.127},
#   '32h战略配给': {'times': 11, 'quantity': 1, 'std_dev': 0.2875},
#   '罗德岛物资补给III': {'times': 21, 'quantity': 4, 'std_dev': 0.3927},
#   '源岩': {'times': 671, 'quantity': 2469, 'std_dev': 0.6344},
#   '固源岩': {'times': 671, 'quantity': 13, 'std_dev': 0.1378},
#   '罗德岛物资补给': {'times': 6, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 671, 'quantity': 168, 'std_dev': 0.4332},
#   '破损装置': {'times': 671, 'quantity': 94, 'std_dev': 0.3472},
#   '感谢庆典物资补给': {'times': 8, 'quantity': 3, 'std_dev': 0.4841},
#   '岁过华灯': {'times': 7, 'quantity': 2, 'std_dev': 0.4518},
#   '赤金': {'times': 671, 'quantity': 51, 'std_dev': 0.265},
#   '基础作战记录': {'times': 671, 'quantity': 825, 'std_dev': 0.4204},
#   '应急理智小样': {'times': 21, 'quantity': 3, 'std_dev': 0.3499}},
#  'wk_kc_1': {'家具': {'times': 132, 'quantity': 2, 'std_dev': 0.1222},
#   '感谢庆典物资补给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给II': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '初级作战记录': {'times': 132, 'quantity': 396, 'std_dev': 0},
#   '基础作战记录': {'times': 132, 'quantity': 273, 'std_dev': 0.7302}},
#  'main_03-06': {'应急理智小样': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '双酮': {'times': 355, 'quantity': 40, 'std_dev': 0.3161},
#   '罗德岛物资补给II': {'times': 13, 'quantity': 6, 'std_dev': 0.4985},
#   '代糖': {'times': 355, 'quantity': 62, 'std_dev': 0.3796},
#   '异铁': {'times': 355, 'quantity': 38, 'std_dev': 0.3091},
#   '糖': {'times': 355, 'quantity': 41, 'std_dev': 0.3197},
#   '罗德岛物资补给III': {'times': 2, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 355, 'quantity': 54, 'std_dev': 0.3592},
#   '酮凝集': {'times': 355, 'quantity': 35, 'std_dev': 0.298},
#   '初级作战记录': {'times': 355, 'quantity': 68, 'std_dev': 0.3935},
#   '基础作战记录': {'times': 355, 'quantity': 25, 'std_dev': 0.2559},
#   '罗德岛物资补给': {'times': 9, 'quantity': 1, 'std_dev': 0.3143},
#   '家具': {'times': 355, 'quantity': 11, 'std_dev': 0.1734}},
#  'act9d0_05': {'装置': {'times': 530, 'quantity': 216, 'std_dev': 0.4914},
#   '家具': {'times': 530, 'quantity': 11, 'std_dev': 0.1426},
#   '糖': {'times': 530, 'quantity': 712, 'std_dev': 0.4748}},
#  'main_06-08': {'中级作战记录': {'times': 413, 'quantity': 413, 'std_dev': 0},
#   '聚酸酯': {'times': 413, 'quantity': 469, 'std_dev': 0.3424},
#   '家具': {'times': 413, 'quantity': 5, 'std_dev': 0.1093},
#   '罗德岛物资补给': {'times': 45, 'quantity': 8, 'std_dev': 0.3823},
#   '32h战略配给': {'times': 1, 'quantity': 0, 'std_dev': 0}},
#  'act18d3_04_perm': {'破损装置': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 5, 'quantity': 7, 'std_dev': 0.4899},
#   '家具': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '赤金': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '酯原料': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 5, 'quantity': 4, 'std_dev': 0.4},
#   '固源岩': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 5, 'quantity': 0, 'std_dev': 0},
#   '源岩': {'times': 5, 'quantity': 1, 'std_dev': 0.4}},
#  'main_09-07': {'扭转醇': {'times': 1529, 'quantity': 560, 'std_dev': 0.4939},
#   '罗德岛物资补给II': {'times': 616, 'quantity': 124, 'std_dev': 0.401},
#   '源岩': {'times': 1529, 'quantity': 408, 'std_dev': 0.4423},
#   '破损装置': {'times': 1529, 'quantity': 158, 'std_dev': 0.3044},
#   '罗德岛物资补给III': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '固源岩组': {'times': 1529, 'quantity': 31, 'std_dev': 0.1409},
#   '家具': {'times': 1529, 'quantity': 25, 'std_dev': 0.1268},
#   '装置': {'times': 1529, 'quantity': 182, 'std_dev': 0.3238},
#   '全新装置': {'times': 1529, 'quantity': 16, 'std_dev': 0.1018},
#   '固源岩': {'times': 1529, 'quantity': 486, 'std_dev': 0.4656},
#   '半自然溶剂': {'times': 1529, 'quantity': 15, 'std_dev': 0.0986},
#   '凝胶': {'times': 1529, 'quantity': 20, 'std_dev': 0.1136},
#   '应急理智小样': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '白马醇': {'times': 1529, 'quantity': 59, 'std_dev': 0.1926},
#   '赤金': {'times': 1529, 'quantity': 182, 'std_dev': 0.3239}},
#  'act13side_07': {'装置': {'times': 688, 'quantity': 615, 'std_dev': 0.3351},
#   '异铁': {'times': 688, 'quantity': 424, 'std_dev': 0.5039},
#   '家具': {'times': 688, 'quantity': 11, 'std_dev': 0.1254}},
#  'main_06-03': {'固源岩组': {'times': 621, 'quantity': 20, 'std_dev': 0.1766},
#   '凝胶': {'times': 621, 'quantity': 7, 'std_dev': 0.1055},
#   '半自然溶剂': {'times': 61, 'quantity': 3, 'std_dev': 0.2162},
#   '糖组': {'times': 621, 'quantity': 233, 'std_dev': 0.4841},
#   '固源岩': {'times': 621, 'quantity': 197, 'std_dev': 0.4654},
#   '装置': {'times': 621, 'quantity': 70, 'std_dev': 0.3162},
#   '赤金': {'times': 621, 'quantity': 64, 'std_dev': 0.304},
#   '岁过华灯': {'times': 33, 'quantity': 8, 'std_dev': 0.4285},
#   '罗德岛物资补给II': {'times': 14, 'quantity': 3, 'std_dev': 0.4103},
#   '源岩': {'times': 621, 'quantity': 167, 'std_dev': 0.4434},
#   '扭转醇': {'times': 621, 'quantity': 13, 'std_dev': 0.1431},
#   '破损装置': {'times': 621, 'quantity': 79, 'std_dev': 0.3332},
#   '全新装置': {'times': 621, 'quantity': 5, 'std_dev': 0.0894},
#   '罗德岛物资补给': {'times': 289, 'quantity': 74, 'std_dev': 0.4365},
#   '家具': {'times': 621, 'quantity': 11, 'std_dev': 0.1319}},
#  'act9d0_04': {'固源岩': {'times': 1819, 'quantity': 3029, 'std_dev': 0.4719},
#   '异铁': {'times': 1819, 'quantity': 793, 'std_dev': 0.4959},
#   '家具': {'times': 1819, 'quantity': 41, 'std_dev': 0.1484}},
#  'act5d0_02': {'初级作战记录': {'times': 6, 'quantity': 18, 'std_dev': 0},
#   '家具': {'times': 6, 'quantity': 0, 'std_dev': 0}},
#  'act13d5_08_rep': {'轻锰矿': {'times': 4315,
#    'quantity': 2885,
#    'std_dev': 0.4707},
#   '家具': {'times': 4315, 'quantity': 98, 'std_dev': 0.149}},
#  'act13d0_06': {'固源岩': {'times': 2397, 'quantity': 54, 'std_dev': 0.1484},
#   '家具': {'times': 2397, 'quantity': 38, 'std_dev': 0.1249},
#   '装置': {'times': 2397, 'quantity': 42, 'std_dev': 0.1312},
#   '酯原料': {'times': 2397, 'quantity': 633, 'std_dev': 0.4408},
#   '赤金': {'times': 2397, 'quantity': 237, 'std_dev': 0.2985},
#   '源岩': {'times': 2397, 'quantity': 934, 'std_dev': 0.4877},
#   '聚酸酯': {'times': 2397, 'quantity': 41, 'std_dev': 0.1297},
#   '扭转醇': {'times': 2397, 'quantity': 842, 'std_dev': 0.4774},
#   '破损装置': {'times': 2397, 'quantity': 395, 'std_dev': 0.371}},
#  'main_02-09': {'罗德岛物资补给': {'times': 98, 'quantity': 13, 'std_dev': 0.3392},
#   '32h战略配给': {'times': 21, 'quantity': 3, 'std_dev': 0.3499},
#   '源岩': {'times': 6755, 'quantity': 2853, 'std_dev': 0.4939},
#   '固源岩': {'times': 6755, 'quantity': 192, 'std_dev': 0.1663},
#   '破损装置': {'times': 6755, 'quantity': 1066, 'std_dev': 0.3646},
#   '应急理智小样': {'times': 15, 'quantity': 5, 'std_dev': 0.4714},
#   '扭转醇': {'times': 6755, 'quantity': 1771, 'std_dev': 0.4398},
#   '罗德岛物资补给III': {'times': 15, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 6755, 'quantity': 89, 'std_dev': 0.1141},
#   '聚酸酯': {'times': 6755, 'quantity': 121, 'std_dev': 0.1326},
#   '岁过华灯': {'times': 117, 'quantity': 16, 'std_dev': 0.3436},
#   '罗德岛物资补给II': {'times': 7, 'quantity': 1, 'std_dev': 0.3499},
#   '赤金': {'times': 6755, 'quantity': 609, 'std_dev': 0.2864},
#   '家具': {'times': 6755, 'quantity': 86, 'std_dev': 0.1121},
#   '基础作战记录': {'times': 6755, 'quantity': 8420, 'std_dev': 0.431},
#   '感谢庆典物资补给': {'times': 86, 'quantity': 9, 'std_dev': 0.3061},
#   '酯原料': {'times': 6755, 'quantity': 1778, 'std_dev': 0.4404}},
#  'a001_03_perm': {'酯原料': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '破损装置': {'times': 21, 'quantity': 2, 'std_dev': 0.2936},
#   '装置': {'times': 21, 'quantity': 2, 'std_dev': 0.2936},
#   '源岩': {'times': 21, 'quantity': 57, 'std_dev': 1.2777},
#   '赤金': {'times': 21, 'quantity': 2, 'std_dev': 0.2935},
#   '固源岩': {'times': 21, 'quantity': 1, 'std_dev': 0.213},
#   '聚酸酯': {'times': 21, 'quantity': 1, 'std_dev': 0.2129},
#   '家具': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 21, 'quantity': 24, 'std_dev': 0.5595}},
#  'act18d3_09': {'全新装置': {'times': 116534, 'quantity': 58144, 'std_dev': 0.5},
#   '家具': {'times': 116534, 'quantity': 2872, 'std_dev': 0.155}},
#  'act11d0_05_rep': {'装置': {'times': 176, 'quantity': 69, 'std_dev': 0.4882},
#   '酮凝集': {'times': 176, 'quantity': 201, 'std_dev': 0.3491},
#   '家具': {'times': 176, 'quantity': 1, 'std_dev': 0.0752}},
#  'act12d0_02_rep': {'酯原料': {'times': 51, 'quantity': 45, 'std_dev': 0.3222},
#   '破损装置': {'times': 51, 'quantity': 51, 'std_dev': 0},
#   '家具': {'times': 51, 'quantity': 1, 'std_dev': 0.1386}},
#  'act18side_02': {'破损装置': {'times': 1939, 'quantity': 462, 'std_dev': 0.426},
#   '酯原料': {'times': 1939, 'quantity': 822, 'std_dev': 0.4942},
#   '代糖': {'times': 1939, 'quantity': 809, 'std_dev': 0.4931},
#   '异铁碎片': {'times': 1939, 'quantity': 657, 'std_dev': 0.4733},
#   '双酮': {'times': 1939, 'quantity': 640, 'std_dev': 0.4702},
#   '家具': {'times': 1939, 'quantity': 19, 'std_dev': 0.0985},
#   '源岩': {'times': 1939, 'quantity': 1185, 'std_dev': 0.4875}},
#  'sub_06-1-1': {'酮凝集': {'times': 260, 'quantity': 21, 'std_dev': 0.2725},
#   '聚酸酯': {'times': 260, 'quantity': 25, 'std_dev': 0.2948},
#   '家具': {'times': 260, 'quantity': 6, 'std_dev': 0.1501},
#   'RMA70-12': {'times': 260, 'quantity': 2, 'std_dev': 0.0874},
#   '罗德岛物资补给II': {'times': 23, 'quantity': 6, 'std_dev': 0.4391},
#   '晶体元件': {'times': 33, 'quantity': 0, 'std_dev': 0},
#   '罗德岛物资补给': {'times': 49, 'quantity': 10, 'std_dev': 0.403},
#   '双酮': {'times': 260, 'quantity': 84, 'std_dev': 0.4676},
#   '研磨石': {'times': 260, 'quantity': 1, 'std_dev': 0.0619},
#   '中级作战记录': {'times': 260, 'quantity': 729, 'std_dev': 0.782},
#   '32h战略配给': {'times': 1, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯组': {'times': 260, 'quantity': 6, 'std_dev': 0.1501},
#   '化合切削液': {'times': 23, 'quantity': 0, 'std_dev': 0},
#   '酮凝集组': {'times': 260, 'quantity': 6, 'std_dev': 0.1501},
#   '酯原料': {'times': 260, 'quantity': 115, 'std_dev': 0.4966},
#   '感谢庆典物资补给': {'times': 1, 'quantity': 1, 'std_dev': 0}},
#  'a003_f02_perm': {'酯原料': {'times': 21, 'quantity': 57, 'std_dev': 0.7649},
#   '赤金': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '家具': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '基础作战记录': {'times': 21, 'quantity': 23, 'std_dev': 0.526},
#   '源岩': {'times': 21, 'quantity': 6, 'std_dev': 0.4517},
#   '破损装置': {'times': 21, 'quantity': 3, 'std_dev': 0.3499},
#   '固源岩': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '聚酸酯': {'times': 21, 'quantity': 0, 'std_dev': 0},
#   '装置': {'times': 21, 'quantity': 0, 'std_dev': 0}},
#  'a001_05': {'扭转醇': {'times': 12211, 'quantity': 8073, 'std_dev': 0.4733},
#   '家具': {'times': 12211, 'quantity': 369, 'std_dev': 0.1712}},
#  'pro_d_2': {'感谢庆典物资补给': {'times': 142, 'quantity': 56, 'std_dev': 0.4887},
#   '近卫芯片组': {'times': 32940, 'quantity': 16421, 'std_dev': 0.5},
#   '特种芯片组': {'times': 32940, 'quantity': 16519, 'std_dev': 0.5},
#   '罗德岛物资补给II': {'times': 114, 'quantity': 42, 'std_dev': 0.4824},
#   '罗德岛物资补给III': {'times': 178, 'quantity': 63, 'std_dev': 0.4782},
#   '家具': {'times': 33643, 'quantity': 10, 'std_dev': 0.0172},
#   '应急理智小样': {'times': 178, 'quantity': 59, 'std_dev': 0.4707},
#   '32h战略配给': {'times': 628, 'quantity': 304, 'std_dev': 0.4997}},
#  'sub_05-4-2': {'炽合金': {'times': 7540, 'quantity': 2316, 'std_dev': 0.4613},
#   '全新装置': {'times': 7540, 'quantity': 71, 'std_dev': 0.0966},
#   '罗德岛物资补给III': {'times': 11, 'quantity': 1, 'std_dev': 0.2875},
#   '装置': {'times': 7540, 'quantity': 875, 'std_dev': 0.3203},
#   '应急理智小样': {'times': 11, 'quantity': 4, 'std_dev': 0.481},
#   '固源岩': {'times': 7540, 'quantity': 2374, 'std_dev': 0.4644},
#   '半自然溶剂': {'times': 2840, 'quantity': 30, 'std_dev': 0.1023},
#   '炽合金块': {'times': 7540, 'quantity': 309, 'std_dev': 0.1982},
#   '感谢庆典物资补给': {'times': 89, 'quantity': 21, 'std_dev': 0.4246},
#   '家具': {'times': 7540, 'quantity': 149, 'std_dev': 0.1392},
#   '32h战略配给': {'times': 37, 'quantity': 7, 'std_dev': 0.3917},
#   '破损装置': {'times': 7540, 'quantity': 871, 'std_dev': 0.3195},
#   '固源岩组': {'times': 7540, 'quantity': 149, 'std_dev': 0.1392},
#   '扭转醇': {'times': 7540, 'quantity': 122, 'std_dev': 0.1261},
#   '凝胶': {'times': 7540, 'quantity': 108, 'std_dev': 0.1189},
#   '赤金': {'times': 7540, 'quantity': 790, 'std_dev': 0.3063},
#   '罗德岛物资补给II': {'times': 175, 'quantity': 46, 'std_dev': 0.4402},
#   '罗德岛物资补给': {'times': 1112, 'quantity': 240, 'std_dev': 0.4114},
#   '岁过华灯': {'times': 72, 'quantity': 18, 'std_dev': 0.433},
#   '源岩': {'times': 7540, 'quantity': 2160, 'std_dev': 0.4521}},
#  'act13side_08': {'家具': {'times': 7844, 'quantity': 221, 'std_dev': 0.1655},
#   '糖组': {'times': 7844, 'quantity': 6424, 'std_dev': 0.385}},
#  'act13d5_06_perm': {'异铁': {'times': 507, 'quantity': 60, 'std_dev': 0.323},
#   '聚合凝胶': {'times': 507, 'quantity': 24, 'std_dev': 0.2124},
#   '凝胶': {'times': 507, 'quantity': 127, 'std_dev': 0.4333},
#   '酮凝集': {'times': 507, 'quantity': 58, 'std_dev': 0.3183},
#   '初级作战记录': {'times': 507, 'quantity': 88, 'std_dev': 0.3787},
#   '代糖': {'times': 507, 'quantity': 79, 'std_dev': 0.3627},
#   '双酮': {'times': 507, 'quantity': 62, 'std_dev': 0.3276},
#   '基础作战记录': {'times': 507, 'quantity': 42, 'std_dev': 0.2756},
#   '家具': {'times': 507, 'quantity': 0, 'std_dev': 0},
#   '异铁碎片': {'times': 507, 'quantity': 60, 'std_dev': 0.323},
#   '糖': {'times': 507, 'quantity': 58, 'std_dev': 0.3183}},
#  'main_04-07': {'赤金': {'times': 36553, 'quantity': 3672, 'std_dev': 0.3007},
#   '罗德岛物资补给III': {'times': 218, 'quantity': 40, 'std_dev': 0.3871},
#   '家具': {'times': 36553, 'quantity': 810, 'std_dev': 0.1472},
#   '全新装置': {'times': 36553, 'quantity': 404, 'std_dev': 0.1045},
#   '32h战略配给': {'times': 3459, 'quantity': 721, 'std_dev': 0.4062},
#   '轻锰矿': {'times': 36553, 'quantity': 10866, 'std_dev': 0.4571},
#   '装置': {'times': 36553, 'quantity': 4575, 'std_dev': 0.3309},
#   '应急理智小样': {'times': 218, 'quantity': 34, 'std_dev': 0.3628},
#   '凝胶': {'times': 36553, 'quantity': 413, 'std_dev': 0.1058},
#   '感谢庆典物资补给': {'times': 34, 'quantity': 4, 'std_dev': 0.3222},
#   '罗德岛物资补给II': {'times': 46, 'quantity': 10, 'std_dev': 0.4125},
#   '破损装置': {'times': 36553, 'quantity': 4111, 'std_dev': 0.316},
#   '扭转醇': {'times': 36553, 'quantity': 650, 'std_dev': 0.1321},
#   '半自然溶剂': {'times': 7113, 'quantity': 82, 'std_dev': 0.1068},
#   '固源岩组': {'times': 36553, 'quantity': 715, 'std_dev': 0.1384},
#   '罗德岛物资补给': {'times': 2128, 'quantity': 443, 'std_dev': 0.406},
#   '岁过华灯': {'times': 2349, 'quantity': 508, 'std_dev': 0.4117},
#   '源岩': {'times': 36553, 'quantity': 10522, 'std_dev': 0.4527},
#   '三水锰矿': {'times': 36553, 'quantity': 1439, 'std_dev': 0.1945},
#   '固源岩': {'times': 36553, 'quantity': 11422, 'std_dev': 0.4636}}}
